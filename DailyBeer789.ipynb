# %% [markdown]
# # Daily Beer 789 Analysis

# %%
# %load_ext sql
# Out:
# /root/anaconda2/lib/python2.7/site-packages/IPython/config.py:13: ShimWarning: The `IPython.config` package has been deprecated since IPython 4.0. You should import from traitlets.config instead.
#   "You should import from traitlets.config instead.", ShimWarning)
# /root/anaconda2/lib/python2.7/site-packages/IPython/utils/traitlets.py:5: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   warn("IPython.utils.traitlets has moved to a top-level traitlets package.")

# %%
# %sql sqlite:///Order789Gsheet.db
# Out:
# u'Connected: None@Order789Gsheet.db'

# %%
# %sql select * from Order789Gsheet;

# %%
# %%sql
# select
#         sku, pname,
#         month,
#         '월' as mon,
#         sum(total) as gtotal,
#         sum(qty) as qty,
#         '개' as quantity
# from order789Gsheet
# group by sku, month
# order by sku, month;
# Out:
# Done.
# [(u'100353', u'\ubc31\uc124 \ubc14\uc0ad\ud280\uae40\uac00\ub8e8(1Kg/EA) \ubbf8\uad6d\n\u203b\ubbf8\uad6d\uc0b0', u'8', u'\uc6d4', 2750, 1, u'\uac1c'),
#  (u'100353', u'\ubc31\uc124 \ubc14\uc0ad\ud280\uae40\uac00\ub8e8(1Kg/EA) \ubbf8\uad6d\n\u203b\ubbf8\uad6d\uc0b0', u'9', u'\uc6d4', 13750, 5, u'\uac1c'),
#  (u'100743', u'\ucf54\uce74\ucf5c\ub77c \ucf5c\ub77c(\uce94_355ml 355g/EA) \ud55c\uad6d 24EA/BOX\n\u203b\uad6d\ub0b4\uc0b0', u'7', u'\uc6d4', 68112, 4, u'\uac1c'),
#  (u'100743', u'\ucf54\uce74\ucf5c\ub77c \ucf5c\ub77c(\uce94_355ml 355g/EA) \ud55c\uad6d 24EA/BOX\n\u203b\uad6d\ub0b4\uc0b0', u'8', u'\uc6d4', 68112, 4, u'\uac1c'),
#  (u'100743', u'\ucf54\uce74\ucf5c\ub77c \ucf5c\ub77c(\uce94_355ml 355g/EA) \ud55c\uad6d 24EA/BOX\n\u203b\uad6d\ub0b4\uc0b0', u'9', u'\uc6d4', 34056, 2, u'\uac1c'),
#  (u'100744', u'\uc2a4\ud504\ub77c\uc774\ud2b8 \uc0ac\uc774\ub2e4(355ml 355g/EA) \ud55c\uad6d 24EA/BOX\n\u203b\uad6d\ub0b4\uc0b0', u'7', u'\uc6d4', 76955, 5, u'\uac1c'),
# ...
