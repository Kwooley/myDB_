# %% [markdown]
# # Daily Beer 789 Analysis

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite:///OrderAll.db
# Out:
# u'Connected: None@OrderAll.db'

# %%
# %sql select * from Order789Gsheet;

# %%
# %%sql
# select
#         sku, pname,
#         month,
#         '월' as mon,
#         sum(total) as gtotal,
#         sum(qty) as qty,
#         '개' as quantity
# from OrderAll
# group by sku, month
# order by sku, month;
# Out:
# Done.
# [(u'100353', u'\ubc31\uc124 \ubc14\uc0ad\ud280\uae40\uac00\ub8e8(1Kg/EA) \ubbf8\uad6d-\u203b\ubbf8\uad6d\uc0b0', 8, u'\uc6d4', 2750, 1, u'\uac1c'),
#  (u'100353', u'\ubc31\uc124 \ubc14\uc0ad\ud280\uae40\uac00\ub8e8(1Kg/EA) \ubbf8\uad6d-\u203b\ubbf8\uad6d\uc0b0', 9, u'\uc6d4', 13750, 5, u'\uac1c'),
#  (u'100743', u'\ucf54\uce74\ucf5c\ub77c \ucf5c\ub77c(\uce94_355ml 355g/EA) \ud55c\uad6d 24EA/BOX-\u203b\uad6d\ub0b4\uc0b0', 7, u'\uc6d4', 51084, 3, u'\uac1c'),
#  (u'100743', u'\ucf54\uce74\ucf5c\ub77c \ucf5c\ub77c(\uce94_355ml 355g/EA) \ud55c\uad6d 24EA/BOX-\u203b\uad6d\ub0b4\uc0b0', 8, u'\uc6d4', 68112, 4, u'\uac1c'),
#  (u'100743', u'\ucf54\uce74\ucf5c\ub77c \ucf5c\ub77c(\uce94_355ml 355g/EA) \ud55c\uad6d 24EA/BOX-\u203b\uad6d\ub0b4\uc0b0', 9, u'\uc6d4', 34056, 2, u'\uac1c'),
#  (u'100743', u'\ucf54\uce74\ucf5c\ub77c \ucf5c\ub77c(\uce94_355ml 355g/EA) \ud55c\uad6d 24EA/BOX-\u203b\uad6d\ub0b4\uc0b0', 10, u'\uc6d4', 51084, 3, u'\uac1c'),
# ...

# %%
# %%sql
# select * from OrderAll where  month = '10';
# Out:
# Done.
# [(2017, 10, 31, u'2017-10-31', u'1', u'2114865845', u'134356', u'\uc2ec\ud50c\ub85c\ud2b8 \ub0c9\ub3d9\uac10\uc790(\uba54\uac00\ud06c\ub7f0\uce58 2.04Kg/EA)', u'EA', u'5', u'9960', u'49800', u'4980', u'54780'),
#  (2017, 10, 31, u'2017-10-31', u'2', u'2114865845', u'140440', u'\uc2ec\ud50c\ub85c\ud2b8 \ub0c9\ub3d9\uac10\uc790(\ud06c\ub9c1\ud074\ucef7\uc6e8\uc9c0 2.26Kg/EA)', u'EA', u'5', u'6980', u'34900', u'3490', u'38390'),
#  (2017, 10, 31, u'2017-10-31', u'3', u'2114865845', u'146239', u'\uc250\ud504\uc194\ub8e8\uc158 \uae40\uce58\ubcf6\uc74c\ubc25(300g/EA)', u'EA', u'10', u'1400', u'14000', u'1400', u'15400'),
#  (2017, 10, 31, u'2017-10-31', u'4', u'2114865840', u'127454', u'\ud30c\ub85c \ud560\ub77c\ud398\ub1e8(\uc2ac\ub77c\uc774\uc2a4 3Kg/EA)', u'EA', u'2', u'8500', u'17000', u'1700', u'18700'),
# ...

# %%
# %%sql
# select * from OrderAll where orderno = '2117949949';
# Out:
# Done.
# []
