# %% [markdown]
# # DailyBeer 789

# %%
import sqlite3
conn = sqlite3.connect("Order10.db")

# %% [markdown]
# ## Monthly  Outgoing Analysis

# %%
sql_cmd = """
select month, sku, pname, sum(total) as gtotal, '원' as won, sum(qty) as qty, '개' as quantity
from order789Gsheet
where month = 10 and year = 2017
group by sku
order by gtotal desc;
"""
cursor = conn.cursor()
cursor.execute(sql_cmd)
tuples = cursor.fetchall()

# %%
for tuple in tuples:
    #pname = tuple[2].replace("\n", "-")
    pname = tuple[2]
    
    print tuple[0], '월', tuple[1], pname[:10].ljust(40), '\t\t\t', "{:10,}".format(tuple[3]),'원', '\t\t', tuple[5],'개'
# Out:
# 10 월 424782 염지닭(생활맥주용                                			 1,851,630 원 		31 개
# 10 월 134356 심플로트 냉동감자(                               			   777,876 원 		71 개
# 10 월 424783 염지닭안심(생활맥주                               			   592,020 원 		13 개
# 10 월 140440 심플로트 냉동감자(                               			   514,426 원 		67 개
# 10 월 144398 심플로트 냉동감자(                               			   474,628 원 		46 개
# 10 월 232931 반건오징어(생활맥주                               			   442,500 원 		15 개
# 10 월 176689 소시지(생활맥주용                                			   432,630 원 		90 개
# 10 월 169394 샐러드믹스(생활맥주                               			   288,000 원 		20 개
# 10 월 163815 이츠웰 골뱅이캔(자                               			   271,040 원 		88 개
# 10 월 201934 소고기육포(생활맥주                               			   262,020 원 		60 개
# 10 월 115722 사세통상 버팔로윙(                               			   242,550 원 		21 개
# 10 월 247491 뫼루니식품 레드소스                               			   227,700 원 		30 개
# 10 월 116709 리코스 나쵸칩(45                               			   226,490 원 		71 개
# 10 월 116981 사세통상 버팔로윙스                               			   226,380 원 		21 개
# 10 월 124531 맥앤치즈볼(생활맥주                               			   222,992 원 		56 개
# 10 월 215140 양파드레싱(생활맥주                               			   198,000 원 		20 개
# 10 월 206578 길림양행 땅콩(껍질                               			   177,100 원 		23 개
# 10 월 118232 스팸 햄캔(마일드                                			   138,600 원 		45 개
# 10 월 119863 삼조쎌텍 나쵸치즈소                               			   127,820 원 		14 개
# 10 월 127454 파로 할라페뇨(슬라                               			   121,550 원 		13 개
# 10 월 145970 치킨무(외식체인전용                               			   119,700 원 		21 개
# 10 월 166412 뫼루니식품 물결무늬                               			   115,720 원 		8 개
# 10 월 100744 스프라이트 사이다(                               			    92,346 원 		6 개
# 10 월 146239 쉐프솔루션 김치볶음                               			    84,700 원 		55 개
# 10 월 177050 기름여과지(생활맥주                               			    80,300 원 		1 개
# 10 월 115364 삼진 살사소스(2K                               			    79,200 원 		8 개
# 10 월 112371 칵테일냅킨(생활맥주                               			    66,000 원 		2 개
# 10 월 526116 유산지(생활맥주용                                			    66,000 원 		2 개
# 10 월 178883 코스터(생활맥주용                                			    62,700 원 		1 개
# 10 월 171838 팔도 비빔면(130                               			    58,960 원 		2 개
# 10 월 401354 계란(특란_60g*                               			    56,937 원 		7 개
# 10 월 100743 코카콜라 콜라(캔_                               			    51,084 원 		3 개
# 10 월 160016 오뚜기 케찹(스파우                               			    43,450 원 		10 개
# 10 월 242910 웰넛 건포도(500                               			    40,480 원 		16 개
# 10 월 526117 비닐백(생활맥주용                                			    39,600 원 		4 개
# 10 월 111308 천일식품 새우볶음밥                               			    32,274 원 		18 개
# 10 월 146391 쉐프솔루션 햄야채볶                               			    30,703 원 		19 개
# 10 월 215139 케이준드레싱(생활맥                               			    29,865 원 		3 개
# 10 월 501386 트레펑(1L 막힌하                               			    24,365 원 		10 개
# 10 월 105409 아담스 파마산치즈파                               			    24,200 원 		2 개
# 10 월 178733 물티슈(생활맥주용                                			    24,200 원 		2 개
# 10 월 166413 뫼루니 양념치킨소스                               			    22,770 원 		3 개
# 10 월 138389 이츠웰 초고추장(N                               			    19,800 원 		6 개
# 10 월 146393 쉐프솔루션 해물볶음                               			    12,840 원 		8 개
# 10 월 154639 오뚜기 마요네즈(골                               			    10,780 원 		1 개
# 10 월 512188 이츠웰 롤백(중_3                               			     7,700 원 		2 개
# 10 월 135267 그라나파다노치즈(포                               			     7,260 원 		1 개
# 10 월 139476 신영상회 파슬리후레                               			     5,960 원 		1 개
# 10 월 512186 이츠웰 롤백(소_2                               			     5,390 원 		2 개
# 10 월 503517 스카치브라이트 양면                               			     4,813 원 		5 개
# 10 월 500556 일회용기세트(1호_                               			     4,772 원 		2 개
# 10 월 514158 이츠웰 주방세제(그                               			     3,116 원 		1 개
# 10 월 159365 유니푸드 양념소금(                               			     2,200 원 		2 개

# %% [markdown]
# ## Group by SKU, MONTH

# %%
sql_cmd = """
select
        sku, pname,
        month,
        '월' as mon,
        sum(total) as gtotal,
        sum(qty) as qty,
        '개' as quantity
from order789Gsheet
group by sku, month
order by sku, month;
"""
cursor = conn.cursor()
cursor.execute(sql_cmd)
tuples = cursor.fetchall()

# %%
i=0
for tuple in tuples:
    glist = []
    #pname = tuple[1].replace("\n","-")
    pname = tuple[1]
    monthstring = tuple[2]+u'월'
    qtystring = str(tuple[5])+u'개' 
    eachmonth = [tuple[0], pname, monthstring, tuple[4], qtystring]
    
    print eachmonth[0], (eachmonth[1][:20]).ljust(30),'\t\t', eachmonth[2], '\t\t',eachmonth[3],'\t\t', eachmonth[4]
    i = i + 1
#    if i > 30:
#        break
# Out:
# 100353 백설 바삭튀김가루(1Kg/EA) 미국           		8월 		2750 		1개
# 100353 백설 바삭튀김가루(1Kg/EA) 미국           		9월 		13750 		5개
# 100743 코카콜라 콜라(캔_355ml 355g           		10월 		51084 		3개
# 100743 코카콜라 콜라(캔_355ml 355g           		7월 		51084 		3개
# 100743 코카콜라 콜라(캔_355ml 355g           		8월 		68112 		4개
# 100743 코카콜라 콜라(캔_355ml 355g           		9월 		34056 		2개
# 100744 스프라이트 사이다(355ml 355g           		10월 		92346 		6개
# 100744 스프라이트 사이다(355ml 355g           		7월 		30782 		2개
# 100744 스프라이트 사이다(355ml 355g           		8월 		76955 		5개
# 100744 스프라이트 사이다(355ml 355g           		9월 		61564 		4개
# 105409 아담스 파마산치즈파우더(1Kg/EA)           		10월 		24200 		2개
# 105409 아담스 파마산치즈파우더(1Kg/EA)           		8월 		12100 		1개
# 111308 천일식품 새우볶음밥(300g/EA)            		10월 		32274 		18개
# 111308 천일식품 새우볶음밥(300g/EA)            		7월 		8965 		5개
# 111308 천일식품 새우볶음밥(300g/EA)            		8월 		17930 		10개
# 112371 칵테일냅킨(생활맥주용 10000장입            		10월 		66000 		2개
# 112371 칵테일냅킨(생활맥주용 10000장입            		8월 		33000 		1개
# 115364 삼진 살사소스(2Kg/EA)                		10월 		79200 		8개
# 115364 삼진 살사소스(2Kg/EA)                		7월 		19800 		2개
# 115364 삼진 살사소스(2Kg/EA)                		8월 		59400 		6개
# 115364 삼진 살사소스(2Kg/EA)                		9월 		19800 		2개
# 115722 사세통상 버팔로윙(1Kg/EA) 태국           		10월 		242550 		21개
# 115722 사세통상 버팔로윙(1Kg/EA) 태국           		7월 		127050 		11개
# 115722 사세통상 버팔로윙(1Kg/EA) 태국           		8월 		127050 		11개
# 115722 사세통상 버팔로윙(1Kg/EA) 태국           		9월 		173250 		15개
# 116709 리코스 나쵸칩(454g/EA) 미국-           		10월 		226490 		71개
# 116709 리코스 나쵸칩(454g/EA) 미국-           		7월 		153120 		48개
# 116709 리코스 나쵸칩(454g/EA) 미국-           		8월 		210540 		66개
# 116709 리코스 나쵸칩(454g/EA) 미국-           		9월 		191400 		60개
# 116981 사세통상 버팔로윙스틱(1Kg/EA)            		10월 		226380 		21개
# 116981 사세통상 버팔로윙스틱(1Kg/EA)            		7월 		118580 		11개
# 116981 사세통상 버팔로윙스틱(1Kg/EA)            		8월 		172480 		16개
# 116981 사세통상 버팔로윙스틱(1Kg/EA)            		9월 		161700 		15개
# 118232 스팸 햄캔(마일드 200g/EA)-※           		10월 		138600 		45개
# 118232 스팸 햄캔(마일드 200g/EA)-※           		7월 		92400 		30개
# 118232 스팸 햄캔(마일드 200g/EA)-※           		8월 		184800 		60개
# 118232 스팸 햄캔(마일드 200g/EA)-※           		9월 		169400 		55개
# 119863 삼조쎌텍 나쵸치즈소스(1Kg/EA)            		10월 		127820 		14개
# 119863 삼조쎌텍 나쵸치즈소스(1Kg/EA)            		8월 		82170 		9개
# 119863 삼조쎌텍 나쵸치즈소스(1Kg/EA)            		9월 		63910 		7개
# 124531 맥앤치즈볼(생활맥주용 50G*4입 2           		10월 		222992 		56개
# 124531 맥앤치즈볼(생활맥주용 50G*4입 2           		7월 		95568 		24개
# 124531 맥앤치즈볼(생활맥주용 50G*4입 2           		8월 		167244 		42개
# 124531 맥앤치즈볼(생활맥주용 50G*4입 2           		9월 		119460 		30개
# 127454 파로 할라페뇨(슬라이스 3Kg/EA)           		10월 		121550 		13개
# 127454 파로 할라페뇨(슬라이스 3Kg/EA)           		7월 		37400 		4개
# 127454 파로 할라페뇨(슬라이스 3Kg/EA)           		8월 		93500 		10개
# 127454 파로 할라페뇨(슬라이스 3Kg/EA)           		9월 		46750 		5개
# 133941 유동 골뱅이캔(자연산 140g/EA)           		8월 		30800 		10개
# 133941 유동 골뱅이캔(자연산 140g/EA)           		9월 		15400 		5개
# 134356 심플로트 냉동감자(메가크런치 2.04           		10월 		777876 		71개
# 134356 심플로트 냉동감자(메가크런치 2.04           		7월 		273900 		25개
# 134356 심플로트 냉동감자(메가크런치 2.04           		8월 		493020 		45개
# 134356 심플로트 냉동감자(메가크런치 2.04           		9월 		438240 		40개
# 135267 그라나파다노치즈(포션 200g/EA)           		10월 		7260 		1개
# 135267 그라나파다노치즈(포션 200g/EA)           		7월 		14520 		2개
# 135267 그라나파다노치즈(포션 200g/EA)           		8월 		21780 		3개
# 138389 이츠웰 초고추장(NEW 1Kg/EA)           		10월 		19800 		6개
# 138389 이츠웰 초고추장(NEW 1Kg/EA)           		7월 		16500 		5개
# 138389 이츠웰 초고추장(NEW 1Kg/EA)           		8월 		23100 		7개
# 138389 이츠웰 초고추장(NEW 1Kg/EA)           		9월 		29700 		9개
# 139476 신영상회 파슬리후레이크(250g/EA           		10월 		5960 		1개
# 139476 신영상회 파슬리후레이크(250g/EA           		7월 		5960 		1개
# 140440 심플로트 냉동감자(크링클컷웨지 2.2           		10월 		514426 		67개
# 140440 심플로트 냉동감자(크링클컷웨지 2.2           		7월 		253374 		33개
# 140440 심플로트 냉동감자(크링클컷웨지 2.2           		8월 		383900 		50개
# 140440 심플로트 냉동감자(크링클컷웨지 2.2           		9월 		399256 		52개
# 143790 이츠웰 참기름(NEW_캔_1L 916           		9월 		11660 		1개
# 144398 심플로트 냉동감자(세이보리_스트레이트           		10월 		474628 		46개
# 144398 심플로트 냉동감자(세이보리_스트레이트           		7월 		340494 		33개
# 144398 심플로트 냉동감자(세이보리_스트레이트           		8월 		340494 		33개
# 144398 심플로트 냉동감자(세이보리_스트레이트           		9월 		443674 		43개
# 145970 치킨무(외식체인전용 5Kg/EA) 한           		10월 		119700 		21개
# 145970 치킨무(외식체인전용 5Kg/EA) 한           		7월 		51300 		9개
# 145970 치킨무(외식체인전용 5Kg/EA) 한           		8월 		102600 		18개
# 145970 치킨무(외식체인전용 5Kg/EA) 한           		9월 		74100 		13개
# 146239 쉐프솔루션 김치볶음밥(300g/EA)           		10월 		84700 		55개
# 146239 쉐프솔루션 김치볶음밥(300g/EA)           		7월 		12320 		8개
# 146239 쉐프솔루션 김치볶음밥(300g/EA)           		8월 		69300 		45개
# 146239 쉐프솔루션 김치볶음밥(300g/EA)           		9월 		100100 		65개
# 146391 쉐프솔루션 햄야채볶음밥(300g/EA           		10월 		30703 		19개
# 146391 쉐프솔루션 햄야채볶음밥(300g/EA           		7월 		12928 		8개
# 146391 쉐프솔루션 햄야채볶음밥(300g/EA           		8월 		48479 		30개
# 146391 쉐프솔루션 햄야채볶음밥(300g/EA           		9월 		56558 		35개
# 146393 쉐프솔루션 해물볶음밥(300g/EA)           		10월 		12840 		8개
# 146393 쉐프솔루션 해물볶음밥(300g/EA)           		7월 		8025 		5개
# 146393 쉐프솔루션 해물볶음밥(300g/EA)           		8월 		24074 		15개
# 146393 쉐프솔루션 해물볶음밥(300g/EA)           		9월 		44939 		28개
# 154639 오뚜기 마요네즈(골드 스파우트팩 3.           		10월 		10780 		1개
# 154639 오뚜기 마요네즈(골드 스파우트팩 3.           		7월 		21560 		2개
# 154639 오뚜기 마요네즈(골드 스파우트팩 3.           		8월 		21560 		2개
# 159365 유니푸드 양념소금(마파치킨용 3.5g           		10월 		2200 		2개
# 159365 유니푸드 양념소금(마파치킨용 3.5g           		7월 		1100 		1개
# 159365 유니푸드 양념소금(마파치킨용 3.5g           		9월 		1100 		1개
# 160016 오뚜기 케찹(스파우트팩 3.3Kg/E           		10월 		43450 		10개
# 160016 오뚜기 케찹(스파우트팩 3.3Kg/E           		7월 		8690 		2개
# 160016 오뚜기 케찹(스파우트팩 3.3Kg/E           		8월 		43450 		10개
# 160016 오뚜기 케찹(스파우트팩 3.3Kg/E           		9월 		34760 		8개
# 163815 이츠웰 골뱅이캔(자연산 140g/EA           		10월 		271040 		88개
# 163815 이츠웰 골뱅이캔(자연산 140g/EA           		7월 		197120 		64개
# 163815 이츠웰 골뱅이캔(자연산 140g/EA           		8월 		323400 		105개
# 163815 이츠웰 골뱅이캔(자연산 140g/EA           		9월 		231000 		75개
# 166412 뫼루니식품 물결무늬파우더(데일리비어용           		10월 		115720 		8개
# 166412 뫼루니식품 물결무늬파우더(데일리비어용           		7월 		86790 		6개
# 166412 뫼루니식품 물결무늬파우더(데일리비어용           		8월 		101255 		7개
# 166412 뫼루니식품 물결무늬파우더(데일리비어용           		9월 		86790 		6개
# 166413 뫼루니 양념치킨소스(데일리비어용 양념           		10월 		22770 		3개
# 166413 뫼루니 양념치킨소스(데일리비어용 양념           		7월 		60720 		8개
# 166413 뫼루니 양념치킨소스(데일리비어용 양념           		8월 		106260 		14개
# 169394 샐러드믹스(생활맥주용 150g*5입            		10월 		288000 		20개
# 169394 샐러드믹스(생활맥주용 150g*5입            		7월 		201600 		14개
# 169394 샐러드믹스(생활맥주용 150g*5입            		8월 		288000 		20개
# 169394 샐러드믹스(생활맥주용 150g*5입            		9월 		187200 		13개
# 171838 팔도 비빔면(130g/EA) 40EA           		10월 		58960 		2개
# 171838 팔도 비빔면(130g/EA) 40EA           		7월 		58960 		2개
# 171838 팔도 비빔면(130g/EA) 40EA           		8월 		58960 		2개
# 171838 팔도 비빔면(130g/EA) 40EA           		9월 		88440 		3개
# 176689 소시지(생활맥주용 천연돈장_70g*4           		10월 		432630 		90개
# 176689 소시지(생활맥주용 천연돈장_70g*4           		7월 		96140 		20개
# 176689 소시지(생활맥주용 천연돈장_70g*4           		8월 		490314 		102개
# 176689 소시지(생활맥주용 천연돈장_70g*4           		9월 		394174 		82개
# 177050 기름여과지(생활맥주용 100매 BOX           		10월 		80300 		1개
# 177058 미니고무장갑(생활맥주용 10입 EA)           		7월 		8250 		1개
# 177058 미니고무장갑(생활맥주용 10입 EA)           		8월 		16500 		2개
# 177058 미니고무장갑(생활맥주용 10입 EA)           		9월 		8250 		1개
# 178733 물티슈(생활맥주용 500입 BOX)            		10월 		24200 		2개
# 178733 물티슈(생활맥주용 500입 BOX)            		9월 		12100 		1개
# 178883 코스터(생활맥주용 600매 EA)             		10월 		62700 		1개
# 178883 코스터(생활맥주용 600매 EA)             		9월 		62700 		1개
# 201934 소고기육포(생활맥주용 70g/EA)            		10월 		262020 		60개
# 201934 소고기육포(생활맥주용 70g/EA)            		7월 		262020 		60개
# 201934 소고기육포(생활맥주용 70g/EA)            		8월 		240185 		55개
# 201934 소고기육포(생활맥주용 70g/EA)            		9월 		152845 		35개
# 206578 길림양행 땅콩(껍질무_1/2태 1Kg           		10월 		177100 		23개
# 206578 길림양행 땅콩(껍질무_1/2태 1Kg           		7월 		77000 		10개
# 206578 길림양행 땅콩(껍질무_1/2태 1Kg           		8월 		115500 		15개
# 206578 길림양행 땅콩(껍질무_1/2태 1Kg           		9월 		100100 		13개
# 215139 케이준드레싱(생활맥주용 2Kg/EA)           		10월 		29865 		3개
# 215139 케이준드레싱(생활맥주용 2Kg/EA)           		8월 		39820 		4개
# 215139 케이준드레싱(생활맥주용 2Kg/EA)           		9월 		9955 		1개
# 215140 양파드레싱(생활맥주용 2Kg/EA)            		10월 		198000 		20개
# 215140 양파드레싱(생활맥주용 2Kg/EA)            		7월 		79200 		8개
# 215140 양파드레싱(생활맥주용 2Kg/EA)            		8월 		158400 		16개
# 215140 양파드레싱(생활맥주용 2Kg/EA)            		9월 		138600 		14개
# 232931 반건오징어(생활맥주용 10미 1.3K           		10월 		442500 		15개
# 232931 반건오징어(생활맥주용 10미 1.3K           		7월 		88500 		3개
# 232931 반건오징어(생활맥주용 10미 1.3K           		8월 		590000 		20개
# 232931 반건오징어(생활맥주용 10미 1.3K           		9월 		383500 		13개
# 242910 웰넛 건포도(500g/EA) 미국-※           		10월 		40480 		16개
# 242910 웰넛 건포도(500g/EA) 미국-※           		7월 		25300 		10개
# 242910 웰넛 건포도(500g/EA) 미국-※           		8월 		25300 		10개
# 242910 웰넛 건포도(500g/EA) 미국-※           		9월 		30360 		12개
# 247491 뫼루니식품 레드소스(데일리비어용 양념           		10월 		227700 		30개
# 247491 뫼루니식품 레드소스(데일리비어용 양념           		8월 		15180 		2개
# 247491 뫼루니식품 레드소스(데일리비어용 양념           		9월 		121440 		16개
# 401354 계란(특란_60g*30입 1.8Kg/           		10월 		56937 		7개
# 401354 계란(특란_60g*30입 1.8Kg/           		7월 		38144 		4개
# 401354 계란(특란_60g*30입 1.8Kg/           		8월 		90590 		10개
# 401354 계란(특란_60g*30입 1.8Kg/           		9월 		72030 		10개
# 424782 염지닭(생활맥주용 9호_9각 850g           		10월 		1851630 		31개
# 424782 염지닭(생활맥주용 9호_9각 850g           		7월 		836220 		14개
# 424782 염지닭(생활맥주용 9호_9각 850g           		8월 		1552980 		26개
# 424782 염지닭(생활맥주용 9호_9각 850g           		9월 		1254330 		21개
# 424783 염지닭안심(생활맥주용 1Kg/EA)            		10월 		592020 		13개
# 424783 염지닭안심(생활맥주용 1Kg/EA)            		7월 		409860 		9개
# 424783 염지닭안심(생활맥주용 1Kg/EA)            		8월 		364320 		8개
# 424783 염지닭안심(생활맥주용 1Kg/EA)            		9월 		455400 		10개
# 500556 일회용기세트(1호_70*30mm_10           		10월 		4772 		2개
# 500556 일회용기세트(1호_70*30mm_10           		8월 		2386 		1개
# 500556 일회용기세트(1호_70*30mm_10           		9월 		7158 		3개
# 501191 하이코리아 락스(2L EA)                		7월 		12316 		12개
# 501326 스파크 세탁세제(5kg EA)               		8월 		12617 		1개
# 501326 스파크 세탁세제(5kg EA)               		9월 		12617 		1개
# 501386 트레펑(1L 막힌하수구용 EA)              		10월 		24365 		10개
# 501386 트레펑(1L 막힌하수구용 EA)              		8월 		48730 		20개
# 501386 트레펑(1L 막힌하수구용 EA)              		9월 		48730 		20개
# 503517 스카치브라이트 양면스폰지수세미(EA)           		10월 		4813 		5개
# 512186 이츠웰 롤백(소_25*35cm_500           		10월 		5390 		2개
# 512186 이츠웰 롤백(소_25*35cm_500           		8월 		8085 		3개
# 512188 이츠웰 롤백(중_30*40cm_500           		10월 		7700 		2개
# 512237 이츠웰 페이퍼타올(핸드타올_4500매           		9월 		21450 		1개
# 514151 이츠웰 다용도봉투(파란색_30L_48           		7월 		9900 		3개
# 514158 이츠웰 주방세제(그린알로_3kg EA           		10월 		3116 		1개
# 514158 이츠웰 주방세제(그린알로_3kg EA           		9월 		6232 		2개
# 514663 지원 일회용기뚜껑(W-3_75mm_1           		8월 		2024 		1개
# 514663 지원 일회용기뚜껑(W-3_75mm_1           		9월 		4048 		2개
# 514664 지원 일회용기(W-3_75*65mm_           		9월 		13726 		2개
# 526116 유산지(생활맥주용 1000개 EA)            		10월 		66000 		2개
# 526116 유산지(생활맥주용 1000개 EA)            		8월 		33000 		1개
# 526116 유산지(생활맥주용 1000개 EA)            		9월 		66000 		2개
# 526117 비닐백(생활맥주용 100매 EA)             		10월 		39600 		4개

# %%
print tuple[1]
def unicode_truncate(s, length, encoding='utf-8'):
    encoded = s.encode(encoding)[:length]
    return encoded.decode(encoding, 'ignore')
print unicode_truncate(tuple[1], 60)
# Out:
# 백설 바삭튀김가루(1Kg/EA) 미국
# ※미국산
# 백설 바삭튀김가루(1Kg/EA) 미국
# ※미국산
