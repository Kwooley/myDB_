# %% [markdown]
# # Make SQL Insert Statement

# %% [markdown]
# ## from Excel file to SQL statements

# %%
from openpyxl import Workbook
from openpyxl.compat import range
from openpyxl.utils import get_column_letter
from openpyxl import load_workbook
from openpyxl import Workbook

# %%
print ord('T') - ord('A')
print ord('V') - ord('A')
print ord('P') - ord('A')
# Out:
# 19
# 21
# 15

# %% [markdown]
# ### Function splitdate
# ##### split 2017-10-31 string into 2017, 10, 31

# %%
def splitdate(orderdatestring):
    ody,odm, odd = orderdatestring.split('-')
    return({'year':ody, 'month':odm, 'day':odd})

# %% [markdown]
# ### Find Order row and make Insert stmt

# %%
wb = load_workbook(filename = './XLSX/2018JUNE.xlsx')
ws = wb.active

num_rows = ws.max_row
#num_rows = 70
print num_rows

f = open("./SQL/2018JUNE.sql", 'w')


prev_val = None
stmt_flag = date_found = False
order_cnt = total_order_cnt = 0
lcv = 0 
for row in ws.iter_rows(min_row=1, max_col=24, max_row=num_rows):
    sql_stmt = None
    sql_stmt_u = None
            
    # Find the row that contains the YMD
    # print unicode(row[0].value)[:6]
    if (unicode(row[0].value)[:6] == u'차량번호 :'):
        date_found = True
        YMD_string_org = unicode(row[15].value)
        YMD_string = YMD_string_org[7:]
        odate_dic = splitdate(YMD_string)
        print odate_dic
        
    # Find the 1st Row 
    if (row[0].value == 1) and ( prev_val == 'No.'):
        stmt_flag = True
    if (stmt_flag) and (date_found):
        # Find the Last Row
        if (unicode(prev_val).isdigit() == True ) and (unicode(row[0].value).isdigit() == False):
            stmt_flag = False
            date_found = False
            total_order_cnt += order_cnt
            print 'Order count', order_cnt, 'Total Order Count', total_order_cnt
            order_cnt = 0
        else:
            order_cnt += 1
            # 0 : iD / 1: OrderNO / 2: SKU / 5: pname / 14: metric / 16:qty / 18:price / 19:amount / 21:tax / 23:total
            tuple_dict = {'year':odate_dic['year'],
                          'month':odate_dic['month'],
                          'day':odate_dic['day'],
                          'YMD':YMD_string,
                          'dno':row[0].value,
                          'orderno':row[1].value,
                          'sku':row[2].value,
                          'pname':unicode(row[5].value).replace('\n','-'),
                          'metric':row[14].value, 
                          'qty':row[16].value,
                          'price':row[18].value,
                          'amount':row[19].value,
                          'tax':row[21].value,
                          'total':row[23].value
                         }
            
            sql_stmt = u'Insert into OrderAll values '
            sql_stmt += '('
            sql_stmt += str(tuple_dict['year'])+','
            sql_stmt += str(tuple_dict['month'])+','
            sql_stmt += str(tuple_dict['day'])+','
            sql_stmt += '\'' + tuple_dict['YMD'] + '\','
            sql_stmt += str(tuple_dict['dno'])+','
            sql_stmt += str(tuple_dict['orderno'])+','
            sql_stmt += str(tuple_dict['sku'])+','
            sql_stmt += '\'' + tuple_dict['pname'] + '\','
            sql_stmt += '\'' + tuple_dict['metric'] + '\','
            sql_stmt += str(tuple_dict['qty'])+','
            sql_stmt += str(tuple_dict['price'])+','
            sql_stmt += str(tuple_dict['amount'])+','
            sql_stmt += str(tuple_dict['tax'])+','
            sql_stmt += str(tuple_dict['total'])
            sql_stmt += ');\n'

            print sql_stmt
            #print ''
            # f.write(sql_stmt_r.replace(u'\ufeff','').encode("utf-16"))
            
            f.write(sql_stmt.encode('utf-8'))
            
                
    prev_val = row[0].value
    lcv += 1
    
    if lcv > num_rows:
        break


f.close()
# Out:
# 583
# {'month': u'06', 'day': u'01', 'year': u'2018'}
# Insert into OrderAll values (2018,06,01,'2018-06-01',1,2123716893,251902,'냉동감자(생활맥주용 클리어코트슈스트링 2.04Kg/EA)','EA',6,8960,53760,5376,59136);
#
# Insert into OrderAll values (2018,06,01,'2018-06-01',2,2123716893,251901,'냉동감자(생활맥주용 스파이시스트레이트컷 2.04Kg/EA)','EA',4,8960,35840,3584,39424);
#
# Insert into OrderAll values (2018,06,01,'2018-06-01',3,2123716893,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',6,6980,41880,4188,46068);
#
# Insert into OrderAll values (2018,06,01,'2018-06-01',4,2123716893,176689,'소시지(생활맥주용 천연돈장_70g*4입 280g/EA) 한국-※돼지고기(국내산)','EA',10,4370,43700,4370,48070);
#
# Insert into OrderAll values (2018,06,01,'2018-06-01',5,2123716893,124531,'맥앤치즈볼(생활맥주용 50G*4입 200g/EA)','EA',6,3620,21720,2172,23892);
#
# Insert into OrderAll values (2018,06,01,'2018-06-01',6,2123716954,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',2,54300,108600,10860,119460);
#
# Insert into OrderAll values (2018,06,01,'2018-06-01',7,2123716954,169394,'샐러드믹스(생활맥주용 150g*5입 750g/BOX) 한국 1EA/BOX-※국내산','BOX',2,14400,28800,0,28800);
#
# Insert into OrderAll values (2018,06,01,'2018-06-01',8,2123716893,145970,'치킨무(외식체인전용 5Kg/EA) 한국-※국내산','EA',2,5700,11400,0,11400);
#
# Insert into OrderAll values (2018,06,01,'2018-06-01',9,2123716893,201934,'소고기육포(생활맥주용 70g/EA) 호주-※호주산','EA',10,3970,39700,3970,43670);
#
# Insert into OrderAll values (2018,06,01,'2018-06-01',10,2123716893,115722,'사세통상 버팔로윙(1Kg/EA) 태국-※닭고기(태국산)','EA',2,10500,21000,2100,23100);
#
# Insert into OrderAll values (2018,06,01,'2018-06-01',11,2123716893,116981,'사세통상 버팔로윙스틱(1Kg/EA) 태국-※닭고기(태국산)','EA',2,9800,19600,1960,21560);
#
# Insert into OrderAll values (2018,06,01,'2018-06-01',12,2123716893,133941,'유동 골뱅이캔(자연산 140g/EA)','EA',12,2800,33600,3360,36960);
#
# Insert into OrderAll values (2018,06,01,'2018-06-01',13,2123716893,177058,'미니고무장갑(생활맥주용 10입 EA)','EA',1,7500,7500,750,8250);
#
# Order count 13 Total Order Count 13
# {'month': u'06', 'day': u'02', 'year': u'2018'}
# Insert into OrderAll values (2018,06,02,'2018-06-02',1,2123761049,424783,'염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX','BOX',1,41400,41400,4140,45540);
#
# Insert into OrderAll values (2018,06,02,'2018-06-02',2,2123762463,232931,'반건오징어(생활맥주용 10미 1.3Kg/EA) 한국-※국내산','EA',2,32000,64000,0,64000);
#
# Order count 2 Total Order Count 15
# {'month': u'06', 'day': u'04', 'year': u'2018'}
# Insert into OrderAll values (2018,06,04,'2018-06-04',1,2123812088,166412,'뫼루니식품 물결무늬파우더(데일리비어용 매운맛 5Kg/EA) 미국-※미국산','EA',2,13150,26300,2630,28930);
#
# Insert into OrderAll values (2018,06,04,'2018-06-04',2,2123812088,176689,'소시지(생활맥주용 천연돈장_70g*4입 280g/EA) 한국-※돼지고기(국내산)','EA',10,4370,43700,4370,48070);
#
# Insert into OrderAll values (2018,06,04,'2018-06-04',3,2123812088,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',6,6980,41880,4188,46068);
#
# Insert into OrderAll values (2018,06,04,'2018-06-04',4,2123812088,251901,'냉동감자(생활맥주용 스파이시스트레이트컷 2.04Kg/EA)','EA',3,8960,26880,2688,29568);
#
# Insert into OrderAll values (2018,06,04,'2018-06-04',5,2123812088,251902,'냉동감자(생활맥주용 클리어코트슈스트링 2.04Kg/EA)','EA',4,8960,35840,3584,39424);
#
# Insert into OrderAll values (2018,06,04,'2018-06-04',6,2123812088,116709,'리코스 나쵸칩(454g/EA) 미국-※미국','EA',6,2900,17400,1740,19140);
#
# Insert into OrderAll values (2018,06,04,'2018-06-04',7,2123812091,135267,'그라나파다노치즈(포션 200g/EA)','EA',1,6600,6600,660,7260);
#
# Insert into OrderAll values (2018,06,04,'2018-06-04',8,2123812088,145970,'치킨무(외식체인전용 5Kg/EA) 한국-※국내산','EA',3,5700,17100,0,17100);
#
# Insert into OrderAll values (2018,06,04,'2018-06-04',9,2123812091,105409,'아담스 파마산치즈파우더(1Kg/EA)','EA',1,11000,11000,1100,12100);
#
# Insert into OrderAll values (2018,06,04,'2018-06-04',10,2123812088,206578,'길림양행 땅콩(껍질무_1/2태 1Kg/PAC)-※이력번호:10931-18-040229M','PAC',3,7000,21000,2100,23100);
#
# Insert into OrderAll values (2018,06,04,'2018-06-04',11,2123812091,242910,'웰넛 건포도(500g/EA) 미국-※미국산','EA',3,3130,9390,939,10329);
#
# Order count 11 Total Order Count 26
# {'month': u'06', 'day': u'05', 'year': u'2018'}
# Insert into OrderAll values (2018,06,05,'2018-06-05',1,2123812085,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',3,54300,162900,16290,179190);
#
# Insert into OrderAll values (2018,06,05,'2018-06-05',2,2123812085,424783,'염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX','BOX',1,41400,41400,4140,45540);
#
# Insert into OrderAll values (2018,06,05,'2018-06-05',3,2123824303,100743,'코카콜라 콜라(캔_355ml 355g/EA) 24EA/BOX','BOX',1,17040,17040,1704,18744);
#
# Insert into OrderAll values (2018,06,05,'2018-06-05',4,2123824303,100744,'스프라이트 사이다(355ml 355g/EA) 24EA/BOX','BOX',1,13992,13992,1399,15391);
#
# Order count 4 Total Order Count 30
# {'month': u'06', 'day': u'07', 'year': u'2018'}
# Insert into OrderAll values (2018,06,07,'2018-06-07',1,2123892713,133941,'유동 골뱅이캔(자연산 140g/EA)','EA',12,2800,33600,3360,36960);
#
# Insert into OrderAll values (2018,06,07,'2018-06-07',2,2123892713,247491,'뫼루니식품 레드소스(데일리비어용 양념치킨용 2Kg/EA)','EA',3,6900,20700,2070,22770);
#
# Insert into OrderAll values (2018,06,07,'2018-06-07',3,2123893685,401354,'계란(특란_60g*30입 1.8Kg/PAC) 한국-※달걀(국내산)','PAC',2,6506,13012,0,13012);
#
# Insert into OrderAll values (2018,06,07,'2018-06-07',4,2123892713,176689,'소시지(생활맥주용 천연돈장_70g*4입 280g/EA) 한국-※돼지고기(국내산)','EA',15,4370,65550,6555,72105);
#
# Insert into OrderAll values (2018,06,07,'2018-06-07',5,2123892713,232931,'반건오징어(생활맥주용 10미 1.3Kg/EA) 한국-※국내산','EA',2,32000,64000,0,64000);
#
# Insert into OrderAll values (2018,06,07,'2018-06-07',6,2123892713,160016,'오뚜기 케찹(스파우트팩 3.3Kg/EA)','EA',2,3950,7900,790,8690);
#
# Insert into OrderAll values (2018,06,07,'2018-06-07',7,2123892713,178733,'물티슈(생활맥주용 500입 BOX) 1EA/BOX','BOX',2,11000,22000,2200,24200);
#
# Insert into OrderAll values (2018,06,07,'2018-06-07',8,2123892713,118232,'스팸 햄캔(마일드 200g/EA)-※돼지고기(수입산 80%+국내산 20%) 96.27%','EA',10,2800,28000,2800,30800);
#
# Insert into OrderAll values (2018,06,07,'2018-06-07',9,2123893685,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',2,54300,108600,10860,119460);
#
# Insert into OrderAll values (2018,06,07,'2018-06-07',10,2123893685,424783,'염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX','BOX',1,41400,41400,4140,45540);
#
# Insert into OrderAll values (2018,06,07,'2018-06-07',11,2123892713,138389,'이츠웰 초고추장(NEW 1Kg/EA)','EA',2,3000,6000,600,6600);
#
# Insert into OrderAll values (2018,06,07,'2018-06-07',12,2123893685,169394,'샐러드믹스(생활맥주용 150g*5입 750g/BOX) 한국 1EA/BOX-※국내산','BOX',1,14400,14400,0,14400);
#
# Insert into OrderAll values (2018,06,07,'2018-06-07',13,2123893685,119863,'삼조쎌텍 나쵸치즈소스(1Kg/EA)','EA',2,8300,16600,1660,18260);
#
# Insert into OrderAll values (2018,06,07,'2018-06-07',14,2123893685,115364,'삼진 살사소스(2Kg/EA)','EA',2,9000,18000,1800,19800);
#
# Insert into OrderAll values (2018,06,07,'2018-06-07',15,2123892713,201934,'소고기육포(생활맥주용 70g/EA) 호주-※호주산','EA',15,3970,59550,5955,65505);
#
# Insert into OrderAll values (2018,06,07,'2018-06-07',16,2123907505,159365,'유니푸드 양념소금(마파치킨용 3.5g*90입 315g/EA) 한국-※정제염(국내산)','EA',1,1000,1000,100,1100);
#
# Order count 16 Total Order Count 46
# {'month': u'06', 'day': u'08', 'year': u'2018'}
# Insert into OrderAll values (2018,06,08,'2018-06-08',1,2123907547,251902,'냉동감자(생활맥주용 클리어코트슈스트링 2.04Kg/EA)','EA',4,8960,35840,3584,39424);
#
# Insert into OrderAll values (2018,06,08,'2018-06-08',2,2123907547,251901,'냉동감자(생활맥주용 스파이시스트레이트컷 2.04Kg/EA)','EA',2,8960,17920,1792,19712);
#
# Insert into OrderAll values (2018,06,08,'2018-06-08',3,2123908795,112371,'칵테일냅킨(생활맥주용 10000장입 BOX) 1EA/BOX','BOX',1,30000,30000,3000,33000);
#
# Insert into OrderAll values (2018,06,08,'2018-06-08',4,2123907547,145970,'치킨무(외식체인전용 5Kg/EA) 한국-※국내산','EA',2,5700,11400,0,11400);
#
# Order count 4 Total Order Count 50
# {'month': u'06', 'day': u'09', 'year': u'2018'}
# Insert into OrderAll values (2018,06,09,'2018-06-09',1,2123954658,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',2,54300,108600,10860,119460);
#
# Insert into OrderAll values (2018,06,09,'2018-06-09',2,2123954659,232931,'반건오징어(생활맥주용 10미 1.3Kg/EA) 한국-※국내산','EA',2,32000,64000,0,64000);
#
# Insert into OrderAll values (2018,06,09,'2018-06-09',3,2123954659,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',4,6980,27920,2792,30712);
#
# Order count 3 Total Order Count 53
# {'month': u'06', 'day': u'11', 'year': u'2018'}
# Insert into OrderAll values (2018,06,11,'2018-06-11',1,2124001460,116709,'리코스 나쵸칩(454g/EA) 미국-※미국','EA',10,2900,29000,2900,31900);
#
# Insert into OrderAll values (2018,06,11,'2018-06-11',2,2124001460,201934,'소고기육포(생활맥주용 70g/EA) 호주-※호주산','EA',15,3970,59550,5955,65505);
#
# Insert into OrderAll values (2018,06,11,'2018-06-11',3,2124001460,206578,'길림양행 땅콩(껍질무_1/2태 1Kg/PAC)-※이력번호:10931-18-040229M','PAC',6,7000,42000,4200,46200);
#
# Insert into OrderAll values (2018,06,11,'2018-06-11',4,2124001484,242910,'웰넛 건포도(500g/EA) 미국-※미국산','EA',4,3130,12520,1252,13772);
#
# Insert into OrderAll values (2018,06,11,'2018-06-11',5,2124001460,115722,'사세통상 버팔로윙(1Kg/EA) 태국-※닭고기(태국산)','EA',3,10500,31500,3150,34650);
#
# Insert into OrderAll values (2018,06,11,'2018-06-11',6,2124001460,116981,'사세통상 버팔로윙스틱(1Kg/EA) 태국-※닭고기(태국산)','EA',3,9800,29400,2940,32340);
#
# Insert into OrderAll values (2018,06,11,'2018-06-11',7,2124001460,215140,'양파드레싱(생활맥주용 2Kg/EA)','EA',4,9000,36000,3600,39600);
#
# Insert into OrderAll values (2018,06,11,'2018-06-11',8,2124001460,247491,'뫼루니식품 레드소스(데일리비어용 양념치킨용 2Kg/EA)','EA',3,6900,20700,2070,22770);
#
# Insert into OrderAll values (2018,06,11,'2018-06-11',9,2124001460,133941,'유동 골뱅이캔(자연산 140g/EA)','EA',7,2800,19600,1960,21560);
#
# Insert into OrderAll values (2018,06,11,'2018-06-11',10,2124001484,215139,'케이준드레싱(생활맥주용 2Kg/EA)','EA',1,9050,9050,905,9955);
#
# Insert into OrderAll values (2018,06,11,'2018-06-11',11,2124001460,118227,'오뚜기 마요네즈(파우치 3Kg/EA)','EA',1,11146,11146,1115,12261);
#
# Insert into OrderAll values (2018,06,11,'2018-06-11',12,2124001460,166412,'뫼루니식품 물결무늬파우더(데일리비어용 매운맛 5Kg/EA) 미국-※미국산','EA',2,13150,26300,2630,28930);
#
# Insert into OrderAll values (2018,06,11,'2018-06-11',13,2124001484,127454,'파로 할라페뇨(슬라이스 3Kg/EA)','EA',2,8500,17000,1700,18700);
#
# Insert into OrderAll values (2018,06,11,'2018-06-11',14,2124001460,176689,'소시지(생활맥주용 천연돈장_70g*4입 280g/EA) 한국-※돼지고기(국내산)','EA',7,4370,30590,3059,33649);
#
# Insert into OrderAll values (2018,06,11,'2018-06-11',15,2124046038,215140,'양파드레싱(생활맥주용 2Kg/EA)-※당일 오입고건 고객 사용양해','EA',1,9000,9000,900,9900);
#
# Order count 15 Total Order Count 68
# {'month': u'06', 'day': u'12', 'year': u'2018'}
# Insert into OrderAll values (2018,06,12,'2018-06-12',1,2124015963,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',2,54300,108600,10860,119460);
#
# Insert into OrderAll values (2018,06,12,'2018-06-12',2,2124015963,424783,'염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX','BOX',2,41400,82800,8280,91080);
#
# Insert into OrderAll values (2018,06,12,'2018-06-12',3,2124015963,169394,'샐러드믹스(생활맥주용 150g*5입 750g/BOX) 한국 1EA/BOX-※국내산','BOX',2,14400,28800,0,28800);
#
# Insert into OrderAll values (2018,06,12,'2018-06-12',4,2124015963,522877,'소스뚜껑(70파이*3cm_100입 EA)','EA',1,1210,1210,121,1331);
#
# Insert into OrderAll values (2018,06,12,'2018-06-12',5,2124015963,522878,'소스용기(70파이*3cm_100입 EA)','EA',1,1560,1560,156,1716);
#
# Insert into OrderAll values (2018,06,12,'2018-06-12',6,2124045954,215139,'케이준드레싱(생활맥주용 2Kg/EA)-※★6/11 오입고 반품 재주문 > 케이준드레싱으로 확인후 납품요청','EA',1,9050,9050,905,9955);
#
# Insert into OrderAll values (2018,06,12,'2018-06-12',7,2124047631,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',4,6980,27920,2792,30712);
#
# Insert into OrderAll values (2018,06,12,'2018-06-12',8,2124047631,251902,'냉동감자(생활맥주용 클리어코트슈스트링 2.04Kg/EA)','EA',6,8960,53760,5376,59136);
#
# Order count 8 Total Order Count 76
# {'month': u'06', 'day': u'15', 'year': u'2018'}
# Insert into OrderAll values (2018,06,15,'2018-06-15',1,2124102919,145970,'치킨무(외식체인전용 5Kg/EA) 한국-※국내산','EA',3,5700,17100,0,17100);
#
# Insert into OrderAll values (2018,06,15,'2018-06-15',2,2124103105,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',3,54300,162900,16290,179190);
#
# Insert into OrderAll values (2018,06,15,'2018-06-15',3,2124102919,116709,'리코스 나쵸칩(454g/EA) 미국-※미국','EA',10,2900,29000,2900,31900);
#
# Insert into OrderAll values (2018,06,15,'2018-06-15',4,2124102919,247491,'뫼루니식품 레드소스(데일리비어용 양념치킨용 2Kg/EA)','EA',3,6900,20700,2070,22770);
#
# Insert into OrderAll values (2018,06,15,'2018-06-15',5,2124102919,251902,'냉동감자(생활맥주용 클리어코트슈스트링 2.04Kg/EA)','EA',6,8960,53760,5376,59136);
#
# Insert into OrderAll values (2018,06,15,'2018-06-15',6,2124102919,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',4,6980,27920,2792,30712);
#
# Insert into OrderAll values (2018,06,15,'2018-06-15',7,2124102919,251901,'냉동감자(생활맥주용 스파이시스트레이트컷 2.04Kg/EA)','EA',2,8960,17920,1792,19712);
#
# Insert into OrderAll values (2018,06,15,'2018-06-15',8,2124102919,118232,'스팸 햄캔(마일드 200g/EA)-※돼지고기(수입산 80%+국내산 20%) 96.27%','EA',8,2800,22400,2240,24640);
#
# Insert into OrderAll values (2018,06,15,'2018-06-15',9,2124102919,252265,'이츠웰 주방세제(리뉴얼_그린알로_3kg EA)','EA',2,2833,5666,567,6233);
#
# Insert into OrderAll values (2018,06,15,'2018-06-15',10,2124102919,100744,'스프라이트 사이다(355ml 355g/EA) 24EA/BOX','BOX',1,13992,13992,1399,15391);
#
# Insert into OrderAll values (2018,06,15,'2018-06-15',11,2124102919,176689,'소시지(생활맥주용 천연돈장_70g*4입 280g/EA) 한국-※돼지고기(국내산)','EA',8,4370,34960,3496,38456);
#
# Insert into OrderAll values (2018,06,15,'2018-06-15',12,2124102919,166412,'뫼루니식품 물결무늬파우더(데일리비어용 매운맛 5Kg/EA) 미국-※미국산','EA',2,13150,26300,2630,28930);
#
# Order count 12 Total Order Count 88
# {'month': u'06', 'day': u'16', 'year': u'2018'}
# Insert into OrderAll values (2018,06,16,'2018-06-16',1,2124189763,133941,'유동 골뱅이캔(자연산 140g/EA)','EA',10,2800,28000,2800,30800);
#
# Insert into OrderAll values (2018,06,16,'2018-06-16',2,2124189763,232931,'반건오징어(생활맥주용 10미 1.3Kg/EA) 한국-※국내산','EA',2,32000,64000,0,64000);
#
# Insert into OrderAll values (2018,06,16,'2018-06-16',3,2124189763,124531,'맥앤치즈볼(생활맥주용 50G*4입 200g/EA)','EA',6,3620,21720,2172,23892);
#
# Order count 3 Total Order Count 91
# {'month': u'06', 'day': u'18', 'year': u'2018'}
# Insert into OrderAll values (2018,06,18,'2018-06-18',1,2124199639,401354,'계란(특란_60g*30입 1.8Kg/PAC) 한국-※달걀(국내산)','PAC',2,6506,13012,0,13012);
#
# Insert into OrderAll values (2018,06,18,'2018-06-18',2,2124199641,171838,'팔도 비빔면(130g/EA) 40EA/BOX','BOX',1,26800,26800,2680,29480);
#
# Insert into OrderAll values (2018,06,18,'2018-06-18',3,2124199641,206578,'길림양행 땅콩(껍질무_1/2태 1Kg/PAC)-※이력번호:10931-18-050103M','PAC',4,7000,28000,2800,30800);
#
# Insert into OrderAll values (2018,06,18,'2018-06-18',4,2124199639,242910,'웰넛 건포도(500g/EA) 미국-※미국산','EA',4,3130,12520,1252,13772);
#
# Insert into OrderAll values (2018,06,18,'2018-06-18',5,2124199641,251902,'냉동감자(생활맥주용 클리어코트슈스트링 2.04Kg/EA)','EA',4,8960,35840,3584,39424);
#
# Insert into OrderAll values (2018,06,18,'2018-06-18',6,2124199641,251901,'냉동감자(생활맥주용 스파이시스트레이트컷 2.04Kg/EA)','EA',2,8960,17920,1792,19712);
#
# Insert into OrderAll values (2018,06,18,'2018-06-18',7,2124199641,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',3,6980,20940,2094,23034);
#
# Order count 7 Total Order Count 98
# {'month': u'06', 'day': u'19', 'year': u'2018'}
# Insert into OrderAll values (2018,06,19,'2018-06-19',1,2124199638,424783,'염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX','BOX',1,41400,41400,4140,45540);
#
# Order count 1 Total Order Count 99
# {'month': u'06', 'day': u'20', 'year': u'2018'}
# Insert into OrderAll values (2018,06,20,'2018-06-20',1,2124243246,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',2,54300,108600,10860,119460);
#
# Insert into OrderAll values (2018,06,20,'2018-06-20',2,2124243267,100743,'코카콜라 콜라(캔_355ml 355g/EA) 24EA/BOX','BOX',2,17040,34080,3408,37488);
#
# Insert into OrderAll values (2018,06,20,'2018-06-20',3,2124243267,133941,'유동 골뱅이캔(자연산 140g/EA)','EA',10,2800,28000,2800,30800);
#
# Insert into OrderAll values (2018,06,20,'2018-06-20',4,2124243267,115722,'사세통상 버팔로윙(1Kg/EA) 태국-※닭고기(태국산)','EA',3,10500,31500,3150,34650);
#
# Insert into OrderAll values (2018,06,20,'2018-06-20',5,2124243267,116981,'사세통상 버팔로윙스틱(1Kg/EA) 태국-※닭고기(태국산)','EA',3,9800,29400,2940,32340);
#
# Insert into OrderAll values (2018,06,20,'2018-06-20',6,2124275159,119863,'삼조쎌텍 나쵸치즈소스(1Kg/EA)','EA',2,8300,16600,1660,18260);
#
# Insert into OrderAll values (2018,06,20,'2018-06-20',7,2124243267,166412,'뫼루니식품 물결무늬파우더(데일리비어용 매운맛 5Kg/EA) 미국-※미국산','EA',2,13150,26300,2630,28930);
#
# Insert into OrderAll values (2018,06,20,'2018-06-20',8,2124243267,138389,'이츠웰 초고추장(NEW 1Kg/EA)','EA',2,3000,6000,600,6600);
#
# Insert into OrderAll values (2018,06,20,'2018-06-20',9,2124243267,118232,'스팸 햄캔(마일드 200g/EA)-※돼지고기(수입산 80%+국내산 20%) 96.27%','EA',10,2800,28000,2800,30800);
#
# Insert into OrderAll values (2018,06,20,'2018-06-20',10,2124243267,145970,'치킨무(외식체인전용 5Kg/EA) 한국-※국내산','EA',2,5700,11400,0,11400);
#
# Insert into OrderAll values (2018,06,20,'2018-06-20',11,2124275159,526116,'유산지(생활맥주용 1000개 EA)','EA',1,30000,30000,3000,33000);
#
# Insert into OrderAll values (2018,06,20,'2018-06-20',12,2124275159,526117,'비닐백(생활맥주용 100매 EA)','EA',1,9000,9000,900,9900);
#
# Insert into OrderAll values (2018,06,20,'2018-06-20',13,2124243267,176689,'소시지(생활맥주용 천연돈장_70g*4입 280g/EA) 한국-※돼지고기(국내산)','EA',10,4370,43700,4370,48070);
#
# Insert into OrderAll values (2018,06,20,'2018-06-20',14,2124243267,512237,'이츠웰 페이퍼타올(핸드타올_4500매 BOX) 1EA/BOX','BOX',1,19500,19500,1950,21450);
#
# Order count 14 Total Order Count 113
# {'month': u'06', 'day': u'23', 'year': u'2018'}
# Insert into OrderAll values (2018,06,23,'2018-06-23',1,2124348988,251902,'냉동감자(생활맥주용 클리어코트슈스트링 2.04Kg/EA)','EA',4,8960,35840,3584,39424);
#
# Insert into OrderAll values (2018,06,23,'2018-06-23',2,2124348988,251901,'냉동감자(생활맥주용 스파이시스트레이트컷 2.04Kg/EA)','EA',2,8960,17920,1792,19712);
#
# Insert into OrderAll values (2018,06,23,'2018-06-23',3,2124348988,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',2,6980,13960,1396,15356);
#
# Insert into OrderAll values (2018,06,23,'2018-06-23',4,2124348991,169394,'샐러드믹스(생활맥주용 150g*5입 750g/BOX) 한국 1EA/BOX-※국내산','BOX',2,14400,28800,0,28800);
#
# Insert into OrderAll values (2018,06,23,'2018-06-23',5,2124348991,424783,'염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX','BOX',1,41400,41400,4140,45540);
#
# Insert into OrderAll values (2018,06,23,'2018-06-23',6,2124348991,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',2,54300,108600,10860,119460);
#
# Insert into OrderAll values (2018,06,23,'2018-06-23',7,2124348988,201934,'소고기육포(생활맥주용 70g/EA) 호주-※호주산','EA',10,3970,39700,3970,43670);
#
# Order count 7 Total Order Count 120
# {'month': u'06', 'day': u'25', 'year': u'2018'}
# Insert into OrderAll values (2018,06,25,'2018-06-25',1,2124401557,145970,'치킨무(외식체인전용 5Kg/EA) 한국-※국내산','EA',2,5700,11400,0,11400);
#
# Insert into OrderAll values (2018,06,25,'2018-06-25',2,2124401557,100744,'스프라이트 사이다(355ml 355g/EA) 24EA/BOX','BOX',2,13992,27984,2798,30782);
#
# Insert into OrderAll values (2018,06,25,'2018-06-25',3,2124401557,178733,'물티슈(생활맥주용 500입 BOX) 1EA/BOX','BOX',2,11000,22000,2200,24200);
#
# Insert into OrderAll values (2018,06,25,'2018-06-25',4,2124401557,246087,'아델리타 할라페뇨(슬라이스 2.9Kg/EA)','EA',2,8000,16000,1600,17600);
#
# Insert into OrderAll values (2018,06,25,'2018-06-25',5,2124401557,116709,'리코스 나쵸칩(454g/EA) 미국-※미국','EA',10,2900,29000,2900,31900);
#
# Insert into OrderAll values (2018,06,25,'2018-06-25',6,2124401557,232931,'반건오징어(생활맥주용 10미 1.3Kg/EA) 한국-※국내산','EA',2,35000,70000,0,70000);
#
# Insert into OrderAll values (2018,06,25,'2018-06-25',7,2124401557,176689,'소시지(생활맥주용 천연돈장_70g*4입 280g/EA) 한국-※돼지고기(국내산)','EA',10,4370,43700,4370,48070);
#
# Insert into OrderAll values (2018,06,25,'2018-06-25',8,2124401557,133941,'유동 골뱅이캔(자연산 140g/EA)','EA',8,2800,22400,2240,24640);
#
# Order count 8 Total Order Count 128
# {'month': u'06', 'day': u'26', 'year': u'2018'}
# Insert into OrderAll values (2018,06,26,'2018-06-26',1,2124401866,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',3,54300,162900,16290,179190);
#
# Insert into OrderAll values (2018,06,26,'2018-06-26',2,2124401866,424783,'염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX','BOX',1,41400,41400,4140,45540);
#
# Insert into OrderAll values (2018,06,26,'2018-06-26',3,2124440345,247491,'뫼루니식품 레드소스(데일리비어용 양념치킨용 2Kg/EA)','EA',3,6900,20700,2070,22770);
#
# Insert into OrderAll values (2018,06,26,'2018-06-26',4,2124440346,115364,'삼진 살사소스(2Kg/EA)','EA',2,9000,18000,1800,19800);
#
# Insert into OrderAll values (2018,06,26,'2018-06-26',5,2124440346,119863,'삼조쎌텍 나쵸치즈소스(1Kg/EA)','EA',3,8300,24900,2490,27390);
#
# Insert into OrderAll values (2018,06,26,'2018-06-26',6,2124440345,114937,'청우 캡사이신소스(550g/EA)','EA',1,6900,6900,690,7590);
#
# Insert into OrderAll values (2018,06,26,'2018-06-26',7,2124440345,177058,'미니고무장갑(생활맥주용 10입 EA)','EA',1,7500,7500,750,8250);
#
# Insert into OrderAll values (2018,06,26,'2018-06-26',8,2124440345,251901,'냉동감자(생활맥주용 스파이시스트레이트컷 2.04Kg/EA)','EA',4,8960,35840,3584,39424);
#
# Insert into OrderAll values (2018,06,26,'2018-06-26',9,2124440345,251902,'냉동감자(생활맥주용 클리어코트슈스트링 2.04Kg/EA)','EA',4,8960,35840,3584,39424);
#
# Insert into OrderAll values (2018,06,26,'2018-06-26',10,2124440345,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',2,6980,13960,1396,15356);
#
# Insert into OrderAll values (2018,06,26,'2018-06-26',11,2124440345,206578,'길림양행 땅콩(껍질무_1/2태 1Kg/PAC)-※이력번호:10931-18-050103M','PAC',4,7000,28000,2800,30800);
#
# Insert into OrderAll values (2018,06,26,'2018-06-26',12,2124440346,242910,'웰넛 건포도(500g/EA) 미국-※미국산','EA',3,3130,9390,939,10329);
#
# Insert into OrderAll values (2018,06,26,'2018-06-26',13,2124440345,160016,'오뚜기 케찹(스파우트팩 3.3Kg/EA)','EA',2,3950,7900,790,8690);
#
# Insert into OrderAll values (2018,06,26,'2018-06-26',14,2124440345,154639,'오뚜기 마요네즈(골드 스파우트팩 3.2Kg/EA)','EA',1,9800,9800,980,10780);
#
# Insert into OrderAll values (2018,06,26,'2018-06-26',15,2124440345,215140,'양파드레싱(생활맥주용 2Kg/EA)','EA',3,9000,27000,2700,29700);
#
# Order count 15 Total Order Count 143
# {'month': u'06', 'day': u'27', 'year': u'2018'}
# Insert into OrderAll values (2018,06,27,'2018-06-27',1,2124440423,232931,'반건오징어(생활맥주용 10미 1.3Kg/EA) 한국-※국내산','EA',2,35000,70000,0,70000);
#
# Insert into OrderAll values (2018,06,27,'2018-06-27',2,2124440423,166412,'뫼루니식품 물결무늬파우더(데일리비어용 매운맛 5Kg/EA) 미국-※미국산','EA',2,13150,26300,2630,28930);
#
# Insert into OrderAll values (2018,06,27,'2018-06-27',3,2124440472,169394,'샐러드믹스(생활맥주용 150g*5입 750g/BOX) 한국 1EA/BOX-※국내산','BOX',2,14400,28800,0,28800);
#
# Insert into OrderAll values (2018,06,27,'2018-06-27',4,2124440423,116709,'리코스 나쵸칩(454g/EA) 미국-※미국','EA',10,2900,29000,2900,31900);
#
# Insert into OrderAll values (2018,06,27,'2018-06-27',5,2124440423,115722,'사세통상 버팔로윙(1Kg/EA) 태국-※닭고기(태국산)','EA',2,10500,21000,2100,23100);
#
# Insert into OrderAll values (2018,06,27,'2018-06-27',6,2124440423,116981,'사세통상 버팔로윙스틱(1Kg/EA) 태국-※닭고기(태국산)','EA',3,9800,29400,2940,32340);
#
# Order count 6 Total Order Count 149
# {'month': u'06', 'day': u'28', 'year': u'2018'}
# Insert into OrderAll values (2018,06,28,'2018-06-28',1,2124517332,133941,'유동 골뱅이캔(자연산 140g/EA)','EA',10,2800,28000,2800,30800);
#
# Insert into OrderAll values (2018,06,28,'2018-06-28',2,2124517332,176689,'소시지(생활맥주용 천연돈장_70g*4입 280g/EA) 한국-※돼지고기(국내산)','EA',10,4370,43700,4370,48070);
#
# Insert into OrderAll values (2018,06,28,'2018-06-28',3,2124517332,124531,'맥앤치즈볼(생활맥주용 50G*4입 200g/EA)','EA',8,3620,28960,2896,31856);
#
# Insert into OrderAll values (2018,06,28,'2018-06-28',4,2124517332,118232,'스팸 햄캔(마일드 200g/EA)-※돼지고기(수입산 80%+국내산 20%) 96.27%','EA',6,2800,16800,1680,18480);
#
# Insert into OrderAll values (2018,06,28,'2018-06-28',5,2124517332,145970,'치킨무(외식체인전용 5Kg/EA) 한국-※국내산','EA',3,5700,17100,0,17100);
#
# Insert into OrderAll values (2018,06,28,'2018-06-28',6,2124517532,135267,'그라나파다노치즈(포션 200g/EA)','EA',1,6600,6600,660,7260);
#
# Order count 6 Total Order Count 155
# {'month': u'06', 'day': u'29', 'year': u'2018'}
# Insert into OrderAll values (2018,06,29,'2018-06-29',1,2124517335,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',2,54300,108600,10860,119460);
#
# Insert into OrderAll values (2018,06,29,'2018-06-29',2,2124517335,424783,'염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX','BOX',1,41400,41400,4140,45540);
#
# Insert into OrderAll values (2018,06,29,'2018-06-29',3,2124517375,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',2,6980,13960,1396,15356);
#
# Insert into OrderAll values (2018,06,29,'2018-06-29',4,2124517375,251902,'냉동감자(생활맥주용 클리어코트슈스트링 2.04Kg/EA)','EA',4,8960,35840,3584,39424);
#
# Insert into OrderAll values (2018,06,29,'2018-06-29',5,2124517375,251901,'냉동감자(생활맥주용 스파이시스트레이트컷 2.04Kg/EA)','EA',3,8960,26880,2688,29568);
#
# Insert into OrderAll values (2018,06,29,'2018-06-29',6,2124517375,232931,'반건오징어(생활맥주용 10미 1.3Kg/EA) 한국-※국내산','EA',2,35000,70000,0,70000);
#
# Insert into OrderAll values (2018,06,29,'2018-06-29',7,2124517375,201934,'소고기육포(생활맥주용 70g/EA) 호주-※호주산','EA',10,3970,39700,3970,43670);
#
# Order count 7 Total Order Count 162
# {'month': u'06', 'day': u'30', 'year': u'2018'}
# Insert into OrderAll values (2018,06,30,'2018-06-30',1,2124560338,401354,'계란(특란_60g*30입 1.8Kg/PAC) 한국-※달걀(국내산)','PAC',2,6506,13012,0,13012);
#
# Order count 1 Total Order Count 163

# %%
fb = open('ftest.sql', 'w')

string = u'한글문장'

ustring = string.encode("utf-16")
fb.write(ustring)

fb.close()
