# %% [markdown]
# # Make SQL Insert Statement

# %% [markdown]
# ## from Excel file to SQL statements

# %%
from openpyxl import Workbook
from openpyxl.compat import range
from openpyxl.utils import get_column_letter
from openpyxl import load_workbook
from openpyxl import Workbook

# %%
print ord('T') - ord('A')
print ord('V') - ord('A')
print ord('P') - ord('A')
# Out:
# 19
# 21
# 15

# %% [markdown]
# ### Function splitdate
# ##### split 2017-10-31 string into 2017, 10, 31

# %%
def splitdate(orderdatestring):
    ody,odm, odd = orderdatestring.split('-')
    return({'year':ody, 'month':odm, 'day':odd})

# %% [markdown]
# ### Find Order row and make Insert stmt

# %%
wb = load_workbook(filename = '2017SEP.xlsx')
ws = wb.active

num_rows = ws.max_row
#num_rows = 70
print num_rows

f = open("2017SEP.sql", 'w')


prev_val = None
stmt_flag = False
order_cnt = 0
for row in ws.iter_rows(min_row=1, max_col=24, max_row=num_rows):
    sql_stmt = None
    sql_stmt_u = None
            
    # Find the row that contains the YMD
    if (unicode(row[0].value) == u'차량번호 :'):
        YMD_string_org = unicode(row[15].value)
        YMD_string = YMD_string_org[7:]
        odate_dic = splitdate(YMD_string)
        print odate_dic
        
    # Find the 1st Row 
    if (row[0].value == 1) and ( prev_val == 'No.'):
        stmt_flag = True
    if (stmt_flag):
        # Find the Last Row
        if (unicode(prev_val).isdigit() == True ) and (unicode(row[0].value).isdigit() == False):
            stmt_flag = False
            print 'Order count', order_cnt
            order_cnt = 0
        else:
            order_cnt += 1
            # 0 : iD / 1: OrderNO / 2: SKU / 5: pname / 14: metric / 16:qty / 18:price / 19:amount / 21:tax / 23:total
            tuple_dict = {'year':odate_dic['year'],
                          'month':odate_dic['month'],
                          'day':odate_dic['day'],
                          'YMD':YMD_string,
                          'dno':row[0].value,
                          'orderno':row[1].value,
                          'sku':row[2].value,
                          'pname':unicode(row[5].value).replace('\n','-'),
                          'metric':row[14].value, 
                          'qty':row[16].value,
                          'price':row[18].value,
                          'amount':row[19].value,
                          'tax':row[21].value,
                          'total':row[23].value
                         }
            
            sql_stmt = u'Insert into Order789Gsheet values '
            sql_stmt += '('
            sql_stmt += str(tuple_dict['year'])+','
            sql_stmt += str(tuple_dict['month'])+','
            sql_stmt += str(tuple_dict['day'])+','
            sql_stmt += '\'' + tuple_dict['YMD'] + '\','
            sql_stmt += str(tuple_dict['dno'])+','
            sql_stmt += str(tuple_dict['orderno'])+','
            sql_stmt += str(tuple_dict['sku'])+','
            sql_stmt += '\'' + tuple_dict['pname'] + '\','
            sql_stmt += '\'' + tuple_dict['metric'] + '\','
            sql_stmt += str(tuple_dict['qty'])+','
            sql_stmt += str(tuple_dict['price'])+','
            sql_stmt += str(tuple_dict['amount'])+','
            sql_stmt += str(tuple_dict['tax'])+','
            sql_stmt += str(tuple_dict['total'])
            sql_stmt += ');\n'

            print sql_stmt
            #print ''
            # f.write(sql_stmt_r.replace(u'\ufeff','').encode("utf-16"))
            
            f.write(sql_stmt.encode('utf-8'))
            
                
    prev_val = row[0].value

f.close()
# Out:
# 750
# {'month': u'09', 'day': u'01', 'year': u'2017'}
# Insert into Order789Gsheet values (2017,09,01,'2017-09-01',1,2116440702,171838,'팔도 비빔면(130g/EA) 40EA/BOX','BOX',1,26800,26800,2680,29480);
#
# Insert into Order789Gsheet values (2017,09,01,'2017-09-01',2,2116440702,134356,'심플로트 냉동감자(메가크런치 2.04Kg/EA)','EA',2,9960,19920,1992,21912);
#
# Insert into Order789Gsheet values (2017,09,01,'2017-09-01',3,2116440702,138389,'이츠웰 초고추장(NEW 1Kg/EA)','EA',3,3000,9000,900,9900);
#
# Insert into Order789Gsheet values (2017,09,01,'2017-09-01',4,2116440702,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',4,6980,27920,2792,30712);
#
# Insert into Order789Gsheet values (2017,09,01,'2017-09-01',5,2116440702,144398,'심플로트 냉동감자(세이보리_스트레이트컷 2.26Kg/EA)','EA',5,9380,46900,4690,51590);
#
# Insert into Order789Gsheet values (2017,09,01,'2017-09-01',6,2116440702,145970,'치킨무(외식체인전용 5Kg/EA) 한국-※국내산','EA',1,5700,5700,0,5700);
#
# Order count 6
# {'month': u'09', 'day': u'02', 'year': u'2017'}
# Insert into Order789Gsheet values (2017,09,02,'2017-09-02',1,2116478027,424783,'염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX','BOX',1,41400,41400,4140,45540);
#
# Insert into Order789Gsheet values (2017,09,02,'2017-09-02',2,2116481658,100744,'스프라이트 사이다(355ml 355g/EA) 한국 24EA/BOX-※국내산','BOX',1,13992,13992,1399,15391);
#
# Insert into Order789Gsheet values (2017,09,02,'2017-09-02',3,2116481658,116709,'리코스 나쵸칩(454g/EA) 미국-※미국','EA',5,2900,14500,1450,15950);
#
# Insert into Order789Gsheet values (2017,09,02,'2017-09-02',4,2116478027,169394,'샐러드믹스(생활맥주용 150g*5입 750g/BOX) 한국 1EA/BOX-※국내산','BOX',1,14400,14400,0,14400);
#
# Insert into Order789Gsheet values (2017,09,02,'2017-09-02',5,2116481658,247491,'뫼루니식품 레드소스(데일리비어용 양념치킨용 2Kg/EA)','EA',2,6900,13800,1380,15180);
#
# Insert into Order789Gsheet values (2017,09,02,'2017-09-02',6,2116478027,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',3,54300,162900,16290,179190);
#
# Order count 6
# {'month': u'09', 'day': u'04', 'year': u'2017'}
# Insert into Order789Gsheet values (2017,09,04,'2017-09-04',1,2116520248,146393,'쉐프솔루션 해물볶음밥(300g/EA)','EA',5,1459,7295,730,8025);
#
# Insert into Order789Gsheet values (2017,09,04,'2017-09-04',2,2116520248,146391,'쉐프솔루션 햄야채볶음밥(300g/EA)','EA',5,1469,7345,735,8080);
#
# Insert into Order789Gsheet values (2017,09,04,'2017-09-04',3,2116520248,146239,'쉐프솔루션 김치볶음밥(300g/EA)','EA',20,1400,28000,2800,30800);
#
# Insert into Order789Gsheet values (2017,09,04,'2017-09-04',4,2116520248,145970,'치킨무(외식체인전용 5Kg/EA) 한국-※국내산','EA',2,5700,11400,0,11400);
#
# Insert into Order789Gsheet values (2017,09,04,'2017-09-04',5,2116520248,144398,'심플로트 냉동감자(세이보리_스트레이트컷 2.26Kg/EA)','EA',5,9380,46900,4690,51590);
#
# Insert into Order789Gsheet values (2017,09,04,'2017-09-04',6,2116520248,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',10,6980,69800,6980,76780);
#
# Insert into Order789Gsheet values (2017,09,04,'2017-09-04',7,2116520248,134356,'심플로트 냉동감자(메가크런치 2.04Kg/EA)','EA',5,9960,49800,4980,54780);
#
# Insert into Order789Gsheet values (2017,09,04,'2017-09-04',8,2116511241,127454,'파로 할라페뇨(슬라이스 3Kg/EA)','EA',1,8500,8500,850,9350);
#
# Insert into Order789Gsheet values (2017,09,04,'2017-09-04',9,2116520248,124531,'맥앤치즈볼(생활맥주용 50G*4입 200g/EA)','EA',10,3620,36200,3620,39820);
#
# Insert into Order789Gsheet values (2017,09,04,'2017-09-04',10,2116520248,116981,'사세통상 버팔로윙스틱(1Kg/EA) 태국-※닭고기(태국산)','EA',2,9800,19600,1960,21560);
#
# Insert into Order789Gsheet values (2017,09,04,'2017-09-04',11,2116520248,116709,'리코스 나쵸칩(454g/EA) 미국-※미국','EA',10,2900,29000,2900,31900);
#
# Insert into Order789Gsheet values (2017,09,04,'2017-09-04',12,2116520248,160016,'오뚜기 케찹(스파우트팩 3.3Kg/EA)','EA',2,3950,7900,790,8690);
#
# Insert into Order789Gsheet values (2017,09,04,'2017-09-04',13,2116535906,514158,'이츠웰 주방세제(그린알로_3kg EA)','EA',1,2833,2833,283,3116);
#
# Insert into Order789Gsheet values (2017,09,04,'2017-09-04',14,2116511241,500556,'일회용기세트(1호_70*30mm_100입 다용도 PAC)','PAC',1,2169,2169,217,2386);
#
# Insert into Order789Gsheet values (2017,09,04,'2017-09-04',15,2116511241,401354,'계란(특란_60g*30입 1.8Kg/PAC) 한국-※달걀(국내산)','PAC',3,7203,21609,0,21609);
#
# Insert into Order789Gsheet values (2017,09,04,'2017-09-04',16,2116520248,247491,'뫼루니식품 레드소스(데일리비어용 양념치킨용 2Kg/EA)','EA',2,6900,13800,1380,15180);
#
# Insert into Order789Gsheet values (2017,09,04,'2017-09-04',17,2116520248,215140,'양파드레싱(생활맥주용 2Kg/EA)','EA',2,9000,18000,1800,19800);
#
# Insert into Order789Gsheet values (2017,09,04,'2017-09-04',18,2116511241,215139,'케이준드레싱(생활맥주용 2Kg/EA)','EA',1,9050,9050,905,9955);
#
# Insert into Order789Gsheet values (2017,09,04,'2017-09-04',19,2116520248,206578,'길림양행 땅콩(껍질무_1/2태 1Kg/PAC)-※이력번호:13361-17-300713M','PAC',3,7000,21000,2100,23100);
#
# Insert into Order789Gsheet values (2017,09,04,'2017-09-04',20,2116520248,201934,'소고기육포(생활맥주용 70g/EA) 호주-※호주산','EA',10,3970,39700,3970,43670);
#
# Insert into Order789Gsheet values (2017,09,04,'2017-09-04',21,2116520248,177058,'미니고무장갑(생활맥주용 10입 EA)','EA',1,7500,7500,750,8250);
#
# Insert into Order789Gsheet values (2017,09,04,'2017-09-04',22,2116520248,176689,'소시지(생활맥주용 천연돈장_70g*4입 280g/EA) 한국-※돼지고기(국내산)','EA',25,4370,109250,10925,120175);
#
# Insert into Order789Gsheet values (2017,09,04,'2017-09-04',23,2116511241,169394,'샐러드믹스(생활맥주용 150g*5입 750g/BOX) 한국 1EA/BOX-※국내산','BOX',1,14400,14400,0,14400);
#
# Insert into Order789Gsheet values (2017,09,04,'2017-09-04',24,2116520248,163815,'이츠웰 골뱅이캔(자연산 140g/EA)','EA',10,2800,28000,2800,30800);
#
# Order count 24
# {'month': u'09', 'day': u'05', 'year': u'2017'}
# Insert into Order789Gsheet values (2017,09,05,'2017-09-05',1,2116527625,424783,'염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX','BOX',2,41400,82800,8280,91080);
#
# Insert into Order789Gsheet values (2017,09,05,'2017-09-05',2,2116570349,116981,'사세통상 버팔로윙스틱(1Kg/EA) 태국-※닭고기(태국산)','EA',1,9800,9800,980,10780);
#
# Insert into Order789Gsheet values (2017,09,05,'2017-09-05',3,2116527625,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',2,54300,108600,10860,119460);
#
# Insert into Order789Gsheet values (2017,09,05,'2017-09-05',4,2116570349,115722,'사세통상 버팔로윙(1Kg/EA) 태국-※닭고기(태국산)','EA',2,10500,21000,2100,23100);
#
# Order count 4
# {'month': u'09', 'day': u'06', 'year': u'2017'}
# Insert into Order789Gsheet values (2017,09,06,'2017-09-06',1,2116572654,169394,'샐러드믹스(생활맥주용 150g*5입 750g/BOX) 한국 1EA/BOX-※국내산','BOX',2,14400,28800,0,28800);
#
# Insert into Order789Gsheet values (2017,09,06,'2017-09-06',2,2116572654,501386,'트레펑(1L 막힌하수구용 EA)','EA',10,2215,22150,2215,24365);
#
# Insert into Order789Gsheet values (2017,09,06,'2017-09-06',3,2116600551,166412,'뫼루니식품 물결무늬파우더(데일리비어용 매운맛 5Kg/EA) 미국-※미국산','EA',3,13150,39450,3945,43395);
#
# Order count 3
# {'month': u'09', 'day': u'07', 'year': u'2017'}
# Insert into Order789Gsheet values (2017,09,07,'2017-09-07',1,2116602764,119863,'삼조쎌텍 나쵸치즈소스(1Kg/EA)','EA',2,8300,16600,1660,18260);
#
# Insert into Order789Gsheet values (2017,09,07,'2017-09-07',2,2116602785,145970,'치킨무(외식체인전용 5Kg/EA) 한국-※국내산','EA',2,5700,11400,0,11400);
#
# Insert into Order789Gsheet values (2017,09,07,'2017-09-07',3,2116602785,163815,'이츠웰 골뱅이캔(자연산 140g/EA)','EA',5,2800,14000,1400,15400);
#
# Insert into Order789Gsheet values (2017,09,07,'2017-09-07',4,2116602764,169394,'샐러드믹스(생활맥주용 150g*5입 750g/BOX) 한국 1EA/BOX-※국내산','BOX',1,14400,14400,0,14400);
#
# Insert into Order789Gsheet values (2017,09,07,'2017-09-07',5,2116602764,501386,'트레펑(1L 막힌하수구용 EA)','EA',10,2215,22150,2215,24365);
#
# Order count 5
# {'month': u'09', 'day': u'08', 'year': u'2017'}
# Insert into Order789Gsheet values (2017,09,08,'2017-09-08',1,2116633542,215140,'양파드레싱(생활맥주용 2Kg/EA)','EA',3,9000,27000,2700,29700);
#
# Insert into Order789Gsheet values (2017,09,08,'2017-09-08',2,2116632521,242910,'웰넛 건포도(500g/EA) 미국-※미국산','EA',5,2300,11500,1150,12650);
#
# Insert into Order789Gsheet values (2017,09,08,'2017-09-08',3,2116632521,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',1,54300,54300,5430,59730);
#
# Insert into Order789Gsheet values (2017,09,08,'2017-09-08',4,2116633542,116709,'리코스 나쵸칩(454g/EA) 미국-※미국','EA',10,2900,29000,2900,31900);
#
# Insert into Order789Gsheet values (2017,09,08,'2017-09-08',5,2116633542,118232,'스팸 햄캔(마일드 200g/EA)-※돼지고기(수입산 80%+국내산 20%) 96.27%','EA',20,2800,56000,5600,61600);
#
# Insert into Order789Gsheet values (2017,09,08,'2017-09-08',6,2116632521,119863,'삼조쎌텍 나쵸치즈소스(1Kg/EA)','EA',1,8300,8300,830,9130);
#
# Insert into Order789Gsheet values (2017,09,08,'2017-09-08',7,2116669728,127454,'파로 할라페뇨(슬라이스 3Kg/EA)','EA',1,8500,8500,850,9350);
#
# Insert into Order789Gsheet values (2017,09,08,'2017-09-08',8,2116633542,134356,'심플로트 냉동감자(메가크런치 2.04Kg/EA)','EA',8,9960,79680,7968,87648);
#
# Insert into Order789Gsheet values (2017,09,08,'2017-09-08',9,2116633542,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',5,6980,34900,3490,38390);
#
# Insert into Order789Gsheet values (2017,09,08,'2017-09-08',10,2116633542,144398,'심플로트 냉동감자(세이보리_스트레이트컷 2.26Kg/EA)','EA',8,9380,75040,7504,82544);
#
# Insert into Order789Gsheet values (2017,09,08,'2017-09-08',11,2116633542,163815,'이츠웰 골뱅이캔(자연산 140g/EA)','EA',15,2800,42000,4200,46200);
#
# Insert into Order789Gsheet values (2017,09,08,'2017-09-08',12,2116633542,206578,'길림양행 땅콩(껍질무_1/2태 1Kg/PAC)-※이력번호:10931-17-080068M','PAC',3,7000,21000,2100,23100);
#
# Order count 12
# {'month': u'09', 'day': u'09', 'year': u'2017'}
# Insert into Order789Gsheet values (2017,09,09,'2017-09-09',1,2116705394,100353,'백설 바삭튀김가루(1Kg/EA) 미국-※미국산','EA',5,2500,12500,1250,13750);
#
# Insert into Order789Gsheet values (2017,09,09,'2017-09-09',2,2116705394,176689,'소시지(생활맥주용 천연돈장_70g*4입 280g/EA) 한국-※돼지고기(국내산)','EA',20,4370,87400,8740,96140);
#
# Insert into Order789Gsheet values (2017,09,09,'2017-09-09',3,2116700479,526116,'유산지(생활맥주용 1000개 EA)','EA',0,30000,0,0,0);
#
# Insert into Order789Gsheet values (2017,09,09,'2017-09-09',4,2116705394,247491,'뫼루니식품 레드소스(데일리비어용 양념치킨용 2Kg/EA)','EA',2,6900,13800,1380,15180);
#
# Insert into Order789Gsheet values (2017,09,09,'2017-09-09',5,2116700175,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX-※★ma김경묵님 요청건','BOX',0,54300,0,0,0);
#
# Insert into Order789Gsheet values (2017,09,09,'2017-09-09',6,2116705394,201934,'소고기육포(생활맥주용 70g/EA) 호주-※호주산','EA',10,3970,39700,3970,43670);
#
# Order count 6
# {'month': u'09', 'day': u'11', 'year': u'2017'}
# Insert into Order789Gsheet values (2017,09,11,'2017-09-11',1,2116718355,526116,'유산지(생활맥주용 1000개 EA)','EA',2,30000,60000,6000,66000);
#
# Insert into Order789Gsheet values (2017,09,11,'2017-09-11',2,2116698825,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',3,54300,162900,16290,179190);
#
# Insert into Order789Gsheet values (2017,09,11,'2017-09-11',3,2116698825,424783,'염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX','BOX',1,41400,41400,4140,45540);
#
# Order count 3
# {'month': u'09', 'day': u'12', 'year': u'2017'}
# Insert into Order789Gsheet values (2017,09,12,'2017-09-12',1,2116752038,116981,'사세통상 버팔로윙스틱(1Kg/EA) 태국-※닭고기(태국산)','EA',3,9800,29400,2940,32340);
#
# Insert into Order789Gsheet values (2017,09,12,'2017-09-12',2,2116752038,124531,'맥앤치즈볼(생활맥주용 50G*4입 200g/EA)','EA',10,3620,36200,3620,39820);
#
# Insert into Order789Gsheet values (2017,09,12,'2017-09-12',3,2116752038,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',8,6980,55840,5584,61424);
#
# Insert into Order789Gsheet values (2017,09,12,'2017-09-12',4,2116752038,145970,'치킨무(외식체인전용 5Kg/EA) 한국-※국내산','EA',2,5700,11400,0,11400);
#
# Insert into Order789Gsheet values (2017,09,12,'2017-09-12',5,2116752038,232931,'반건오징어(생활맥주용 10미 1.3Kg/EA) 한국-※국내산','EA',3,29500,88500,0,88500);
#
# Insert into Order789Gsheet values (2017,09,12,'2017-09-12',6,2116752038,100744,'스프라이트 사이다(355ml 355g/EA) 한국 24EA/BOX-※국내산','BOX',1,13992,13992,1399,15391);
#
# Insert into Order789Gsheet values (2017,09,12,'2017-09-12',7,2116752038,100743,'코카콜라 콜라(캔_355ml 355g/EA) 한국 24EA/BOX-※국내산','BOX',1,15480,15480,1548,17028);
#
# Insert into Order789Gsheet values (2017,09,12,'2017-09-12',8,2116752038,115722,'사세통상 버팔로윙(1Kg/EA) 태국-※닭고기(태국산)','EA',4,10500,42000,4200,46200);
#
# Order count 8
# {'month': u'09', 'day': u'13', 'year': u'2017'}
# Insert into Order789Gsheet values (2017,09,13,'2017-09-13',1,2116752140,143790,'이츠웰 참기름(NEW_캔_1L 916g/EA) 수입산-※참깨(베트남산,미얀마산)','EA',1,10600,10600,1060,11660);
#
# Insert into Order789Gsheet values (2017,09,13,'2017-09-13',2,2116780868,138389,'이츠웰 초고추장(NEW 1Kg/EA)','EA',3,3000,9000,900,9900);
#
# Insert into Order789Gsheet values (2017,09,13,'2017-09-13',3,2116752140,116709,'리코스 나쵸칩(454g/EA) 미국-※미국','EA',5,2900,14500,1450,15950);
#
# Insert into Order789Gsheet values (2017,09,13,'2017-09-13',4,2116752140,146239,'쉐프솔루션 김치볶음밥(300g/EA)','EA',10,1400,14000,1400,15400);
#
# Insert into Order789Gsheet values (2017,09,13,'2017-09-13',5,2116752477,169394,'샐러드믹스(생활맥주용 150g*5입 750g/BOX) 한국 1EA/BOX-※국내산','BOX',2,14400,28800,0,28800);
#
# Insert into Order789Gsheet values (2017,09,13,'2017-09-13',6,2116752140,163815,'이츠웰 골뱅이캔(자연산 140g/EA)','EA',10,2800,28000,2800,30800);
#
# Insert into Order789Gsheet values (2017,09,13,'2017-09-13',7,2116752140,146393,'쉐프솔루션 해물볶음밥(300g/EA)','EA',10,1459,14590,1459,16049);
#
# Insert into Order789Gsheet values (2017,09,13,'2017-09-13',8,2116752140,146391,'쉐프솔루션 햄야채볶음밥(300g/EA)','EA',10,1469,14690,1469,16159);
#
# Order count 8
# {'month': u'09', 'day': u'14', 'year': u'2017'}
# Insert into Order789Gsheet values (2017,09,14,'2017-09-14',1,2116757504,116709,'리코스 나쵸칩(454g/EA) 미국-※미국','EA',5,2900,14500,1450,15950);
#
# Insert into Order789Gsheet values (2017,09,14,'2017-09-14',2,2116757504,134356,'심플로트 냉동감자(메가크런치 2.04Kg/EA)','EA',10,9960,99600,9960,109560);
#
# Insert into Order789Gsheet values (2017,09,14,'2017-09-14',3,2116757504,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',3,6980,20940,2094,23034);
#
# Insert into Order789Gsheet values (2017,09,14,'2017-09-14',4,2116757504,144398,'심플로트 냉동감자(세이보리_스트레이트컷 2.26Kg/EA)','EA',5,9380,46900,4690,51590);
#
# Insert into Order789Gsheet values (2017,09,14,'2017-09-14',5,2116757504,160016,'오뚜기 케찹(스파우트팩 3.3Kg/EA)','EA',2,3950,7900,790,8690);
#
# Insert into Order789Gsheet values (2017,09,14,'2017-09-14',6,2116781432,424783,'염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX','BOX',1,41400,41400,4140,45540);
#
# Insert into Order789Gsheet values (2017,09,14,'2017-09-14',7,2116781432,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',1,54300,54300,5430,59730);
#
# Insert into Order789Gsheet values (2017,09,14,'2017-09-14',8,2116757504,215140,'양파드레싱(생활맥주용 2Kg/EA)','EA',1,9000,9000,900,9900);
#
# Insert into Order789Gsheet values (2017,09,14,'2017-09-14',9,2116757504,201934,'소고기육포(생활맥주용 70g/EA) 호주-※호주산','EA',15,3970,59550,5955,65505);
#
# Insert into Order789Gsheet values (2017,09,14,'2017-09-14',10,2116757504,178733,'물티슈(생활맥주용 500입 BOX) 1EA/BOX','BOX',1,11000,11000,1100,12100);
#
# Insert into Order789Gsheet values (2017,09,14,'2017-09-14',11,2116757504,171838,'팔도 비빔면(130g/EA) 40EA/BOX','BOX',1,26800,26800,2680,29480);
#
# Order count 11
# {'month': u'09', 'day': u'15', 'year': u'2017'}
# Insert into Order789Gsheet values (2017,09,15,'2017-09-15',1,2116822728,115364,'삼진 살사소스(2Kg/EA)','EA',2,9000,18000,1800,19800);
#
# Insert into Order789Gsheet values (2017,09,15,'2017-09-15',2,2116822699,115722,'사세통상 버팔로윙(1Kg/EA) 태국-※닭고기(태국산)','EA',1,10500,10500,1050,11550);
#
# Insert into Order789Gsheet values (2017,09,15,'2017-09-15',3,2116822699,116981,'사세통상 버팔로윙스틱(1Kg/EA) 태국-※닭고기(태국산)','EA',2,9800,19600,1960,21560);
#
# Insert into Order789Gsheet values (2017,09,15,'2017-09-15',4,2116822699,118232,'스팸 햄캔(마일드 200g/EA)-※돼지고기(수입산 80%+국내산 20%) 96.27%','EA',10,2800,28000,2800,30800);
#
# Insert into Order789Gsheet values (2017,09,15,'2017-09-15',5,2116822699,134356,'심플로트 냉동감자(메가크런치 2.04Kg/EA)','EA',5,9960,49800,4980,54780);
#
# Insert into Order789Gsheet values (2017,09,15,'2017-09-15',6,2116822699,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',5,6980,34900,3490,38390);
#
# Insert into Order789Gsheet values (2017,09,15,'2017-09-15',7,2116822699,144398,'심플로트 냉동감자(세이보리_스트레이트컷 2.26Kg/EA)','EA',5,9380,46900,4690,51590);
#
# Insert into Order789Gsheet values (2017,09,15,'2017-09-15',8,2116822699,145970,'치킨무(외식체인전용 5Kg/EA) 한국-※국내산','EA',2,5700,11400,0,11400);
#
# Insert into Order789Gsheet values (2017,09,15,'2017-09-15',9,2116822699,163815,'이츠웰 골뱅이캔(자연산 140g/EA)','EA',5,2800,14000,1400,15400);
#
# Insert into Order789Gsheet values (2017,09,15,'2017-09-15',10,2116822699,215140,'양파드레싱(생활맥주용 2Kg/EA)','EA',2,9000,18000,1800,19800);
#
# Insert into Order789Gsheet values (2017,09,15,'2017-09-15',11,2116822699,232931,'반건오징어(생활맥주용 10미 1.3Kg/EA) 한국-※국내산','EA',5,29500,147500,0,147500);
#
# Insert into Order789Gsheet values (2017,09,15,'2017-09-15',12,2116822699,247491,'뫼루니식품 레드소스(데일리비어용 양념치킨용 2Kg/EA)','EA',2,6900,13800,1380,15180);
#
# Order count 12
# {'month': u'09', 'day': u'16', 'year': u'2017'}
# Insert into Order789Gsheet values (2017,09,16,'2017-09-16',1,2116858938,178883,'코스터(생활맥주용 600매 EA)','EA',1,57000,57000,5700,62700);
#
# Insert into Order789Gsheet values (2017,09,16,'2017-09-16',2,2116858938,215140,'양파드레싱(생활맥주용 2Kg/EA)','EA',2,9000,18000,1800,19800);
#
# Insert into Order789Gsheet values (2017,09,16,'2017-09-16',3,2116851805,242910,'웰넛 건포도(500g/EA) 미국-※미국산','EA',3,2300,6900,690,7590);
#
# Insert into Order789Gsheet values (2017,09,16,'2017-09-16',4,2116858938,247491,'뫼루니식품 레드소스(데일리비어용 양념치킨용 2Kg/EA)','EA',3,6900,20700,2070,22770);
#
# Insert into Order789Gsheet values (2017,09,16,'2017-09-16',5,2116851805,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',1,54300,54300,5430,59730);
#
# Insert into Order789Gsheet values (2017,09,16,'2017-09-16',6,2116851805,424783,'염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX','BOX',1,41400,41400,4140,45540);
#
# Order count 6
# {'month': u'09', 'day': u'18', 'year': u'2017'}
# Insert into Order789Gsheet values (2017,09,18,'2017-09-18',1,2116859024,116709,'리코스 나쵸칩(454g/EA) 미국-※미국','EA',10,2900,29000,2900,31900);
#
# Insert into Order789Gsheet values (2017,09,18,'2017-09-18',2,2116851813,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',1,54300,54300,5430,59730);
#
# Insert into Order789Gsheet values (2017,09,18,'2017-09-18',3,2116851813,127454,'파로 할라페뇨(슬라이스 3Kg/EA)','EA',2,8500,17000,1700,18700);
#
# Insert into Order789Gsheet values (2017,09,18,'2017-09-18',4,2116859024,146239,'쉐프솔루션 김치볶음밥(300g/EA)','EA',5,1400,7000,700,7700);
#
# Insert into Order789Gsheet values (2017,09,18,'2017-09-18',5,2116859024,176689,'소시지(생활맥주용 천연돈장_70g*4입 280g/EA) 한국-※돼지고기(국내산)','EA',12,4370,52440,5244,57684);
#
# Insert into Order789Gsheet values (2017,09,18,'2017-09-18',6,2116851813,401354,'계란(특란_60g*30입 1.8Kg/PAC) 한국-※달걀(국내산)','PAC',3,7203,21609,0,21609);
#
# Order count 6
# {'month': u'09', 'day': u'19', 'year': u'2017'}
# Insert into Order789Gsheet values (2017,09,19,'2017-09-19',1,2116905503,169394,'샐러드믹스(생활맥주용 150g*5입 750g/BOX) 한국 1EA/BOX-※국내산','BOX',1,14400,14400,0,14400);
#
# Insert into Order789Gsheet values (2017,09,19,'2017-09-19',2,2116905503,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',1,54300,54300,5430,59730);
#
# Order count 2
# {'month': u'09', 'day': u'20', 'year': u'2017'}
# Insert into Order789Gsheet values (2017,09,20,'2017-09-20',1,2116949674,144398,'심플로트 냉동감자(세이보리_스트레이트컷 2.26Kg/EA)','EA',2,9380,18760,1876,20636);
#
# Insert into Order789Gsheet values (2017,09,20,'2017-09-20',2,2116949674,206578,'길림양행 땅콩(껍질무_1/2태 1Kg/PAC)-※이력번호:10931-17-080068M','PAC',4,7000,28000,2800,30800);
#
# Insert into Order789Gsheet values (2017,09,20,'2017-09-20',3,2116949676,159365,'유니푸드 양념소금(마파치킨용 3.5g*90입 315g/EA)','EA',1,1000,1000,100,1100);
#
# Insert into Order789Gsheet values (2017,09,20,'2017-09-20',4,2116949674,146393,'쉐프솔루션 해물볶음밥(300g/EA)','EA',5,1459,7295,730,8025);
#
# Insert into Order789Gsheet values (2017,09,20,'2017-09-20',5,2116949674,146391,'쉐프솔루션 햄야채볶음밥(300g/EA)','EA',5,1469,7345,735,8080);
#
# Insert into Order789Gsheet values (2017,09,20,'2017-09-20',6,2116949674,115722,'사세통상 버팔로윙(1Kg/EA) 태국-※닭고기(태국산)','EA',2,10500,21000,2100,23100);
#
# Insert into Order789Gsheet values (2017,09,20,'2017-09-20',7,2116949674,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',3,6980,20940,2094,23034);
#
# Insert into Order789Gsheet values (2017,09,20,'2017-09-20',8,2116949674,133941,'유동 골뱅이캔(자연산 140g/EA)','EA',5,2800,14000,1400,15400);
#
# Insert into Order789Gsheet values (2017,09,20,'2017-09-20',9,2116949674,124531,'맥앤치즈볼(생활맥주용 50G*4입 200g/EA)','EA',10,3620,36200,3620,39820);
#
# Insert into Order789Gsheet values (2017,09,20,'2017-09-20',10,2116949676,119863,'삼조쎌텍 나쵸치즈소스(1Kg/EA)','EA',2,8300,16600,1660,18260);
#
# Insert into Order789Gsheet values (2017,09,20,'2017-09-20',11,2116949674,116981,'사세통상 버팔로윙스틱(1Kg/EA) 태국-※닭고기(태국산)','EA',2,9800,19600,1960,21560);
#
# Order count 11
# {'month': u'09', 'day': u'21', 'year': u'2017'}
# Insert into Order789Gsheet values (2017,09,21,'2017-09-21',1,2116986070,146239,'쉐프솔루션 김치볶음밥(300g/EA)','EA',5,1400,7000,700,7700);
#
# Order count 1
# {'month': u'09', 'day': u'22', 'year': u'2017'}
# Insert into Order789Gsheet values (2017,09,22,'2017-09-22',1,2117009720,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',3,54300,162900,16290,179190);
#
# Insert into Order789Gsheet values (2017,09,22,'2017-09-22',2,2117018525,247491,'뫼루니식품 레드소스(데일리비어용 양념치킨용 2Kg/EA)','EA',2,6900,13800,1380,15180);
#
# Insert into Order789Gsheet values (2017,09,22,'2017-09-22',3,2117018525,215140,'양파드레싱(생활맥주용 2Kg/EA)','EA',1,9000,9000,900,9900);
#
# Insert into Order789Gsheet values (2017,09,22,'2017-09-22',4,2117018525,176689,'소시지(생활맥주용 천연돈장_70g*4입 280g/EA) 한국-※돼지고기(국내산)','EA',10,4370,43700,4370,48070);
#
# Insert into Order789Gsheet values (2017,09,22,'2017-09-22',5,2117009720,169394,'샐러드믹스(생활맥주용 150g*5입 750g/BOX) 한국 1EA/BOX-※국내산','BOX',1,14400,14400,0,14400);
#
# Insert into Order789Gsheet values (2017,09,22,'2017-09-22',6,2117018525,160016,'오뚜기 케찹(스파우트팩 3.3Kg/EA)','EA',2,3950,7900,790,8690);
#
# Insert into Order789Gsheet values (2017,09,22,'2017-09-22',7,2117018525,146393,'쉐프솔루션 해물볶음밥(300g/EA)','EA',5,1459,7295,730,8025);
#
# Insert into Order789Gsheet values (2017,09,22,'2017-09-22',8,2117018525,146391,'쉐프솔루션 햄야채볶음밥(300g/EA)','EA',5,1469,7345,735,8080);
#
# Insert into Order789Gsheet values (2017,09,22,'2017-09-22',9,2117018525,145970,'치킨무(외식체인전용 5Kg/EA) 한국-※국내산','EA',2,5700,11400,0,11400);
#
# Insert into Order789Gsheet values (2017,09,22,'2017-09-22',10,2117047329,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',3,6980,20940,2094,23034);
#
# Insert into Order789Gsheet values (2017,09,22,'2017-09-22',11,2117018525,100744,'스프라이트 사이다(355ml 355g/EA) 한국 24EA/BOX-※국내산','BOX',1,13992,13992,1399,15391);
#
# Insert into Order789Gsheet values (2017,09,22,'2017-09-22',12,2117009720,424783,'염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX','BOX',1,41400,41400,4140,45540);
#
# Insert into Order789Gsheet values (2017,09,22,'2017-09-22',13,2117018525,100743,'코카콜라 콜라(캔_355ml 355g/EA) 한국 24EA/BOX-※국내산','BOX',1,15480,15480,1548,17028);
#
# Order count 13
# {'month': u'09', 'day': u'23', 'year': u'2017'}
# Insert into Order789Gsheet values (2017,09,23,'2017-09-23',1,2117018526,424783,'염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX','BOX',1,41400,41400,4140,45540);
#
# Insert into Order789Gsheet values (2017,09,23,'2017-09-23',2,2117018526,500556,'일회용기세트(1호_70*30mm_100입 다용도 PAC)','PAC',2,2169,4338,434,4772);
#
# Insert into Order789Gsheet values (2017,09,23,'2017-09-23',3,2117044952,512237,'이츠웰 페이퍼타올(핸드타올_4500매 BOX) 1EA/BOX','BOX',1,19500,19500,1950,21450);
#
# Insert into Order789Gsheet values (2017,09,23,'2017-09-23',4,2117018526,514663,'지원 일회용기뚜껑(W-3_75mm_100입 EA)','EA',2,1840,3680,368,4048);
#
# Insert into Order789Gsheet values (2017,09,23,'2017-09-23',5,2117018526,514664,'지원 일회용기(W-3_75*65mm_100입 EA)','EA',2,6239,12478,1248,13726);
#
# Insert into Order789Gsheet values (2017,09,23,'2017-09-23',6,2117044952,166412,'뫼루니식품 물결무늬파우더(데일리비어용 매운맛 5Kg/EA) 미국-※미국산','EA',3,13150,39450,3945,43395);
#
# Order count 6
# {'month': u'09', 'day': u'25', 'year': u'2017'}
# Insert into Order789Gsheet values (2017,09,25,'2017-09-25',1,2117097704,116709,'리코스 나쵸칩(454g/EA) 미국-※미국','EA',5,2900,14500,1450,15950);
#
# Insert into Order789Gsheet values (2017,09,25,'2017-09-25',2,2117097704,118232,'스팸 햄캔(마일드 200g/EA)-※돼지고기(수입산 80%+국내산 20%) 96.27%','EA',10,2800,28000,2800,30800);
#
# Insert into Order789Gsheet values (2017,09,25,'2017-09-25',3,2117097704,134356,'심플로트 냉동감자(메가크런치 2.04Kg/EA)','EA',5,9960,49800,4980,54780);
#
# Insert into Order789Gsheet values (2017,09,25,'2017-09-25',4,2117097704,138389,'이츠웰 초고추장(NEW 1Kg/EA)','EA',3,3000,9000,900,9900);
#
# Insert into Order789Gsheet values (2017,09,25,'2017-09-25',5,2117097704,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',8,6980,55840,5584,61424);
#
# Insert into Order789Gsheet values (2017,09,25,'2017-09-25',6,2117097704,144398,'심플로트 냉동감자(세이보리_스트레이트컷 2.26Kg/EA)','EA',8,9380,75040,7504,82544);
#
# Insert into Order789Gsheet values (2017,09,25,'2017-09-25',7,2117097704,145970,'치킨무(외식체인전용 5Kg/EA) 한국-※국내산','EA',2,5700,11400,0,11400);
#
# Insert into Order789Gsheet values (2017,09,25,'2017-09-25',8,2117097704,146239,'쉐프솔루션 김치볶음밥(300g/EA)','EA',5,1400,7000,700,7700);
#
# Insert into Order789Gsheet values (2017,09,25,'2017-09-25',9,2117097704,163815,'이츠웰 골뱅이캔(자연산 140g/EA)','EA',10,2800,28000,2800,30800);
#
# Insert into Order789Gsheet values (2017,09,25,'2017-09-25',10,2117045345,169394,'샐러드믹스(생활맥주용 150g*5입 750g/BOX) 한국 1EA/BOX-※국내산','BOX',2,14400,28800,0,28800);
#
# Insert into Order789Gsheet values (2017,09,25,'2017-09-25',11,2117097704,176689,'소시지(생활맥주용 천연돈장_70g*4입 280g/EA) 한국-※돼지고기(국내산)','EA',5,4370,21850,2185,24035);
#
# Insert into Order789Gsheet values (2017,09,25,'2017-09-25',12,2117097704,215140,'양파드레싱(생활맥주용 2Kg/EA)','EA',1,9000,9000,900,9900);
#
# Insert into Order789Gsheet values (2017,09,25,'2017-09-25',13,2117097754,401354,'계란(특란_60g*30입 1.8Kg/PAC) 한국-※달걀(국내산)','PAC',2,7203,14406,0,14406);
#
# Insert into Order789Gsheet values (2017,09,25,'2017-09-25',14,2117045345,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',1,54300,54300,5430,59730);
#
# Insert into Order789Gsheet values (2017,09,25,'2017-09-25',15,2117045345,424783,'염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX','BOX',1,41400,41400,4140,45540);
#
# Order count 15
# {'month': u'09', 'day': u'26', 'year': u'2017'}
# Insert into Order789Gsheet values (2017,09,26,'2017-09-26',1,2117097762,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',1,54300,54300,5430,59730);
#
# Order count 1
# {'month': u'09', 'day': u'27', 'year': u'2017'}
# Insert into Order789Gsheet values (2017,09,27,'2017-09-27',1,2117146825,115722,'사세통상 버팔로윙(1Kg/EA) 태국-※닭고기(태국산)','EA',2,10500,21000,2100,23100);
#
# Insert into Order789Gsheet values (2017,09,27,'2017-09-27',2,2117146825,206578,'길림양행 땅콩(껍질무_1/2태 1Kg/PAC)-※이력번호:10931-17080202M','PAC',3,7000,21000,2100,23100);
#
# Insert into Order789Gsheet values (2017,09,27,'2017-09-27',3,2117146825,514158,'이츠웰 주방세제(그린알로_3kg EA)','EA',1,2833,2833,283,3116);
#
# Insert into Order789Gsheet values (2017,09,27,'2017-09-27',4,2117146865,501326,'스파크 세탁세제(5kg EA)','EA',1,11470,11470,1147,12617);
#
# Insert into Order789Gsheet values (2017,09,27,'2017-09-27',5,2117179481,242910,'웰넛 건포도(500g/EA) 미국-※미국산','EA',4,2300,9200,920,10120);
#
# Order count 5
# {'month': u'09', 'day': u'28', 'year': u'2017'}
# Insert into Order789Gsheet values (2017,09,28,'2017-09-28',1,2117181479,100744,'스프라이트 사이다(355ml 355g/EA) 한국 24EA/BOX-※국내산','BOX',1,13992,13992,1399,15391);
#
# Insert into Order789Gsheet values (2017,09,28,'2017-09-28',2,2117181479,116981,'사세통상 버팔로윙스틱(1Kg/EA) 태국-※닭고기(태국산)','EA',2,9800,19600,1960,21560);
#
# Insert into Order789Gsheet values (2017,09,28,'2017-09-28',3,2117181479,247491,'뫼루니식품 레드소스(데일리비어용 양념치킨용 2Kg/EA)','EA',3,6900,20700,2070,22770);
#
# Insert into Order789Gsheet values (2017,09,28,'2017-09-28',4,2117181479,215140,'양파드레싱(생활맥주용 2Kg/EA)','EA',2,9000,18000,1800,19800);
#
# Insert into Order789Gsheet values (2017,09,28,'2017-09-28',5,2117210657,176689,'소시지(생활맥주용 천연돈장_70g*4입 280g/EA) 한국-※돼지고기(국내산)','EA',10,4370,43700,4370,48070);
#
# Insert into Order789Gsheet values (2017,09,28,'2017-09-28',6,2117181479,134356,'심플로트 냉동감자(메가크런치 2.04Kg/EA)','EA',5,9960,49800,4980,54780);
#
# Insert into Order789Gsheet values (2017,09,28,'2017-09-28',7,2117210657,144398,'심플로트 냉동감자(세이보리_스트레이트컷 2.26Kg/EA)','EA',5,9380,46900,4690,51590);
#
# Insert into Order789Gsheet values (2017,09,28,'2017-09-28',8,2117181479,146239,'쉐프솔루션 김치볶음밥(300g/EA)','EA',5,1400,7000,700,7700);
#
# Insert into Order789Gsheet values (2017,09,28,'2017-09-28',9,2117181479,146393,'쉐프솔루션 해물볶음밥(300g/EA)','EA',3,1459,4377,438,4815);
#
# Insert into Order789Gsheet values (2017,09,28,'2017-09-28',10,2117181479,163815,'이츠웰 골뱅이캔(자연산 140g/EA)','EA',10,2800,28000,2800,30800);
#
# Insert into Order789Gsheet values (2017,09,28,'2017-09-28',11,2117181504,169394,'샐러드믹스(생활맥주용 150g*5입 750g/BOX) 한국 1EA/BOX-※국내산','BOX',1,14400,14400,0,14400);
#
# Order count 11
# {'month': u'09', 'day': u'29', 'year': u'2017'}
# Insert into Order789Gsheet values (2017,09,29,'2017-09-29',1,2117214750,119863,'삼조쎌텍 나쵸치즈소스(1Kg/EA)','EA',2,8300,16600,1660,18260);
#
# Insert into Order789Gsheet values (2017,09,29,'2017-09-29',2,2117214750,127454,'파로 할라페뇨(슬라이스 3Kg/EA)','EA',1,8500,8500,850,9350);
#
# Insert into Order789Gsheet values (2017,09,29,'2017-09-29',3,2117214676,146239,'쉐프솔루션 김치볶음밥(300g/EA)','EA',5,1400,7000,700,7700);
#
# Insert into Order789Gsheet values (2017,09,29,'2017-09-29',4,2117214676,160016,'오뚜기 케찹(스파우트팩 3.3Kg/EA)','EA',2,3950,7900,790,8690);
#
# Order count 4
# {'month': u'09', 'day': u'30', 'year': u'2017'}
# Insert into Order789Gsheet values (2017,09,30,'2017-09-30',1,2117254287,115722,'사세통상 버팔로윙(1Kg/EA) 태국-※닭고기(태국산)','EA',4,10500,42000,4200,46200);
#
# Insert into Order789Gsheet values (2017,09,30,'2017-09-30',2,2117254287,116709,'리코스 나쵸칩(454g/EA) 미국-※미국','EA',10,2900,29000,2900,31900);
#
# Insert into Order789Gsheet values (2017,09,30,'2017-09-30',3,2117254287,116981,'사세통상 버팔로윙스틱(1Kg/EA) 태국-※닭고기(태국산)','EA',3,9800,29400,2940,32340);
#
# Insert into Order789Gsheet values (2017,09,30,'2017-09-30',4,2117254287,118232,'스팸 햄캔(마일드 200g/EA)-※돼지고기(수입산 80%+국내산 20%) 96.27%','EA',15,2800,42000,4200,46200);
#
# Insert into Order789Gsheet values (2017,09,30,'2017-09-30',5,2117254287,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',3,6980,20940,2094,23034);
#
# Insert into Order789Gsheet values (2017,09,30,'2017-09-30',6,2117254287,146239,'쉐프솔루션 김치볶음밥(300g/EA)','EA',10,1400,14000,1400,15400);
#
# Insert into Order789Gsheet values (2017,09,30,'2017-09-30',7,2117214853,424783,'염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX','BOX',1,41400,41400,4140,45540);
#
# Insert into Order789Gsheet values (2017,09,30,'2017-09-30',8,2117254287,163815,'이츠웰 골뱅이캔(자연산 140g/EA)','EA',10,2800,28000,2800,30800);
#
# Insert into Order789Gsheet values (2017,09,30,'2017-09-30',9,2117214853,169394,'샐러드믹스(생활맥주용 150g*5입 750g/BOX) 한국 1EA/BOX-※국내산','BOX',1,14400,14400,0,14400);
#
# Insert into Order789Gsheet values (2017,09,30,'2017-09-30',10,2117254287,171838,'팔도 비빔면(130g/EA) 40EA/BOX','BOX',1,26800,26800,2680,29480);
#
# Insert into Order789Gsheet values (2017,09,30,'2017-09-30',11,2117254287,232931,'반건오징어(생활맥주용 10미 1.3Kg/EA) 한국-※국내산','EA',5,29500,147500,0,147500);
#
# Insert into Order789Gsheet values (2017,09,30,'2017-09-30',12,2117214853,401354,'계란(특란_60g*30입 1.8Kg/PAC) 한국-※달걀(국내산)','PAC',2,7203,14406,0,14406);
#
# Insert into Order789Gsheet values (2017,09,30,'2017-09-30',13,2117214853,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',3,54300,162900,16290,179190);
#
# Insert into Order789Gsheet values (2017,09,30,'2017-09-30',14,2117254287,146391,'쉐프솔루션 햄야채볶음밥(300g/EA)','EA',10,1469,14690,1469,16159);
#
# Order count 14

# %%
fb = open('ftest.sql', 'w')

string = u'한글문장'

ustring = string.encode("utf-16")
fb.write(ustring)

fb.close()
