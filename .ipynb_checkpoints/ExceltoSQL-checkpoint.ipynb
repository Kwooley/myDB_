# %% [markdown]
# # Make SQL Insert Statement

# %% [markdown]
# ## from Excel file to SQL statements

# %%
from openpyxl import Workbook
from openpyxl.compat import range
from openpyxl.utils import get_column_letter
from openpyxl import load_workbook
from openpyxl import Workbook

# %%
print ord('T') - ord('A')
print ord('V') - ord('A')
print ord('P') - ord('A')
# Out:
# 19
# 21
# 15

# %% [markdown]
# ### Function splitdate
# ##### split 2017-10-31 string into 2017, 10, 31

# %%
def splitdate(orderdatestring):
    ody,odm, odd = orderdatestring.split('-')
    return({'year':ody, 'month':odm, 'day':odd})

# %% [markdown]
# ### Find Order row and make Insert stmt

# %%
wb = load_workbook(filename = './XLSX/2018MAR.xlsx')
ws = wb.active

num_rows = ws.max_row
#num_rows = 70
print num_rows

f = open("./SQL/2018MAR.sql", 'w')


prev_val = None
stmt_flag = date_found = False
order_cnt = total_order_cnt = 0
lcv = 0 
for row in ws.iter_rows(min_row=1, max_col=24, max_row=num_rows):
    sql_stmt = None
    sql_stmt_u = None
            
    # Find the row that contains the YMD
    # print unicode(row[0].value)[:6]
    if (unicode(row[0].value)[:6] == u'차량번호 :'):
        date_found = True
        YMD_string_org = unicode(row[15].value)
        YMD_string = YMD_string_org[7:]
        odate_dic = splitdate(YMD_string)
        print odate_dic
        
    # Find the 1st Row 
    if (row[0].value == 1) and ( prev_val == 'No.'):
        stmt_flag = True
    if (stmt_flag) and (date_found):
        # Find the Last Row
        if (unicode(prev_val).isdigit() == True ) and (unicode(row[0].value).isdigit() == False):
            stmt_flag = False
            date_found = False
            total_order_cnt += order_cnt
            print 'Order count', order_cnt, 'Total Order Count', total_order_cnt
            order_cnt = 0
        else:
            order_cnt += 1
            # 0 : iD / 1: OrderNO / 2: SKU / 5: pname / 14: metric / 16:qty / 18:price / 19:amount / 21:tax / 23:total
            tuple_dict = {'year':odate_dic['year'],
                          'month':odate_dic['month'],
                          'day':odate_dic['day'],
                          'YMD':YMD_string,
                          'dno':row[0].value,
                          'orderno':row[1].value,
                          'sku':row[2].value,
                          'pname':unicode(row[5].value).replace('\n','-'),
                          'metric':row[14].value, 
                          'qty':row[16].value,
                          'price':row[18].value,
                          'amount':row[19].value,
                          'tax':row[21].value,
                          'total':row[23].value
                         }
            
            sql_stmt = u'Insert into OrderAll values '
            sql_stmt += '('
            sql_stmt += str(tuple_dict['year'])+','
            sql_stmt += str(tuple_dict['month'])+','
            sql_stmt += str(tuple_dict['day'])+','
            sql_stmt += '\'' + tuple_dict['YMD'] + '\','
            sql_stmt += str(tuple_dict['dno'])+','
            sql_stmt += str(tuple_dict['orderno'])+','
            sql_stmt += str(tuple_dict['sku'])+','
            sql_stmt += '\'' + tuple_dict['pname'] + '\','
            sql_stmt += '\'' + tuple_dict['metric'] + '\','
            sql_stmt += str(tuple_dict['qty'])+','
            sql_stmt += str(tuple_dict['price'])+','
            sql_stmt += str(tuple_dict['amount'])+','
            sql_stmt += str(tuple_dict['tax'])+','
            sql_stmt += str(tuple_dict['total'])
            sql_stmt += ');\n'

            print sql_stmt
            #print ''
            # f.write(sql_stmt_r.replace(u'\ufeff','').encode("utf-16"))
            
            f.write(sql_stmt.encode('utf-8'))
            
                
    prev_val = row[0].value
    lcv += 1
    
    if lcv > num_rows:
        break


f.close()
# Out:
# 676
# {'month': u'03', 'day': u'01', 'year': u'2018'}
# Insert into OrderAll values (2018,03,01,'2018-03-01',1,2121060543,169394,'샐러드믹스(생활맥주용 150g*5입 750g/BOX) 한국 1EA/BOX-※국내산','BOX',2,14400,28800,0,28800);
#
# Insert into OrderAll values (2018,03,01,'2018-03-01',2,2121060543,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',2,54300,108600,10860,119460);
#
# Insert into OrderAll values (2018,03,01,'2018-03-01',3,2121060543,424783,'염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX','BOX',1,41400,41400,4140,45540);
#
# Order count 3 Total Order Count 3
# {'month': u'03', 'day': u'02', 'year': u'2018'}
# Insert into OrderAll values (2018,03,02,'2018-03-02',1,2121098261,138389,'이츠웰 초고추장(NEW 1Kg/EA)','EA',2,3000,6000,600,6600);
#
# Insert into OrderAll values (2018,03,02,'2018-03-02',2,2121098261,163815,'이츠웰 골뱅이캔(자연산 140g/EA)','EA',12,2800,33600,3360,36960);
#
# Insert into OrderAll values (2018,03,02,'2018-03-02',3,2121098261,215140,'양파드레싱(생활맥주용 2Kg/EA)','EA',3,9000,27000,2700,29700);
#
# Insert into OrderAll values (2018,03,02,'2018-03-02',4,2121098261,232931,'반건오징어(생활맥주용 10미 1.3Kg/EA) 한국-※국내산','EA',2,32000,64000,0,64000);
#
# Insert into OrderAll values (2018,03,02,'2018-03-02',5,2121098261,252265,'이츠웰 주방세제(리뉴얼_그린알로_3kg EA)','EA',1,2833,2833,283,3116);
#
# Insert into OrderAll values (2018,03,02,'2018-03-02',6,2121098261,116709,'리코스 나쵸칩(454g/EA) 미국-※미국','EA',12,2900,34800,3480,38280);
#
# Insert into OrderAll values (2018,03,02,'2018-03-02',7,2121141863,115364,'삼진 살사소스(2Kg/EA)','EA',1,9000,9000,900,9900);
#
# Insert into OrderAll values (2018,03,02,'2018-03-02',8,2121141863,119863,'삼조쎌텍 나쵸치즈소스(1Kg/EA)','EA',2,8300,16600,1660,18260);
#
# Order count 8 Total Order Count 11
# {'month': u'03', 'day': u'03', 'year': u'2018'}
# Insert into OrderAll values (2018,03,03,'2018-03-03',1,2121143291,251901,'냉동감자(생활맥주용 스파이시스트레이트컷 2.04Kg/EA)','EA',4,8960,35840,3584,39424);
#
# Insert into OrderAll values (2018,03,03,'2018-03-03',2,2121143291,145970,'치킨무(외식체인전용 5Kg/EA) 한국-※국내산','EA',2,5700,11400,0,11400);
#
# Insert into OrderAll values (2018,03,03,'2018-03-03',3,2121143291,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',5,6980,34900,3490,38390);
#
# Insert into OrderAll values (2018,03,03,'2018-03-03',4,2121143261,127454,'파로 할라페뇨(슬라이스 3Kg/EA)','EA',2,8500,17000,1700,18700);
#
# Insert into OrderAll values (2018,03,03,'2018-03-03',5,2121143291,251902,'냉동감자(생활맥주용 클리어코트슈스트링 2.04Kg/EA)','EA',4,8960,35840,3584,39424);
#
# Insert into OrderAll values (2018,03,03,'2018-03-03',6,2121143261,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',1,54300,54300,5430,59730);
#
# Insert into OrderAll values (2018,03,03,'2018-03-03',7,2121143261,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',2,54300,108600,10860,119460);
#
# Order count 7 Total Order Count 18
# {'month': u'03', 'day': u'05', 'year': u'2018'}
# Insert into OrderAll values (2018,03,05,'2018-03-05',1,2121212496,116981,'사세통상 버팔로윙스틱(1Kg/EA) 태국-※닭고기(태국산)','EA',3,9800,29400,2940,32340);
#
# Insert into OrderAll values (2018,03,05,'2018-03-05',2,2121212496,115722,'사세통상 버팔로윙(1Kg/EA) 태국-※닭고기(태국산)','EA',2,10500,21000,2100,23100);
#
# Insert into OrderAll values (2018,03,05,'2018-03-05',3,2121212496,247491,'뫼루니식품 레드소스(데일리비어용 양념치킨용 2Kg/EA)','EA',3,6900,20700,2070,22770);
#
# Insert into OrderAll values (2018,03,05,'2018-03-05',4,2121212496,176689,'소시지(생활맥주용 천연돈장_70g*4입 280g/EA) 한국-※돼지고기(국내산)','EA',15,4370,65550,6555,72105);
#
# Insert into OrderAll values (2018,03,05,'2018-03-05',5,2121212496,154639,'오뚜기 마요네즈(골드 스파우트팩 3.2Kg/EA)','EA',1,9800,9800,980,10780);
#
# Order count 5 Total Order Count 23
# {'month': u'03', 'day': u'06', 'year': u'2018'}
# Insert into OrderAll values (2018,03,06,'2018-03-06',1,2121252103,242910,'웰넛 건포도(500g/EA) 미국-※미국산','EA',3,3130,9390,939,10329);
#
# Insert into OrderAll values (2018,03,06,'2018-03-06',2,2121225765,206578,'길림양행 땅콩(껍질무_1/2태 1Kg/PAC)-※이력번호:10931-18-010262M','PAC',3,7000,21000,2100,23100);
#
# Insert into OrderAll values (2018,03,06,'2018-03-06',3,2121225765,171838,'팔도 비빔면(130g/EA) 40EA/BOX','BOX',1,26800,26800,2680,29480);
#
# Insert into OrderAll values (2018,03,06,'2018-03-06',4,2121225765,163815,'이츠웰 골뱅이캔(자연산 140g/EA)','EA',14,2800,39200,3920,43120);
#
# Insert into OrderAll values (2018,03,06,'2018-03-06',5,2121225765,118232,'스팸 햄캔(마일드 200g/EA)-※돼지고기(수입산 80%+국내산 20%) 96.27%','EA',15,2800,42000,4200,46200);
#
# Insert into OrderAll values (2018,03,06,'2018-03-06',6,2121212498,424783,'염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX','BOX',1,41400,41400,4140,45540);
#
# Insert into OrderAll values (2018,03,06,'2018-03-06',7,2121225765,100743,'코카콜라 콜라(캔_355ml 355g/EA) 한국 24EA/BOX-※국내산','BOX',1,16320,16320,1632,17952);
#
# Insert into OrderAll values (2018,03,06,'2018-03-06',8,2121225765,100744,'스프라이트 사이다(355ml 355g/EA) 한국 24EA/BOX-※국내산','BOX',1,13992,13992,1399,15391);
#
# Order count 8 Total Order Count 31
# {'month': u'03', 'day': u'07', 'year': u'2018'}
# Insert into OrderAll values (2018,03,07,'2018-03-07',1,2121254103,112371,'칵테일냅킨(생활맥주용 10000장입 BOX) 1EA/BOX','BOX',1,30000,30000,3000,33000);
#
# Insert into OrderAll values (2018,03,07,'2018-03-07',2,2121254103,401354,'계란(특란_60g*30입 1.8Kg/PAC) 한국-※달걀(국내산)','PAC',1,6506,6506,0,6506);
#
# Insert into OrderAll values (2018,03,07,'2018-03-07',3,2121254113,251902,'냉동감자(생활맥주용 클리어코트슈스트링 2.04Kg/EA)','EA',5,8960,44800,4480,49280);
#
# Insert into OrderAll values (2018,03,07,'2018-03-07',4,2121254113,232931,'반건오징어(생활맥주용 10미 1.3Kg/EA) 한국-※국내산','EA',2,32000,64000,0,64000);
#
# Insert into OrderAll values (2018,03,07,'2018-03-07',5,2121254113,201934,'소고기육포(생활맥주용 70g/EA) 호주-※호주산','EA',10,3970,39700,3970,43670);
#
# Insert into OrderAll values (2018,03,07,'2018-03-07',6,2121254113,178733,'물티슈(생활맥주용 500입 BOX) 1EA/BOX','BOX',1,11000,11000,1100,12100);
#
# Insert into OrderAll values (2018,03,07,'2018-03-07',7,2121254113,166412,'뫼루니식품 물결무늬파우더(데일리비어용 매운맛 5Kg/EA) 미국-※미국산','EA',2,13150,26300,2630,28930);
#
# Insert into OrderAll values (2018,03,07,'2018-03-07',8,2121254113,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',3,6980,20940,2094,23034);
#
# Order count 8 Total Order Count 39
# {'month': u'03', 'day': u'08', 'year': u'2018'}
# Insert into OrderAll values (2018,03,08,'2018-03-08',1,2121320509,145970,'치킨무(외식체인전용 5Kg/EA) 한국-※국내산','EA',2,5700,11400,0,11400);
#
# Order count 1 Total Order Count 40
# {'month': u'03', 'day': u'09', 'year': u'2018'}
# Insert into OrderAll values (2018,03,09,'2018-03-09',1,2121320669,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',2,54300,108600,10860,119460);
#
# Order count 1 Total Order Count 41
# {'month': u'03', 'day': u'10', 'year': u'2018'}
# Insert into OrderAll values (2018,03,10,'2018-03-10',1,2121359347,424783,'염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX','BOX',1,41400,41400,4140,45540);
#
# Insert into OrderAll values (2018,03,10,'2018-03-10',2,2121359349,232931,'반건오징어(생활맥주용 10미 1.3Kg/EA) 한국-※국내산','EA',1,32000,32000,0,32000);
#
# Insert into OrderAll values (2018,03,10,'2018-03-10',3,2121359349,176689,'소시지(생활맥주용 천연돈장_70g*4입 280g/EA) 한국-※돼지고기(국내산)','EA',10,4370,43700,4370,48070);
#
# Insert into OrderAll values (2018,03,10,'2018-03-10',4,2121359349,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',4,6980,27920,2792,30712);
#
# Order count 4 Total Order Count 45
# {'month': u'03', 'day': u'12', 'year': u'2018'}
# Insert into OrderAll values (2018,03,12,'2018-03-12',1,2121420097,251902,'냉동감자(생활맥주용 클리어코트슈스트링 2.04Kg/EA)','EA',5,8960,44800,4480,49280);
#
# Insert into OrderAll values (2018,03,12,'2018-03-12',2,2121420165,215139,'케이준드레싱(생활맥주용 2Kg/EA)','EA',1,9050,9050,905,9955);
#
# Insert into OrderAll values (2018,03,12,'2018-03-12',3,2121420097,201934,'소고기육포(생활맥주용 70g/EA) 호주-※호주산','EA',10,3970,39700,3970,43670);
#
# Insert into OrderAll values (2018,03,12,'2018-03-12',4,2121420097,145970,'치킨무(외식체인전용 5Kg/EA) 한국-※국내산','EA',2,5700,11400,0,11400);
#
# Insert into OrderAll values (2018,03,12,'2018-03-12',5,2121420165,119863,'삼조쎌텍 나쵸치즈소스(1Kg/EA)','EA',2,8300,16600,1660,18260);
#
# Insert into OrderAll values (2018,03,12,'2018-03-12',6,2121420097,116709,'리코스 나쵸칩(454g/EA) 미국-※미국','EA',5,2900,14500,1450,15950);
#
# Insert into OrderAll values (2018,03,12,'2018-03-12',7,2121396500,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',2,54300,108600,10860,119460);
#
# Order count 7 Total Order Count 52
# {'month': u'03', 'day': u'14', 'year': u'2018'}
# Insert into OrderAll values (2018,03,14,'2018-03-14',1,2121454449,242910,'웰넛 건포도(500g/EA) 미국-※미국산','EA',4,3130,12520,1252,13772);
#
# Insert into OrderAll values (2018,03,14,'2018-03-14',2,2121455542,251901,'냉동감자(생활맥주용 스파이시스트레이트컷 2.04Kg/EA)','EA',4,8960,35840,3584,39424);
#
# Insert into OrderAll values (2018,03,14,'2018-03-14',3,2121454449,169394,'샐러드믹스(생활맥주용 150g*5입 750g/BOX) 한국 1EA/BOX-※국내산','BOX',1,14400,14400,0,14400);
#
# Insert into OrderAll values (2018,03,14,'2018-03-14',4,2121455542,206578,'길림양행 땅콩(껍질무_1/2태 1Kg/PAC)-※이력번호:10931-18-010262M','PAC',2,7000,14000,1400,15400);
#
# Insert into OrderAll values (2018,03,14,'2018-03-14',5,2121455542,251902,'냉동감자(생활맥주용 클리어코트슈스트링 2.04Kg/EA)','EA',4,8960,35840,3584,39424);
#
# Insert into OrderAll values (2018,03,14,'2018-03-14',6,2121455542,143790,'이츠웰 참기름(NEW_캔_1L 916g/EA) 수입산-※참깨(베트남산,미얀마산)','EA',1,10600,10600,1060,11660);
#
# Insert into OrderAll values (2018,03,14,'2018-03-14',7,2121454449,509238,'종이봉투(180*110*350mm_100입 범용 PAC) 10EA/BOX','BOX',1,53400,53400,5340,58740);
#
# Insert into OrderAll values (2018,03,14,'2018-03-14',8,2121454449,424783,'염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX','BOX',1,41400,41400,4140,45540);
#
# Insert into OrderAll values (2018,03,14,'2018-03-14',9,2121455542,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',4,6980,27920,2792,30712);
#
# Order count 9 Total Order Count 61
# {'month': u'03', 'day': u'15', 'year': u'2018'}
# Insert into OrderAll values (2018,03,15,'2018-03-15',1,2121455539,526116,'유산지(생활맥주용 1000개 EA)','EA',1,30000,30000,3000,33000);
#
# Insert into OrderAll values (2018,03,15,'2018-03-15',2,2121454806,232931,'반건오징어(생활맥주용 10미 1.3Kg/EA) 한국-※국내산','EA',2,32000,64000,0,64000);
#
# Insert into OrderAll values (2018,03,15,'2018-03-15',3,2121454806,178733,'물티슈(생활맥주용 500입 BOX) 1EA/BOX','BOX',1,11000,11000,1100,12100);
#
# Order count 3 Total Order Count 64
# {'month': u'03', 'day': u'16', 'year': u'2018'}
# Insert into OrderAll values (2018,03,16,'2018-03-16',1,2121523103,100743,'코카콜라 콜라(캔_355ml 355g/EA) 한국 24EA/BOX-※국내산','BOX',1,16320,16320,1632,17952);
#
# Insert into OrderAll values (2018,03,16,'2018-03-16',2,2121523103,100744,'스프라이트 사이다(355ml 355g/EA) 한국 24EA/BOX-※국내산','BOX',1,13992,13992,1399,15391);
#
# Insert into OrderAll values (2018,03,16,'2018-03-16',3,2121454538,115364,'삼진 살사소스(2Kg/EA)','EA',2,9000,18000,1800,19800);
#
# Insert into OrderAll values (2018,03,16,'2018-03-16',4,2121523103,116709,'리코스 나쵸칩(454g/EA) 미국-※미국','EA',10,2900,29000,2900,31900);
#
# Insert into OrderAll values (2018,03,16,'2018-03-16',5,2121454538,169394,'샐러드믹스(생활맥주용 150g*5입 750g/BOX) 한국 1EA/BOX-※국내산','BOX',2,14400,28800,0,28800);
#
# Insert into OrderAll values (2018,03,16,'2018-03-16',6,2121523103,201934,'소고기육포(생활맥주용 70g/EA) 호주-※호주산','EA',10,3970,39700,3970,43670);
#
# Insert into OrderAll values (2018,03,16,'2018-03-16',7,2121523103,215140,'양파드레싱(생활맥주용 2Kg/EA)','EA',2,9000,18000,1800,19800);
#
# Insert into OrderAll values (2018,03,16,'2018-03-16',8,2121523103,247491,'뫼루니식품 레드소스(데일리비어용 양념치킨용 2Kg/EA)','EA',2,6900,13800,1380,15180);
#
# Insert into OrderAll values (2018,03,16,'2018-03-16',9,2121454538,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',2,54300,108600,10860,119460);
#
# Order count 9 Total Order Count 73
# {'month': u'03', 'day': u'17', 'year': u'2018'}
# Insert into OrderAll values (2018,03,17,'2018-03-17',1,2121523143,124531,'맥앤치즈볼(생활맥주용 50G*4입 200g/EA)','EA',10,3620,36200,3620,39820);
#
# Insert into OrderAll values (2018,03,17,'2018-03-17',2,2121523143,176689,'소시지(생활맥주용 천연돈장_70g*4입 280g/EA) 한국-※돼지고기(국내산)','EA',10,4370,43700,4370,48070);
#
# Order count 2 Total Order Count 75
# {'month': u'03', 'day': u'19', 'year': u'2018'}
# Insert into OrderAll values (2018,03,19,'2018-03-19',1,2121612781,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',2,6980,13960,1396,15356);
#
# Insert into OrderAll values (2018,03,19,'2018-03-19',2,2121612781,116981,'사세통상 버팔로윙스틱(1Kg/EA) 태국-※닭고기(태국산)','EA',2,9800,19600,1960,21560);
#
# Insert into OrderAll values (2018,03,19,'2018-03-19',3,2121612781,251902,'냉동감자(생활맥주용 클리어코트슈스트링 2.04Kg/EA)','EA',4,8960,35840,3584,39424);
#
# Insert into OrderAll values (2018,03,19,'2018-03-19',4,2121612781,232931,'반건오징어(생활맥주용 10미 1.3Kg/EA) 한국-※국내산','EA',2,32000,64000,0,64000);
#
# Insert into OrderAll values (2018,03,19,'2018-03-19',5,2121612864,242910,'웰넛 건포도(500g/EA) 미국-※미국산','EA',3,3130,9390,939,10329);
#
# Insert into OrderAll values (2018,03,19,'2018-03-19',6,2121612781,145970,'치킨무(외식체인전용 5Kg/EA) 한국-※국내산','EA',2,5700,11400,0,11400);
#
# Insert into OrderAll values (2018,03,19,'2018-03-19',7,2121612781,206578,'길림양행 땅콩(껍질무_1/2태 1Kg/PAC)-※이력번호:10931-18-010262M','PAC',4,7000,28000,2800,30800);
#
# Insert into OrderAll values (2018,03,19,'2018-03-19',8,2121612781,115722,'사세통상 버팔로윙(1Kg/EA) 태국-※닭고기(태국산)','EA',2,10500,21000,2100,23100);
#
# Order count 8 Total Order Count 83
# {'month': u'03', 'day': u'20', 'year': u'2018'}
# Insert into OrderAll values (2018,03,20,'2018-03-20',1,2121612873,178733,'물티슈(생활맥주용 500입 BOX) 1EA/BOX','BOX',2,11000,22000,2200,24200);
#
# Insert into OrderAll values (2018,03,20,'2018-03-20',2,2121612932,501123,'오라이트 고무장갑(미니_아이보리색 EA)','EA',4,600,2400,240,2640);
#
# Insert into OrderAll values (2018,03,20,'2018-03-20',3,2121612932,424783,'염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX','BOX',1,41400,41400,4140,45540);
#
# Insert into OrderAll values (2018,03,20,'2018-03-20',4,2121612873,252265,'이츠웰 주방세제(리뉴얼_그린알로_3kg EA)','EA',1,2833,2833,283,3116);
#
# Order count 4 Total Order Count 87
# {'month': u'03', 'day': u'21', 'year': u'2018'}
# Insert into OrderAll values (2018,03,21,'2018-03-21',1,2121613009,116709,'리코스 나쵸칩(454g/EA) 미국-※미국','EA',10,2900,29000,2900,31900);
#
# Insert into OrderAll values (2018,03,21,'2018-03-21',2,2121613009,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',4,6980,27920,2792,30712);
#
# Insert into OrderAll values (2018,03,21,'2018-03-21',3,2121613009,163815,'이츠웰 골뱅이캔(자연산 140g/EA)','EA',12,2800,33600,3360,36960);
#
# Insert into OrderAll values (2018,03,21,'2018-03-21',4,2121613002,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',2,54300,108600,10860,119460);
#
# Insert into OrderAll values (2018,03,21,'2018-03-21',5,2121613009,201934,'소고기육포(생활맥주용 70g/EA) 호주-※호주산','EA',15,3970,59550,5955,65505);
#
# Order count 5 Total Order Count 92
# {'month': u'03', 'day': u'22', 'year': u'2018'}
# Insert into OrderAll values (2018,03,22,'2018-03-22',1,2121674280,169394,'샐러드믹스(생활맥주용 150g*5입 750g/BOX) 한국 1EA/BOX-※국내산','BOX',1,14400,14400,0,14400);
#
# Order count 1 Total Order Count 93
# {'month': u'03', 'day': u'23', 'year': u'2018'}
# Insert into OrderAll values (2018,03,23,'2018-03-23',1,2121674314,424783,'염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX','BOX',1,41400,41400,4140,45540);
#
# Order count 1 Total Order Count 94
# {'month': u'03', 'day': u'24', 'year': u'2018'}
# Insert into OrderAll values (2018,03,24,'2018-03-24',1,2121749910,251901,'냉동감자(생활맥주용 스파이시스트레이트컷 2.04Kg/EA)','EA',4,8960,35840,3584,39424);
#
# Insert into OrderAll values (2018,03,24,'2018-03-24',2,2121749910,176689,'소시지(생활맥주용 천연돈장_70g*4입 280g/EA) 한국-※돼지고기(국내산)','EA',15,4370,65550,6555,72105);
#
# Insert into OrderAll values (2018,03,24,'2018-03-24',3,2121674307,169394,'샐러드믹스(생활맥주용 150g*5입 750g/BOX) 한국 1EA/BOX-※국내산','BOX',1,14400,14400,0,14400);
#
# Insert into OrderAll values (2018,03,24,'2018-03-24',4,2121749910,166412,'뫼루니식품 물결무늬파우더(데일리비어용 매운맛 5Kg/EA) 미국-※미국산','EA',1,13150,13150,1315,14465);
#
# Insert into OrderAll values (2018,03,24,'2018-03-24',5,2121749910,154639,'오뚜기 마요네즈(골드 스파우트팩 3.2Kg/EA)','EA',1,9800,9800,980,10780);
#
# Insert into OrderAll values (2018,03,24,'2018-03-24',6,2121749910,116981,'사세통상 버팔로윙스틱(1Kg/EA) 태국-※닭고기(태국산)','EA',2,9800,19600,1960,21560);
#
# Insert into OrderAll values (2018,03,24,'2018-03-24',7,2121749910,115722,'사세통상 버팔로윙(1Kg/EA) 태국-※닭고기(태국산)','EA',2,10500,21000,2100,23100);
#
# Insert into OrderAll values (2018,03,24,'2018-03-24',8,2121749910,251902,'냉동감자(생활맥주용 클리어코트슈스트링 2.04Kg/EA)','EA',4,8960,35840,3584,39424);
#
# Insert into OrderAll values (2018,03,24,'2018-03-24',9,2121674307,401354,'계란(특란_60g*30입 1.8Kg/PAC) 한국-※달걀(국내산)','PAC',1,6506,6506,0,6506);
#
# Order count 9 Total Order Count 103
# {'month': u'03', 'day': u'26', 'year': u'2018'}
# Insert into OrderAll values (2018,03,26,'2018-03-26',1,2121801660,118232,'스팸 햄캔(마일드 200g/EA)-※돼지고기(수입산 80%+국내산 20%) 96.27%','EA',12,2800,33600,3360,36960);
#
# Insert into OrderAll values (2018,03,26,'2018-03-26',2,2121806342,119863,'삼조쎌텍 나쵸치즈소스(1Kg/EA)','EA',1,8300,8300,830,9130);
#
# Insert into OrderAll values (2018,03,26,'2018-03-26',3,2121801660,138389,'이츠웰 초고추장(NEW 1Kg/EA)','EA',2,3000,6000,600,6600);
#
# Insert into OrderAll values (2018,03,26,'2018-03-26',4,2121801660,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',4,6980,27920,2792,30712);
#
# Insert into OrderAll values (2018,03,26,'2018-03-26',5,2121801660,206578,'길림양행 땅콩(껍질무_1/2태 1Kg/PAC)-※이력번호:10931-18-010262M','PAC',2,7000,14000,1400,15400);
#
# Insert into OrderAll values (2018,03,26,'2018-03-26',6,2121801660,247491,'뫼루니식품 레드소스(데일리비어용 양념치킨용 2Kg/EA)','EA',2,6900,13800,1380,15180);
#
# Insert into OrderAll values (2018,03,26,'2018-03-26',7,2121801660,251901,'냉동감자(생활맥주용 스파이시스트레이트컷 2.04Kg/EA)','EA',4,8960,35840,3584,39424);
#
# Insert into OrderAll values (2018,03,26,'2018-03-26',8,2121801660,251902,'냉동감자(생활맥주용 클리어코트슈스트링 2.04Kg/EA)','EA',6,8960,53760,5376,59136);
#
# Order count 8 Total Order Count 111
# {'month': u'03', 'day': u'27', 'year': u'2018'}
# Insert into OrderAll values (2018,03,27,'2018-03-27',1,2121834125,145970,'치킨무(외식체인전용 5Kg/EA) 한국-※국내산','EA',2,5700,11400,0,11400);
#
# Insert into OrderAll values (2018,03,27,'2018-03-27',2,2121801617,146391,'쉐프솔루션 햄야채볶음밥(300g/EA)','EA',20,1469,29380,2938,32318);
#
# Insert into OrderAll values (2018,03,27,'2018-03-27',3,2121801617,232931,'반건오징어(생활맥주용 10미 1.3Kg/EA) 한국-※국내산','EA',1,32000,32000,0,32000);
#
# Insert into OrderAll values (2018,03,27,'2018-03-27',4,2121801613,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',2,54300,108600,10860,119460);
#
# Insert into OrderAll values (2018,03,27,'2018-03-27',5,2121801613,424783,'염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX','BOX',1,41400,41400,4140,45540);
#
# Order count 5 Total Order Count 116
# {'month': u'03', 'day': u'28', 'year': u'2018'}
# Insert into OrderAll values (2018,03,28,'2018-03-28',1,2121806284,401354,'계란(특란_60g*30입 1.8Kg/PAC) 한국-※달걀(국내산)','PAC',1,6506,6506,0,6506);
#
# Order count 1 Total Order Count 117
# {'month': u'03', 'day': u'29', 'year': u'2018'}
# Insert into OrderAll values (2018,03,29,'2018-03-29',1,2121840403,127454,'파로 할라페뇨(슬라이스 3Kg/EA)','EA',2,8500,17000,1700,18700);
#
# Insert into OrderAll values (2018,03,29,'2018-03-29',2,2121873309,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',6,6980,41880,4188,46068);
#
# Insert into OrderAll values (2018,03,29,'2018-03-29',3,2121840403,169394,'샐러드믹스(생활맥주용 150g*5입 750g/BOX) 한국 1EA/BOX-※국내산','BOX',2,14400,28800,0,28800);
#
# Insert into OrderAll values (2018,03,29,'2018-03-29',4,2121873309,215140,'양파드레싱(생활맥주용 2Kg/EA)','EA',3,9000,27000,2700,29700);
#
# Insert into OrderAll values (2018,03,29,'2018-03-29',5,2121840403,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',2,54300,108600,10860,119460);
#
# Insert into OrderAll values (2018,03,29,'2018-03-29',6,2121840403,424783,'염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX','BOX',1,41400,41400,4140,45540);
#
# Order count 6 Total Order Count 123
# {'month': u'03', 'day': u'30', 'year': u'2018'}
# Insert into OrderAll values (2018,03,30,'2018-03-30',1,2121906574,116709,'리코스 나쵸칩(454g/EA) 미국-※미국','EA',10,2900,29000,2900,31900);
#
# Insert into OrderAll values (2018,03,30,'2018-03-30',2,2121906574,160016,'오뚜기 케찹(스파우트팩 3.3Kg/EA)','EA',2,3950,7900,790,8690);
#
# Insert into OrderAll values (2018,03,30,'2018-03-30',3,2121906574,176689,'소시지(생활맥주용 천연돈장_70g*4입 280g/EA) 한국-※돼지고기(국내산)','EA',10,4370,43700,4370,48070);
#
# Insert into OrderAll values (2018,03,30,'2018-03-30',4,2121906574,201934,'소고기육포(생활맥주용 70g/EA) 호주-※호주산','EA',10,3970,39700,3970,43670);
#
# Insert into OrderAll values (2018,03,30,'2018-03-30',5,2121906574,232931,'반건오징어(생활맥주용 10미 1.3Kg/EA) 한국-※국내산','EA',2,32000,64000,0,64000);
#
# Insert into OrderAll values (2018,03,30,'2018-03-30',6,2121907365,501326,'스파크 세탁세제(5kg EA)','EA',1,11470,11470,1147,12617);
#
# Order count 6 Total Order Count 129
# {'month': u'03', 'day': u'31', 'year': u'2018'}
# Insert into OrderAll values (2018,03,31,'2018-03-31',1,2121949675,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',1,54300,54300,5430,59730);
#
# Order count 1 Total Order Count 130

# %%
fb = open('ftest.sql', 'w')

string = u'한글문장'

ustring = string.encode("utf-16")
fb.write(ustring)

fb.close()
