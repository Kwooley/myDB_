# %% [markdown]
# # Make SQL Insert Statement

# %% [markdown]
# ## from Excel file to SQL statements

# %%
from openpyxl import Workbook
from openpyxl.compat import range
from openpyxl.utils import get_column_letter
from openpyxl import load_workbook
from openpyxl import Workbook

# %%
print ord('T') - ord('A')
print ord('V') - ord('A')
print ord('P') - ord('A')
# Out:
# 19
# 21
# 15

# %% [markdown]
# ### Function splitdate
# ##### split 2017-10-31 string into 2017, 10, 31

# %%
def splitdate(orderdatestring):
    ody,odm, odd = orderdatestring.split('-')
    return({'year':ody, 'month':odm, 'day':odd})

# %% [markdown]
# ### Find Order row and make Insert stmt

# %%
wb = load_workbook(filename = './XLSX/2018APR.xlsx')
ws = wb.active

num_rows = ws.max_row
#num_rows = 70
print num_rows

f = open("./SQL/2018APR.sql", 'w')


prev_val = None
stmt_flag = date_found = False
order_cnt = total_order_cnt = 0
lcv = 0 
for row in ws.iter_rows(min_row=1, max_col=24, max_row=num_rows):
    sql_stmt = None
    sql_stmt_u = None
            
    # Find the row that contains the YMD
    # print unicode(row[0].value)[:6]
    if (unicode(row[0].value)[:6] == u'차량번호 :'):
        date_found = True
        YMD_string_org = unicode(row[15].value)
        YMD_string = YMD_string_org[7:]
        odate_dic = splitdate(YMD_string)
        print odate_dic
        
    # Find the 1st Row 
    if (row[0].value == 1) and ( prev_val == 'No.'):
        stmt_flag = True
    if (stmt_flag) and (date_found):
        # Find the Last Row
        if (unicode(prev_val).isdigit() == True ) and (unicode(row[0].value).isdigit() == False):
            stmt_flag = False
            date_found = False
            total_order_cnt += order_cnt
            print 'Order count', order_cnt, 'Total Order Count', total_order_cnt
            order_cnt = 0
        else:
            order_cnt += 1
            # 0 : iD / 1: OrderNO / 2: SKU / 5: pname / 14: metric / 16:qty / 18:price / 19:amount / 21:tax / 23:total
            tuple_dict = {'year':odate_dic['year'],
                          'month':odate_dic['month'],
                          'day':odate_dic['day'],
                          'YMD':YMD_string,
                          'dno':row[0].value,
                          'orderno':row[1].value,
                          'sku':row[2].value,
                          'pname':unicode(row[5].value).replace('\n','-'),
                          'metric':row[14].value, 
                          'qty':row[16].value,
                          'price':row[18].value,
                          'amount':row[19].value,
                          'tax':row[21].value,
                          'total':row[23].value
                         }
            
            sql_stmt = u'Insert into OrderAll values '
            sql_stmt += '('
            sql_stmt += str(tuple_dict['year'])+','
            sql_stmt += str(tuple_dict['month'])+','
            sql_stmt += str(tuple_dict['day'])+','
            sql_stmt += '\'' + tuple_dict['YMD'] + '\','
            sql_stmt += str(tuple_dict['dno'])+','
            sql_stmt += str(tuple_dict['orderno'])+','
            sql_stmt += str(tuple_dict['sku'])+','
            sql_stmt += '\'' + tuple_dict['pname'] + '\','
            sql_stmt += '\'' + tuple_dict['metric'] + '\','
            sql_stmt += str(tuple_dict['qty'])+','
            sql_stmt += str(tuple_dict['price'])+','
            sql_stmt += str(tuple_dict['amount'])+','
            sql_stmt += str(tuple_dict['tax'])+','
            sql_stmt += str(tuple_dict['total'])
            sql_stmt += ');\n'

            print sql_stmt
            #print ''
            # f.write(sql_stmt_r.replace(u'\ufeff','').encode("utf-16"))
            
            f.write(sql_stmt.encode('utf-8'))
            
                
    prev_val = row[0].value
    lcv += 1
    
    if lcv > num_rows:
        break


f.close()
# Out:
# 579
# {'month': u'04', 'day': u'02', 'year': u'2018'}
# Insert into OrderAll values (2018,04,02,'2018-04-02',1,2121949678,424783,'염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX','BOX',2,41400,82800,8280,91080);
#
# Insert into OrderAll values (2018,04,02,'2018-04-02',2,2121993402,145970,'치킨무(외식체인전용 5Kg/EA) 한국-※국내산','EA',2,5700,11400,0,11400);
#
# Insert into OrderAll values (2018,04,02,'2018-04-02',3,2121993402,115722,'사세통상 버팔로윙(1Kg/EA) 태국-※닭고기(태국산)','EA',3,10500,31500,3150,34650);
#
# Insert into OrderAll values (2018,04,02,'2018-04-02',4,2121993402,116981,'사세통상 버팔로윙스틱(1Kg/EA) 태국-※닭고기(태국산)','EA',3,9800,29400,2940,32340);
#
# Insert into OrderAll values (2018,04,02,'2018-04-02',5,2121993402,251901,'냉동감자(생활맥주용 스파이시스트레이트컷 2.04Kg/EA)','EA',3,8960,26880,2688,29568);
#
# Insert into OrderAll values (2018,04,02,'2018-04-02',6,2121993402,251902,'냉동감자(생활맥주용 클리어코트슈스트링 2.04Kg/EA)','EA',3,8960,26880,2688,29568);
#
# Insert into OrderAll values (2018,04,02,'2018-04-02',7,2121993402,163815,'이츠웰 골뱅이캔(자연산 140g/EA)','EA',10,2800,28000,2800,30800);
#
# Insert into OrderAll values (2018,04,02,'2018-04-02',8,2121993402,100744,'스프라이트 사이다(355ml 355g/EA) 한국 24EA/BOX-※국내산','BOX',1,13992,13992,1399,15391);
#
# Insert into OrderAll values (2018,04,02,'2018-04-02',9,2121993402,178733,'물티슈(생활맥주용 500입 BOX) 1EA/BOX','BOX',2,11000,22000,2200,24200);
#
# Insert into OrderAll values (2018,04,02,'2018-04-02',10,2121993402,206578,'길림양행 땅콩(껍질무_1/2태 1Kg/PAC)-※이력번호:10931-18-020135M','PAC',4,7000,28000,2800,30800);
#
# Insert into OrderAll values (2018,04,02,'2018-04-02',11,2121993402,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',4,6980,27920,2792,30712);
#
# Insert into OrderAll values (2018,04,02,'2018-04-02',12,2121993402,176689,'소시지(생활맥주용 천연돈장_70g*4입 280g/EA) 한국-※돼지고기(국내산)','EA',10,4370,43700,4370,48070);
#
# Order count 12 Total Order Count 12
# {'month': u'04', 'day': u'03', 'year': u'2018'}
# Insert into OrderAll values (2018,04,03,'2018-04-03',1,2122019540,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',2,54300,108600,10860,119460);
#
# Insert into OrderAll values (2018,04,03,'2018-04-03',2,2122019540,169394,'샐러드믹스(생활맥주용 150g*5입 750g/BOX) 한국 1EA/BOX-※국내산','BOX',2,14400,28800,0,28800);
#
# Insert into OrderAll values (2018,04,03,'2018-04-03',3,2122019737,100743,'코카콜라 콜라(캔_355ml 355g/EA) 한국 24EA/BOX-※국내산','BOX',1,17040,17040,1704,18744);
#
# Insert into OrderAll values (2018,04,03,'2018-04-03',4,2122019737,201934,'소고기육포(생활맥주용 70g/EA) 호주-※호주산','EA',10,3970,39700,3970,43670);
#
# Insert into OrderAll values (2018,04,03,'2018-04-03',5,2122019540,401354,'계란(특란_60g*30입 1.8Kg/PAC) 한국-※달걀(국내산)','PAC',1,6506,6506,0,6506);
#
# Insert into OrderAll values (2018,04,03,'2018-04-03',6,2122019737,252265,'이츠웰 주방세제(리뉴얼_그린알로_3kg EA)','EA',1,2833,2833,283,3116);
#
# Insert into OrderAll values (2018,04,03,'2018-04-03',7,2122019737,512237,'이츠웰 페이퍼타올(핸드타올_4500매 BOX) 1EA/BOX','BOX',1,19500,19500,1950,21450);
#
# Insert into OrderAll values (2018,04,03,'2018-04-03',8,2122019540,514142,'이츠웰 다용도봉투(검정색_50L_63*82cm_100매 EA)','EA',4,6280,25120,2512,27632);
#
# Insert into OrderAll values (2018,04,03,'2018-04-03',9,2122019737,171838,'팔도 비빔면(130g/EA) 40EA/BOX','BOX',1,26800,26800,2680,29480);
#
# Insert into OrderAll values (2018,04,03,'2018-04-03',10,2122019737,232931,'반건오징어(생활맥주용 10미 1.3Kg/EA) 한국-※국내산','EA',2,32000,64000,0,64000);
#
# Insert into OrderAll values (2018,04,03,'2018-04-03',11,2122019737,118232,'스팸 햄캔(마일드 200g/EA)-※돼지고기(수입산 80%+국내산 20%) 96.27%','EA',7,2800,19600,1960,21560);
#
# Order count 11 Total Order Count 23
# {'month': u'04', 'day': u'05', 'year': u'2018'}
# Insert into OrderAll values (2018,04,05,'2018-04-05',1,2122086363,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',2,54300,108600,10860,119460);
#
# Insert into OrderAll values (2018,04,05,'2018-04-05',2,2122086363,169394,'샐러드믹스(생활맥주용 150g*5입 750g/BOX) 한국 1EA/BOX-※국내산','BOX',2,14400,28800,0,28800);
#
# Insert into OrderAll values (2018,04,05,'2018-04-05',3,2122086410,247491,'뫼루니식품 레드소스(데일리비어용 양념치킨용 2Kg/EA)','EA',3,6900,20700,2070,22770);
#
# Order count 3 Total Order Count 26
# {'month': u'04', 'day': u'06', 'year': u'2018'}
# Insert into OrderAll values (2018,04,06,'2018-04-06',1,2122122317,163815,'이츠웰 골뱅이캔(자연산 140g/EA)','EA',15,2800,42000,4200,46200);
#
# Order count 1 Total Order Count 27
# {'month': u'04', 'day': u'07', 'year': u'2018'}
# Insert into OrderAll values (2018,04,07,'2018-04-07',1,2122162682,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',6,6980,41880,4188,46068);
#
# Insert into OrderAll values (2018,04,07,'2018-04-07',2,2122162682,251902,'냉동감자(생활맥주용 클리어코트슈스트링 2.04Kg/EA)','EA',6,8960,53760,5376,59136);
#
# Insert into OrderAll values (2018,04,07,'2018-04-07',3,2122162833,401354,'계란(특란_60g*30입 1.8Kg/PAC) 한국-※달걀(국내산)','PAC',1,6506,6506,0,6506);
#
# Order count 3 Total Order Count 30
# {'month': u'04', 'day': u'10', 'year': u'2018'}
# Insert into OrderAll values (2018,04,10,'2018-04-10',1,2122222565,169394,'샐러드믹스(생활맥주용 150g*5입 750g/BOX) 한국 1EA/BOX-※국내산','BOX',2,14400,28800,0,28800);
#
# Insert into OrderAll values (2018,04,10,'2018-04-10',2,2122222565,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',1,54300,54300,5430,59730);
#
# Insert into OrderAll values (2018,04,10,'2018-04-10',3,2122222860,124531,'맥앤치즈볼(생활맥주용 50G*4입 200g/EA)','EA',12,3620,43440,4344,47784);
#
# Insert into OrderAll values (2018,04,10,'2018-04-10',4,2122222860,232931,'반건오징어(생활맥주용 10미 1.3Kg/EA) 한국-※국내산','EA',2,32000,64000,0,64000);
#
# Insert into OrderAll values (2018,04,10,'2018-04-10',5,2122222860,116709,'리코스 나쵸칩(454g/EA) 미국-※미국','EA',10,2900,29000,2900,31900);
#
# Insert into OrderAll values (2018,04,10,'2018-04-10',6,2122222565,115364,'삼진 살사소스(2Kg/EA)','EA',2,9000,18000,1800,19800);
#
# Insert into OrderAll values (2018,04,10,'2018-04-10',7,2122222860,145970,'치킨무(외식체인전용 5Kg/EA) 한국-※국내산','EA',2,5700,11400,0,11400);
#
# Insert into OrderAll values (2018,04,10,'2018-04-10',8,2122222860,100744,'스프라이트 사이다(355ml 355g/EA) 한국 24EA/BOX-※국내산','BOX',1,13992,13992,1399,15391);
#
# Order count 8 Total Order Count 38
# {'month': u'04', 'day': u'11', 'year': u'2018'}
# Insert into OrderAll values (2018,04,11,'2018-04-11',1,2122223046,166412,'뫼루니식품 물결무늬파우더(데일리비어용 매운맛 5Kg/EA) 미국-※미국산','EA',2,13150,26300,2630,28930);
#
# Order count 1 Total Order Count 39
# {'month': u'04', 'day': u'12', 'year': u'2018'}
# Insert into OrderAll values (2018,04,12,'2018-04-12',1,2122284061,424783,'염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX','BOX',1,41400,41400,4140,45540);
#
# Insert into OrderAll values (2018,04,12,'2018-04-12',2,2122322019,115722,'사세통상 버팔로윙(1Kg/EA) 태국-※닭고기(태국산)','EA',2,10500,21000,2100,23100);
#
# Insert into OrderAll values (2018,04,12,'2018-04-12',3,2122322019,116981,'사세통상 버팔로윙스틱(1Kg/EA) 태국-※닭고기(태국산)','EA',3,9800,29400,2940,32340);
#
# Insert into OrderAll values (2018,04,12,'2018-04-12',4,2122322019,201934,'소고기육포(생활맥주용 70g/EA) 호주-※호주산','EA',10,3970,39700,3970,43670);
#
# Insert into OrderAll values (2018,04,12,'2018-04-12',5,2122322019,206578,'길림양행 땅콩(껍질무_1/2태 1Kg/PAC)-※이력번호:10931-18-020135M','PAC',3,7000,21000,2100,23100);
#
# Insert into OrderAll values (2018,04,12,'2018-04-12',6,2122322125,242910,'웰넛 건포도(500g/EA) 미국-※미국산','EA',3,3130,9390,939,10329);
#
# Order count 6 Total Order Count 45
# {'month': u'04', 'day': u'13', 'year': u'2018'}
# Insert into OrderAll values (2018,04,13,'2018-04-13',1,2122322098,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',1,54300,54300,5430,59730);
#
# Insert into OrderAll values (2018,04,13,'2018-04-13',2,2122322320,251901,'냉동감자(생활맥주용 스파이시스트레이트컷 2.04Kg/EA)','EA',4,8960,35840,3584,39424);
#
# Insert into OrderAll values (2018,04,13,'2018-04-13',3,2122322320,251902,'냉동감자(생활맥주용 클리어코트슈스트링 2.04Kg/EA)','EA',4,8960,35840,3584,39424);
#
# Insert into OrderAll values (2018,04,13,'2018-04-13',4,2122322320,118232,'스팸 햄캔(마일드 200g/EA)-※돼지고기(수입산 80%+국내산 20%) 96.27%','EA',6,2800,16800,1680,18480);
#
# Order count 4 Total Order Count 49
# {'month': u'04', 'day': u'14', 'year': u'2018'}
# Insert into OrderAll values (2018,04,14,'2018-04-14',1,2122358108,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',1,54300,54300,5430,59730);
#
# Insert into OrderAll values (2018,04,14,'2018-04-14',2,2122361205,176689,'소시지(생활맥주용 천연돈장_70g*4입 280g/EA) 한국-※돼지고기(국내산)','EA',15,4370,65550,6555,72105);
#
# Insert into OrderAll values (2018,04,14,'2018-04-14',3,2122361205,138389,'이츠웰 초고추장(NEW 1Kg/EA)','EA',3,3000,9000,900,9900);
#
# Order count 3 Total Order Count 52
# {'month': u'04', 'day': u'16', 'year': u'2018'}
# Insert into OrderAll values (2018,04,16,'2018-04-16',1,2122397853,100743,'코카콜라 콜라(캔_355ml 355g/EA) 한국 24EA/BOX-※국내산','BOX',1,17040,17040,1704,18744);
#
# Insert into OrderAll values (2018,04,16,'2018-04-16',2,2122397853,100744,'스프라이트 사이다(355ml 355g/EA) 한국 24EA/BOX-※국내산','BOX',1,13992,13992,1399,15391);
#
# Insert into OrderAll values (2018,04,16,'2018-04-16',3,2122397853,232931,'반건오징어(생활맥주용 10미 1.3Kg/EA) 한국-※국내산','EA',2,32000,64000,0,64000);
#
# Insert into OrderAll values (2018,04,16,'2018-04-16',4,2122397853,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',4,6980,27920,2792,30712);
#
# Insert into OrderAll values (2018,04,16,'2018-04-16',5,2122397853,145970,'치킨무(외식체인전용 5Kg/EA) 한국-※국내산','EA',2,5700,11400,0,11400);
#
# Insert into OrderAll values (2018,04,16,'2018-04-16',6,2122397853,163815,'이츠웰 골뱅이캔(자연산 140g/EA)','EA',10,2800,28000,2800,30800);
#
# Order count 6 Total Order Count 58
# {'month': u'04', 'day': u'17', 'year': u'2018'}
# Insert into OrderAll values (2018,04,17,'2018-04-17',1,2122418835,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',1,54300,54300,5430,59730);
#
# Insert into OrderAll values (2018,04,17,'2018-04-17',2,2122418935,251901,'냉동감자(생활맥주용 스파이시스트레이트컷 2.04Kg/EA)','EA',4,8960,35840,3584,39424);
#
# Insert into OrderAll values (2018,04,17,'2018-04-17',3,2122418935,251902,'냉동감자(생활맥주용 클리어코트슈스트링 2.04Kg/EA)','EA',4,8960,35840,3584,39424);
#
# Order count 3 Total Order Count 61
# {'month': u'04', 'day': u'18', 'year': u'2018'}
# Insert into OrderAll values (2018,04,18,'2018-04-18',1,2122450916,424783,'염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX','BOX',1,41400,41400,4140,45540);
#
# Insert into OrderAll values (2018,04,18,'2018-04-18',2,2122450916,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',1,54300,54300,5430,59730);
#
# Insert into OrderAll values (2018,04,18,'2018-04-18',3,2122451428,116709,'리코스 나쵸칩(454g/EA) 미국-※미국','EA',10,2900,29000,2900,31900);
#
# Insert into OrderAll values (2018,04,18,'2018-04-18',4,2122450916,215139,'케이준드레싱(생활맥주용 2Kg/EA)','EA',1,9050,9050,905,9955);
#
# Order count 4 Total Order Count 65
# {'month': u'04', 'day': u'20', 'year': u'2018'}
# Insert into OrderAll values (2018,04,20,'2018-04-20',1,2122518216,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',2,54300,108600,10860,119460);
#
# Insert into OrderAll values (2018,04,20,'2018-04-20',2,2122518216,424783,'염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX','BOX',1,41400,41400,4140,45540);
#
# Insert into OrderAll values (2018,04,20,'2018-04-20',3,2122518216,401354,'계란(특란_60g*30입 1.8Kg/PAC) 한국-※달걀(국내산)','PAC',2,6506,13012,0,13012);
#
# Insert into OrderAll values (2018,04,20,'2018-04-20',4,2122518216,127454,'파로 할라페뇨(슬라이스 3Kg/EA)','EA',2,8500,17000,1700,18700);
#
# Order count 4 Total Order Count 69
# {'month': u'04', 'day': u'21', 'year': u'2018'}
# Insert into OrderAll values (2018,04,21,'2018-04-21',1,2122554830,232931,'반건오징어(생활맥주용 10미 1.3Kg/EA) 한국-※국내산','EA',2,32000,64000,0,64000);
#
# Insert into OrderAll values (2018,04,21,'2018-04-21',2,2122554830,201934,'소고기육포(생활맥주용 70g/EA) 호주-※호주산','EA',10,3970,39700,3970,43670);
#
# Insert into OrderAll values (2018,04,21,'2018-04-21',3,2122554830,178883,'코스터(생활맥주용 600매 EA)','EA',1,57000,57000,5700,62700);
#
# Insert into OrderAll values (2018,04,21,'2018-04-21',4,2122554830,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',3,6980,20940,2094,23034);
#
# Insert into OrderAll values (2018,04,21,'2018-04-21',5,2122554830,251901,'냉동감자(생활맥주용 스파이시스트레이트컷 2.04Kg/EA)','EA',3,8960,26880,2688,29568);
#
# Insert into OrderAll values (2018,04,21,'2018-04-21',6,2122554830,251902,'냉동감자(생활맥주용 클리어코트슈스트링 2.04Kg/EA)','EA',3,8960,26880,2688,29568);
#
# Insert into OrderAll values (2018,04,21,'2018-04-21',7,2122554830,215140,'양파드레싱(생활맥주용 2Kg/EA)','EA',2,9000,18000,1800,19800);
#
# Insert into OrderAll values (2018,04,21,'2018-04-21',8,2122554880,119863,'삼조쎌텍 나쵸치즈소스(1Kg/EA)','EA',2,8300,16600,1660,18260);
#
# Insert into OrderAll values (2018,04,21,'2018-04-21',9,2122554830,118232,'스팸 햄캔(마일드 200g/EA)-※돼지고기(수입산 80%+국내산 20%) 96.27%','EA',20,2800,56000,5600,61600);
#
# Insert into OrderAll values (2018,04,21,'2018-04-21',10,2122554880,169394,'샐러드믹스(생활맥주용 150g*5입 750g/BOX) 한국 1EA/BOX-※국내산','BOX',1,14400,14400,0,14400);
#
# Order count 10 Total Order Count 79
# {'month': u'04', 'day': u'23', 'year': u'2018'}
# Insert into OrderAll values (2018,04,23,'2018-04-23',1,2122601675,115722,'사세통상 버팔로윙(1Kg/EA) 태국-※닭고기(태국산)','EA',3,10500,31500,3150,34650);
#
# Insert into OrderAll values (2018,04,23,'2018-04-23',2,2122601675,116981,'사세통상 버팔로윙스틱(1Kg/EA) 태국-※닭고기(태국산)','EA',3,9800,29400,2940,32340);
#
# Insert into OrderAll values (2018,04,23,'2018-04-23',3,2122601675,176689,'소시지(생활맥주용 천연돈장_70g*4입 280g/EA) 한국-※돼지고기(국내산)','EA',15,4370,65550,6555,72105);
#
# Insert into OrderAll values (2018,04,23,'2018-04-23',4,2122601675,146391,'쉐프솔루션 햄야채볶음밥(300g/EA)','EA',20,1469,29380,2938,32318);
#
# Insert into OrderAll values (2018,04,23,'2018-04-23',5,2122601675,163815,'이츠웰 골뱅이캔(자연산 140g/EA)','EA',10,2800,28000,2800,30800);
#
# Insert into OrderAll values (2018,04,23,'2018-04-23',6,2122601675,145970,'치킨무(외식체인전용 5Kg/EA) 한국-※국내산','EA',2,5700,11400,0,11400);
#
# Insert into OrderAll values (2018,04,23,'2018-04-23',7,2122601675,206578,'길림양행 땅콩(껍질무_1/2태 1Kg/PAC)-※이력번호:10931-18-020135M','PAC',4,7000,28000,2800,30800);
#
# Insert into OrderAll values (2018,04,23,'2018-04-23',8,2122601907,242910,'웰넛 건포도(500g/EA) 미국-※미국산','EA',6,3130,18780,1878,20658);
#
# Insert into OrderAll values (2018,04,23,'2018-04-23',9,2122601907,526116,'유산지(생활맥주용 1000개 EA)','EA',1,30000,30000,3000,33000);
#
# Insert into OrderAll values (2018,04,23,'2018-04-23',10,2122601675,252265,'이츠웰 주방세제(리뉴얼_그린알로_3kg EA)','EA',2,2833,5666,567,6233);
#
# Insert into OrderAll values (2018,04,23,'2018-04-23',11,2122601675,160016,'오뚜기 케찹(스파우트팩 3.3Kg/EA)','EA',2,3950,7900,790,8690);
#
# Insert into OrderAll values (2018,04,23,'2018-04-23',12,2122601675,247491,'뫼루니식품 레드소스(데일리비어용 양념치킨용 2Kg/EA)','EA',3,6900,20700,2070,22770);
#
# Insert into OrderAll values (2018,04,23,'2018-04-23',13,2122601675,154639,'오뚜기 마요네즈(골드 스파우트팩 3.2Kg/EA)','EA',1,9800,9800,980,10780);
#
# Insert into OrderAll values (2018,04,23,'2018-04-23',14,2122601675,166412,'뫼루니식품 물결무늬파우더(데일리비어용 매운맛 5Kg/EA) 미국-※미국산','EA',2,13150,26300,2630,28930);
#
# Order count 14 Total Order Count 93
# {'month': u'04', 'day': u'24', 'year': u'2018'}
# Insert into OrderAll values (2018,04,24,'2018-04-24',1,2122601909,177050,'기름여과지(생활맥주용 100매 BOX) 1EA/BOX','BOX',1,49000,49000,4900,53900);
#
# Insert into OrderAll values (2018,04,24,'2018-04-24',2,2122613863,424783,'염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX','BOX',1,41400,41400,4140,45540);
#
# Insert into OrderAll values (2018,04,24,'2018-04-24',3,2122601909,116709,'리코스 나쵸칩(454g/EA) 미국-※미국','EA',10,2900,29000,2900,31900);
#
# Insert into OrderAll values (2018,04,24,'2018-04-24',4,2122613863,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',1,54300,54300,5430,59730);
#
# Order count 4 Total Order Count 97
# {'month': u'04', 'day': u'25', 'year': u'2018'}
# Insert into OrderAll values (2018,04,25,'2018-04-25',1,2122613865,169394,'샐러드믹스(생활맥주용 150g*5입 750g/BOX) 한국 1EA/BOX-※국내산','BOX',1,14400,14400,0,14400);
#
# Insert into OrderAll values (2018,04,25,'2018-04-25',2,2122678537,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',4,6980,27920,2792,30712);
#
# Insert into OrderAll values (2018,04,25,'2018-04-25',3,2122678537,251902,'냉동감자(생활맥주용 클리어코트슈스트링 2.04Kg/EA)','EA',4,8960,35840,3584,39424);
#
# Insert into OrderAll values (2018,04,25,'2018-04-25',4,2122678537,178733,'물티슈(생활맥주용 500입 BOX) 1EA/BOX','BOX',2,11000,22000,2200,24200);
#
# Order count 4 Total Order Count 101
# {'month': u'04', 'day': u'26', 'year': u'2018'}
# Insert into OrderAll values (2018,04,26,'2018-04-26',1,2122614168,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',1,54300,54300,5430,59730);
#
# Insert into OrderAll values (2018,04,26,'2018-04-26',2,2122614168,424783,'염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX','BOX',1,41400,41400,4140,45540);
#
# Insert into OrderAll values (2018,04,26,'2018-04-26',3,2122614168,169394,'샐러드믹스(생활맥주용 150g*5입 750g/BOX) 한국 1EA/BOX-※국내산','BOX',2,14400,28800,0,28800);
#
# Insert into OrderAll values (2018,04,26,'2018-04-26',4,2122678683,201934,'소고기육포(생활맥주용 70g/EA) 호주-※호주산','EA',10,3970,39700,3970,43670);
#
# Order count 4 Total Order Count 105
# {'month': u'04', 'day': u'27', 'year': u'2018'}
# Insert into OrderAll values (2018,04,27,'2018-04-27',1,2122712515,135267,'그라나파다노치즈(포션 200g/EA)','EA',1,6600,6600,660,7260);
#
# Insert into OrderAll values (2018,04,27,'2018-04-27',2,2122712515,105409,'아담스 파마산치즈파우더(1Kg/EA)','EA',1,11000,11000,1100,12100);
#
# Insert into OrderAll values (2018,04,27,'2018-04-27',3,2122743517,171838,'팔도 비빔면(130g/EA) 40EA/BOX','BOX',1,26800,26800,2680,29480);
#
# Order count 3 Total Order Count 108
# {'month': u'04', 'day': u'28', 'year': u'2018'}
# Insert into OrderAll values (2018,04,28,'2018-04-28',1,2122743560,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',4,6980,27920,2792,30712);
#
# Insert into OrderAll values (2018,04,28,'2018-04-28',2,2122743560,251901,'냉동감자(생활맥주용 스파이시스트레이트컷 2.04Kg/EA)','EA',2,8960,17920,1792,19712);
#
# Insert into OrderAll values (2018,04,28,'2018-04-28',3,2122743560,251902,'냉동감자(생활맥주용 클리어코트슈스트링 2.04Kg/EA)','EA',3,8960,26880,2688,29568);
#
# Insert into OrderAll values (2018,04,28,'2018-04-28',4,2122743560,232931,'반건오징어(생활맥주용 10미 1.3Kg/EA) 한국-※국내산','EA',2,32000,64000,0,64000);
#
# Insert into OrderAll values (2018,04,28,'2018-04-28',5,2122743560,176689,'소시지(생활맥주용 천연돈장_70g*4입 280g/EA) 한국-※돼지고기(국내산)','EA',10,4370,43700,4370,48070);
#
# Insert into OrderAll values (2018,04,28,'2018-04-28',6,2122743560,163815,'이츠웰 골뱅이캔(자연산 140g/EA)','EA',10,2800,28000,2800,30800);
#
# Insert into OrderAll values (2018,04,28,'2018-04-28',7,2122743560,252265,'이츠웰 주방세제(리뉴얼_그린알로_3kg EA)','EA',2,2833,5666,567,6233);
#
# Order count 7 Total Order Count 115
# {'month': u'04', 'day': u'30', 'year': u'2018'}
# Insert into OrderAll values (2018,04,30,'2018-04-30',1,2122813047,145970,'치킨무(외식체인전용 5Kg/EA) 한국-※국내산','EA',2,5700,11400,0,11400);
#
# Insert into OrderAll values (2018,04,30,'2018-04-30',2,2122813047,215140,'양파드레싱(생활맥주용 2Kg/EA)','EA',3,9000,27000,2700,29700);
#
# Order count 2 Total Order Count 117

# %%
fb = open('ftest.sql', 'w')

string = u'한글문장'

ustring = string.encode("utf-16")
fb.write(ustring)

fb.close()
