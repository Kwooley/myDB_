# %% [markdown]
# # Make SQL Insert Statement

# %% [markdown]
# ## from Excel file to SQL statements

# %%
from openpyxl import Workbook
from openpyxl.compat import range
from openpyxl.utils import get_column_letter
from openpyxl import load_workbook
from openpyxl import Workbook

# %%
print ord('T') - ord('A')
print ord('V') - ord('A')
print ord('P') - ord('A')
# Out:
# 19
# 21
# 15

# %% [markdown]
# ### Function splitdate
# ##### split 2017-10-31 string into 2017, 10, 31

# %%
def splitdate(orderdatestring):
    ody,odm, odd = orderdatestring.split('-')
    return({'year':ody, 'month':odm, 'day':odd})

# %% [markdown]
# ### Find Order row and make Insert stmt

# %%
wb = load_workbook(filename = '2018FEB.xlsx')
ws = wb.active

num_rows = ws.max_row
#num_rows = 70
print num_rows

f = open("2018FEB.sql", 'w')


prev_val = None
stmt_flag = date_found = False
order_cnt = total_order_cnt = 0
lcv = 0 
for row in ws.iter_rows(min_row=1, max_col=24, max_row=num_rows):
    sql_stmt = None
    sql_stmt_u = None
            
    # Find the row that contains the YMD
    # print unicode(row[0].value)[:6]
    if (unicode(row[0].value)[:6] == u'차량번호 :'):
        date_found = True
        YMD_string_org = unicode(row[15].value)
        YMD_string = YMD_string_org[7:]
        odate_dic = splitdate(YMD_string)
        print odate_dic
        
    # Find the 1st Row 
    if (row[0].value == 1) and ( prev_val == 'No.'):
        stmt_flag = True
    if (stmt_flag) and (date_found):
        # Find the Last Row
        if (unicode(prev_val).isdigit() == True ) and (unicode(row[0].value).isdigit() == False):
            stmt_flag = False
            date_found = False
            total_order_cnt += order_cnt
            print 'Order count', order_cnt, 'Total Order Count', total_order_cnt
            order_cnt = 0
        else:
            order_cnt += 1
            # 0 : iD / 1: OrderNO / 2: SKU / 5: pname / 14: metric / 16:qty / 18:price / 19:amount / 21:tax / 23:total
            tuple_dict = {'year':odate_dic['year'],
                          'month':odate_dic['month'],
                          'day':odate_dic['day'],
                          'YMD':YMD_string,
                          'dno':row[0].value,
                          'orderno':row[1].value,
                          'sku':row[2].value,
                          'pname':unicode(row[5].value).replace('\n','-'),
                          'metric':row[14].value, 
                          'qty':row[16].value,
                          'price':row[18].value,
                          'amount':row[19].value,
                          'tax':row[21].value,
                          'total':row[23].value
                         }
            
            sql_stmt = u'Insert into OrderAll values '
            sql_stmt += '('
            sql_stmt += str(tuple_dict['year'])+','
            sql_stmt += str(tuple_dict['month'])+','
            sql_stmt += str(tuple_dict['day'])+','
            sql_stmt += '\'' + tuple_dict['YMD'] + '\','
            sql_stmt += str(tuple_dict['dno'])+','
            sql_stmt += str(tuple_dict['orderno'])+','
            sql_stmt += str(tuple_dict['sku'])+','
            sql_stmt += '\'' + tuple_dict['pname'] + '\','
            sql_stmt += '\'' + tuple_dict['metric'] + '\','
            sql_stmt += str(tuple_dict['qty'])+','
            sql_stmt += str(tuple_dict['price'])+','
            sql_stmt += str(tuple_dict['amount'])+','
            sql_stmt += str(tuple_dict['tax'])+','
            sql_stmt += str(tuple_dict['total'])
            sql_stmt += ');\n'

            print sql_stmt
            #print ''
            # f.write(sql_stmt_r.replace(u'\ufeff','').encode("utf-16"))
            
            f.write(sql_stmt.encode('utf-8'))
            
                
    prev_val = row[0].value
    lcv += 1
    
    if lcv > num_rows:
        break


f.close()
# Out:
# 405
# {'month': u'01', 'day': u'12', 'year': u'2018'}
# Insert into OrderAll values (2018,01,12,'2018-01-12',1,2119924564,145970,'치킨무(외식체인전용 5Kg/EA) 한국-※국내산','EA',2,5700,11400,0,11400);
#
# Insert into OrderAll values (2018,01,12,'2018-01-12',2,2119924564,232931,'반건오징어(생활맥주용 10미 1.3Kg/EA) 한국-※국내산','EA',1,32000,32000,0,32000);
#
# Insert into OrderAll values (2018,01,12,'2018-01-12',3,2119925138,127454,'파로 할라페뇨(슬라이스 3Kg/EA)','EA',1,8500,8500,850,9350);
#
# Order count 3 Total Order Count 3
# {'month': u'01', 'day': u'13', 'year': u'2018'}
# Insert into OrderAll values (2018,01,13,'2018-01-13',1,2119926544,251902,'냉동감자(생활맥주용 클리어코트슈스트링 2.04Kg/EA)','EA',3,8960,26880,2688,29568);
#
# Insert into OrderAll values (2018,01,13,'2018-01-13',2,2119926544,251901,'냉동감자(생활맥주용 스파이시스트레이트컷 2.04Kg/EA)','EA',3,8960,26880,2688,29568);
#
# Insert into OrderAll values (2018,01,13,'2018-01-13',3,2119926544,171838,'팔도 비빔면(130g/EA) 40EA/BOX','BOX',1,26800,26800,2680,29480);
#
# Insert into OrderAll values (2018,01,13,'2018-01-13',4,2119926544,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',3,6980,20940,2094,23034);
#
# Insert into OrderAll values (2018,01,13,'2018-01-13',5,2119924606,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',2,54300,108600,10860,119460);
#
# Insert into OrderAll values (2018,01,13,'2018-01-13',6,2119924606,424783,'염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX','BOX',1,41400,41400,4140,45540);
#
# Order count 6 Total Order Count 9
# {'month': u'01', 'day': u'15', 'year': u'2018'}
# Insert into OrderAll values (2018,01,15,'2018-01-15',1,2119966086,138389,'이츠웰 초고추장(NEW 1Kg/EA)','EA',3,3000,9000,900,9900);
#
# Insert into OrderAll values (2018,01,15,'2018-01-15',2,2119966086,145970,'치킨무(외식체인전용 5Kg/EA) 한국-※국내산','EA',3,5700,17100,0,17100);
#
# Insert into OrderAll values (2018,01,15,'2018-01-15',3,2119966086,146391,'쉐프솔루션 햄야채볶음밥(300g/EA)','EA',10,1469,14690,1469,16159);
#
# Insert into OrderAll values (2018,01,15,'2018-01-15',4,2119966086,166412,'뫼루니식품 물결무늬파우더(데일리비어용 매운맛 5Kg/EA) 미국-※미국산','EA',1,13150,13150,1315,14465);
#
# Insert into OrderAll values (2018,01,15,'2018-01-15',5,2119956599,169394,'샐러드믹스(생활맥주용 150g*5입 750g/BOX) 한국 1EA/BOX-※국내산','BOX',2,14400,28800,0,28800);
#
# Insert into OrderAll values (2018,01,15,'2018-01-15',6,2119966086,176689,'소시지(생활맥주용 천연돈장_70g*4입 280g/EA) 한국-※돼지고기(국내산)','EA',10,4370,43700,4370,48070);
#
# Order count 6 Total Order Count 15
# {'month': u'01', 'day': u'17', 'year': u'2018'}
# Insert into OrderAll values (2018,01,17,'2018-01-17',1,2120007461,116981,'사세통상 버팔로윙스틱(1Kg/EA) 태국-※닭고기(태국산)','EA',4,9800,39200,3920,43120);
#
# Insert into OrderAll values (2018,01,17,'2018-01-17',2,2120007461,115722,'사세통상 버팔로윙(1Kg/EA) 태국-※닭고기(태국산)','EA',3,10500,31500,3150,34650);
#
# Insert into OrderAll values (2018,01,17,'2018-01-17',3,2120007461,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',5,6980,34900,3490,38390);
#
# Insert into OrderAll values (2018,01,17,'2018-01-17',4,2120007575,526116,'유산지(생활맥주용 1000개 EA)','EA',1,30000,30000,3000,33000);
#
# Insert into OrderAll values (2018,01,17,'2018-01-17',5,2120007461,251902,'냉동감자(생활맥주용 클리어코트슈스트링 2.04Kg/EA)','EA',3,8960,26880,2688,29568);
#
# Insert into OrderAll values (2018,01,17,'2018-01-17',6,2120007461,251901,'냉동감자(생활맥주용 스파이시스트레이트컷 2.04Kg/EA)','EA',3,8960,26880,2688,29568);
#
# Insert into OrderAll values (2018,01,17,'2018-01-17',7,2120007461,232931,'반건오징어(생활맥주용 10미 1.3Kg/EA) 한국-※국내산','EA',2,32000,64000,0,64000);
#
# Insert into OrderAll values (2018,01,17,'2018-01-17',8,2120007461,201934,'소고기육포(생활맥주용 70g/EA) 호주-※호주산','EA',5,3970,19850,1985,21835);
#
# Order count 8 Total Order Count 23
# {'month': u'01', 'day': u'18', 'year': u'2018'}
# Insert into OrderAll values (2018,01,18,'2018-01-18',1,2120065244,251902,'냉동감자(생활맥주용 클리어코트슈스트링 2.04Kg/EA)','EA',3,8960,26880,2688,29568);
#
# Insert into OrderAll values (2018,01,18,'2018-01-18',2,2120007583,177050,'기름여과지(생활맥주용 100매 BOX) 1EA/BOX','BOX',0,49000,0,0,0);
#
# Insert into OrderAll values (2018,01,18,'2018-01-18',3,2120065244,116709,'리코스 나쵸칩(454g/EA) 미국-※미국','EA',5,2900,14500,1450,15950);
#
# Insert into OrderAll values (2018,01,18,'2018-01-18',4,2120038578,424783,'염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX','BOX',2,41400,82800,8280,91080);
#
# Order count 4 Total Order Count 27
# {'month': u'01', 'day': u'19', 'year': u'2018'}
# Insert into OrderAll values (2018,01,19,'2018-01-19',1,2120066737,160016,'오뚜기 케찹(스파우트팩 3.3Kg/EA)','EA',2,3950,7900,790,8690);
#
# Insert into OrderAll values (2018,01,19,'2018-01-19',2,2120066737,124531,'맥앤치즈볼(생활맥주용 50G*4입 200g/EA)','EA',5,3620,18100,1810,19910);
#
# Insert into OrderAll values (2018,01,19,'2018-01-19',3,2120102699,119863,'삼조쎌텍 나쵸치즈소스(1Kg/EA)','EA',2,8300,16600,1660,18260);
#
# Insert into OrderAll values (2018,01,19,'2018-01-19',4,2120066737,163815,'이츠웰 골뱅이캔(자연산 140g/EA)','EA',5,2800,14000,1400,15400);
#
# Insert into OrderAll values (2018,01,19,'2018-01-19',5,2120066737,201934,'소고기육포(생활맥주용 70g/EA) 호주-※호주산','EA',15,3970,59550,5955,65505);
#
# Insert into OrderAll values (2018,01,19,'2018-01-19',6,2120066737,215140,'양파드레싱(생활맥주용 2Kg/EA)','EA',2,9000,18000,1800,19800);
#
# Insert into OrderAll values (2018,01,19,'2018-01-19',7,2120102699,115364,'삼진 살사소스(2Kg/EA)','EA',2,9000,18000,1800,19800);
#
# Insert into OrderAll values (2018,01,19,'2018-01-19',8,2120066737,118232,'스팸 햄캔(마일드 200g/EA)-※돼지고기(수입산 80%+국내산 20%) 96.27%','EA',10,2800,28000,2800,30800);
#
# Order count 8 Total Order Count 35
# {'month': u'01', 'day': u'20', 'year': u'2018'}
# Insert into OrderAll values (2018,01,20,'2018-01-20',1,2120102555,206578,'길림양행 땅콩(껍질무_1/2태 1Kg/PAC)-※이력번호:10931-18-010027M','PAC',2,7000,14000,1400,15400);
#
# Insert into OrderAll values (2018,01,20,'2018-01-20',2,2120102530,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',2,54300,108600,10860,119460);
#
# Insert into OrderAll values (2018,01,20,'2018-01-20',3,2120102530,242910,'웰넛 건포도(500g/EA) 미국-※미국산','EA',2,3130,6260,626,6886);
#
# Insert into OrderAll values (2018,01,20,'2018-01-20',4,2120102555,116709,'리코스 나쵸칩(454g/EA) 미국-※미국','EA',5,2900,14500,1450,15950);
#
# Insert into OrderAll values (2018,01,20,'2018-01-20',5,2120102530,169394,'샐러드믹스(생활맥주용 150g*5입 750g/BOX) 한국 1EA/BOX-※국내산','BOX',2,14400,28800,0,28800);
#
# Insert into OrderAll values (2018,01,20,'2018-01-20',6,2120102555,176689,'소시지(생활맥주용 천연돈장_70g*4입 280g/EA) 한국-※돼지고기(국내산)','EA',10,4370,43700,4370,48070);
#
# Order count 6 Total Order Count 41
# {'month': u'01', 'day': u'22', 'year': u'2018'}
# Insert into OrderAll values (2018,01,22,'2018-01-22',1,2120138661,251901,'냉동감자(생활맥주용 스파이시스트레이트컷 2.04Kg/EA)','EA',5,8960,44800,4480,49280);
#
# Insert into OrderAll values (2018,01,22,'2018-01-22',2,2120138661,247491,'뫼루니식품 레드소스(데일리비어용 양념치킨용 2Kg/EA)','EA',3,6900,20700,2070,22770);
#
# Insert into OrderAll values (2018,01,22,'2018-01-22',3,2120138661,215140,'양파드레싱(생활맥주용 2Kg/EA)','EA',2,9000,18000,1800,19800);
#
# Insert into OrderAll values (2018,01,22,'2018-01-22',4,2120138661,163815,'이츠웰 골뱅이캔(자연산 140g/EA)','EA',9,2800,25200,2520,27720);
#
# Insert into OrderAll values (2018,01,22,'2018-01-22',5,2120138661,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',7,6980,48860,4886,53746);
#
# Insert into OrderAll values (2018,01,22,'2018-01-22',6,2120144802,127454,'파로 할라페뇨(슬라이스 3Kg/EA)','EA',2,8500,17000,1700,18700);
#
# Insert into OrderAll values (2018,01,22,'2018-01-22',7,2120138661,251902,'냉동감자(생활맥주용 클리어코트슈스트링 2.04Kg/EA)','EA',5,8960,44800,4480,49280);
#
# Insert into OrderAll values (2018,01,22,'2018-01-22',8,2120138661,116709,'리코스 나쵸칩(454g/EA) 미국-※미국','EA',7,2900,20300,2030,22330);
#
# Order count 8 Total Order Count 49
# {'month': u'01', 'day': u'23', 'year': u'2018'}
# Insert into OrderAll values (2018,01,23,'2018-01-23',1,2120144836,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',2,54300,108600,10860,119460);
#
# Insert into OrderAll values (2018,01,23,'2018-01-23',2,2120158601,232931,'반건오징어(생활맥주용 10미 1.3Kg/EA) 한국-※국내산','EA',1,32000,32000,0,32000);
#
# Insert into OrderAll values (2018,01,23,'2018-01-23',3,2120144836,135267,'그라나파다노치즈(포션 200g/EA)','EA',1,6600,6600,660,7260);
#
# Insert into OrderAll values (2018,01,23,'2018-01-23',4,2120158601,100743,'코카콜라 콜라(캔_355ml 355g/EA) 한국 24EA/BOX-※국내산','BOX',1,16320,16320,1632,17952);
#
# Insert into OrderAll values (2018,01,23,'2018-01-23',5,2120144836,424783,'염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX','BOX',1,41400,41400,4140,45540);
#
# Order count 5 Total Order Count 54
# {'month': u'01', 'day': u'24', 'year': u'2018'}
# Insert into OrderAll values (2018,01,24,'2018-01-24',1,2120217938,116981,'사세통상 버팔로윙스틱(1Kg/EA) 태국-※닭고기(태국산)','EA',1,9800,9800,980,10780);
#
# Insert into OrderAll values (2018,01,24,'2018-01-24',2,2120217938,232931,'반건오징어(생활맥주용 10미 1.3Kg/EA) 한국-※국내산','EA',1,32000,32000,0,32000);
#
# Insert into OrderAll values (2018,01,24,'2018-01-24',3,2120217938,163815,'이츠웰 골뱅이캔(자연산 140g/EA)','EA',10,2800,28000,2800,30800);
#
# Insert into OrderAll values (2018,01,24,'2018-01-24',4,2120217938,124531,'맥앤치즈볼(생활맥주용 50G*4입 200g/EA)','EA',5,3620,18100,1810,19910);
#
# Order count 4 Total Order Count 58
# {'month': u'01', 'day': u'25', 'year': u'2018'}
# Insert into OrderAll values (2018,01,25,'2018-01-25',1,2120245541,215140,'양파드레싱(생활맥주용 2Kg/EA)','EA',3,9000,27000,2700,29700);
#
# Insert into OrderAll values (2018,01,25,'2018-01-25',2,2120246211,215139,'케이준드레싱(생활맥주용 2Kg/EA)','EA',1,9050,9050,905,9955);
#
# Insert into OrderAll values (2018,01,25,'2018-01-25',3,2120245541,206578,'길림양행 땅콩(껍질무_1/2태 1Kg/PAC)-※이력번호:10931-18-010027M','PAC',3,7000,21000,2100,23100);
#
# Insert into OrderAll values (2018,01,25,'2018-01-25',4,2120245541,178733,'물티슈(생활맥주용 500입 BOX) 1EA/BOX','BOX',1,11000,11000,1100,12100);
#
# Insert into OrderAll values (2018,01,25,'2018-01-25',5,2120245541,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',2,6980,13960,1396,15356);
#
# Insert into OrderAll values (2018,01,25,'2018-01-25',6,2120246211,242910,'웰넛 건포도(500g/EA) 미국-※미국산','EA',3,3130,9390,939,10329);
#
# Insert into OrderAll values (2018,01,25,'2018-01-25',7,2120245541,251902,'냉동감자(생활맥주용 클리어코트슈스트링 2.04Kg/EA)','EA',3,8960,26880,2688,29568);
#
# Order count 7 Total Order Count 65
# {'month': u'01', 'day': u'26', 'year': u'2018'}
# Insert into OrderAll values (2018,01,26,'2018-01-26',1,2120248965,116709,'리코스 나쵸칩(454g/EA) 미국-※미국','EA',7,2900,20300,2030,22330);
#
# Insert into OrderAll values (2018,01,26,'2018-01-26',2,2120282214,119863,'삼조쎌텍 나쵸치즈소스(1Kg/EA)','EA',3,8300,24900,2490,27390);
#
# Insert into OrderAll values (2018,01,26,'2018-01-26',3,2120248965,145970,'치킨무(외식체인전용 5Kg/EA) 한국-※국내산','EA',2,5700,11400,0,11400);
#
# Insert into OrderAll values (2018,01,26,'2018-01-26',4,2120246221,169394,'샐러드믹스(생활맥주용 150g*5입 750g/BOX) 한국 1EA/BOX-※국내산','BOX',2,14400,28800,0,28800);
#
# Insert into OrderAll values (2018,01,26,'2018-01-26',5,2120248965,201934,'소고기육포(생활맥주용 70g/EA) 호주-※호주산','EA',10,3970,39700,3970,43670);
#
# Insert into OrderAll values (2018,01,26,'2018-01-26',6,2120248965,232931,'반건오징어(생활맥주용 10미 1.3Kg/EA) 한국-※국내산','EA',2,32000,64000,0,64000);
#
# Insert into OrderAll values (2018,01,26,'2018-01-26',7,2120246221,401354,'계란(특란_60g*30입 1.8Kg/PAC) 한국-※달걀(국내산)','PAC',2,6010,12020,0,12020);
#
# Insert into OrderAll values (2018,01,26,'2018-01-26',8,2120246221,424783,'염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX','BOX',1,41400,41400,4140,45540);
#
# Order count 8 Total Order Count 73
# {'month': u'01', 'day': u'27', 'year': u'2018'}
# Insert into OrderAll values (2018,01,27,'2018-01-27',1,2120282408,251901,'냉동감자(생활맥주용 스파이시스트레이트컷 2.04Kg/EA)','EA',5,8960,44800,4480,49280);
#
# Insert into OrderAll values (2018,01,27,'2018-01-27',2,2120282408,251902,'냉동감자(생활맥주용 클리어코트슈스트링 2.04Kg/EA)','EA',5,8960,44800,4480,49280);
#
# Insert into OrderAll values (2018,01,27,'2018-01-27',3,2120279333,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',2,54300,108600,10860,119460);
#
# Insert into OrderAll values (2018,01,27,'2018-01-27',4,2120282408,140440,'심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)','EA',5,6980,34900,3490,38390);
#
# Insert into OrderAll values (2018,01,27,'2018-01-27',5,2120282408,201934,'소고기육포(생활맥주용 70g/EA) 호주-※호주산','EA',10,3970,39700,3970,43670);
#
# Order count 5 Total Order Count 78
# {'month': u'01', 'day': u'29', 'year': u'2018'}
# Insert into OrderAll values (2018,01,29,'2018-01-29',1,2120319644,100744,'스프라이트 사이다(355ml 355g/EA) 한국 24EA/BOX-※국내산','BOX',1,13992,13992,1399,15391);
#
# Insert into OrderAll values (2018,01,29,'2018-01-29',2,2120319644,115722,'사세통상 버팔로윙(1Kg/EA) 태국-※닭고기(태국산)','EA',2,10500,21000,2100,23100);
#
# Insert into OrderAll values (2018,01,29,'2018-01-29',3,2120319644,116981,'사세통상 버팔로윙스틱(1Kg/EA) 태국-※닭고기(태국산)','EA',2,9800,19600,1960,21560);
#
# Insert into OrderAll values (2018,01,29,'2018-01-29',4,2120319644,146391,'쉐프솔루션 햄야채볶음밥(300g/EA)','EA',20,1469,29380,2938,32318);
#
# Insert into OrderAll values (2018,01,29,'2018-01-29',5,2120319644,166412,'뫼루니식품 물결무늬파우더(데일리비어용 매운맛 5Kg/EA) 미국-※미국산','EA',2,13150,26300,2630,28930);
#
# Insert into OrderAll values (2018,01,29,'2018-01-29',6,2120319644,176689,'소시지(생활맥주용 천연돈장_70g*4입 280g/EA) 한국-※돼지고기(국내산)','EA',10,4370,43700,4370,48070);
#
# Insert into OrderAll values (2018,01,29,'2018-01-29',7,2120319644,247491,'뫼루니식품 레드소스(데일리비어용 양념치킨용 2Kg/EA)','EA',3,6900,20700,2070,22770);
#
# Insert into OrderAll values (2018,01,29,'2018-01-29',8,2120284504,177050,'기름여과지(생활맥주용 100매 BOX) 1EA/BOX','BOX',0,49000,0,0,0);
#
# Order count 8 Total Order Count 86
# {'month': u'01', 'day': u'31', 'year': u'2018'}
# Insert into OrderAll values (2018,01,31,'2018-01-31',1,2120372415,116709,'리코스 나쵸칩(454g/EA) 미국-※미국','EA',8,2900,23200,2320,25520);
#
# Insert into OrderAll values (2018,01,31,'2018-01-31',2,2120371183,242910,'웰넛 건포도(500g/EA) 미국-※미국산','EA',2,3130,6260,626,6886);
#
# Insert into OrderAll values (2018,01,31,'2018-01-31',3,2120372415,206578,'길림양행 땅콩(껍질무_1/2태 1Kg/PAC)-※이력번호:10931-18-010027M','PAC',3,7000,21000,2100,23100);
#
# Insert into OrderAll values (2018,01,31,'2018-01-31',4,2120371183,424782,'염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX','BOX',2,54300,108600,10860,119460);
#
# Order count 4 Total Order Count 90

# %%
fb = open('ftest.sql', 'w')

string = u'한글문장'

ustring = string.encode("utf-16")
fb.write(ustring)

fb.close()
