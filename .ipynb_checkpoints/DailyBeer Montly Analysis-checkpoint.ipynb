# %% [markdown]
# # DailyBeer

# %%
import sqlite3
conn = sqlite3.connect("OrderAll.db")

# %% [markdown]
# ## 1. Monthly  Total Amount Report

# %%
from pandas import Series, DataFrame

sql_cmd = """
select month, sum(total) as grandtotal
from OrderAll
group by month
order by month;
"""
cursor = conn.cursor()
cursor.execute(sql_cmd)
tuples = cursor.fetchall()

SR_Gtotal = Series([])


for tuple in tuples:
    SR_Gtotal = SR_Gtotal.set_value(int(tuple[0]), int(tuple[1]))
    print "{:>10}".format(tuple[0]), '월', "{:>12,}".format(tuple[1]),'원'

print SR_Gtotal.values
print SR_Gtotal.index
# Out:
#          7 월    8,474,601 원
#          8 월    7,594,394 원
#          9 월    6,673,702 원
#         10 월    4,974,996 원
# [8474601 7594394 6673702 4974996]
# Int64Index([7, 8, 9, 10], dtype='int64')

# %%
from itertools import cycle, islice
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

ind = np.arange(len(SR_Gtotal))
listtotal = SR_Gtotal.values
listindex = SR_Gtotal.index

plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
people = listindex
y_pos = np.arange(len(listindex))
performance = listtotal
error = np.random.rand(len(listindex))

ax.barh(y_pos, performance, 0.6, align='center',
        color='green', ecolor='black')

for i, v in enumerate(listtotal):
    ax.text(v + 3, i + .25, "{:,}".format(v), color='green', fontweight='bold')

ax.set_yticks(y_pos)
ax.set_yticklabels(listindex)
ax.set_xticklabels([0,100,200,300,400,500,600,700,800,900,1000], rotation=90)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel(u'M')
ax.set_title('Grand Total Amount Paid to CJ')

plt.show()

# %%
sql_cmd = """
select month, sku, pname, sum(total) as gtotal, '원' as won, sum(qty) as qty, '개' as quantity
from OrderAll
where month = 10 and year = 2017
group by sku
order by gtotal desc;
"""
cursor = conn.cursor()
cursor.execute(sql_cmd)
tuples = cursor.fetchall()

# %% [markdown]
# ## 2. Monthly Product Details

# %%
msum = 0
for tuple in tuples:
    #pname = tuple[2].replace("\n", "-")
    pname = tuple[2]
    msum += tuple[3]
    
    print tuple[0], '월', tuple[1], pname[:10].ljust(40), '\t\t\t', "{:10,}".format(tuple[3]),'원', '\t\t', tuple[5],'개'
print 'Total Amount', "{:>12,}".format(msum)
# Out:
# 10 월 424782 염지닭(생활맥주용                                			 1,015,410 원 		17 개
# 10 월 134356 심플로트 냉동감자(                               			   449,196 원 		41 개
# 10 월 424783 염지닭안심(생활맥주                               			   318,780 원 		7 개
# 10 월 140440 심플로트 냉동감자(                               			   291,764 원 		38 개
# 10 월 144398 심플로트 냉동감자(                               			   257,950 원 		25 개
# 10 월 247491 뫼루니식품 레드소스                               			   227,700 원 		30 개
# 10 월 176689 소시지(생활맥주용                                			   216,315 원 		45 개
# 10 월 232931 반건오징어(생활맥주                               			   177,000 원 		6 개
# 10 월 201934 소고기육포(생활맥주                               			   174,680 원 		40 개
# 10 월 169394 샐러드믹스(생활맥주                               			   144,000 원 		10 개
# 10 월 115722 사세통상 버팔로윙(                               			   127,050 원 		11 개
# 10 월 163815 이츠웰 골뱅이캔(자                               			   123,200 원 		40 개
# 10 월 215140 양파드레싱(생활맥주                               			   118,800 원 		12 개
# 10 월 116981 사세통상 버팔로윙스                               			   118,580 원 		11 개
# 10 월 206578 길림양행 땅콩(껍질                               			   115,500 원 		15 개
# 10 월 116709 리코스 나쵸칩(45                               			   111,650 원 		35 개
# 10 월 118232 스팸 햄캔(마일드                                			    92,400 원 		30 개
# 10 월 166412 뫼루니식품 물결무늬                               			    86,790 원 		6 개
# 10 월 177050 기름여과지(생활맥주                               			    80,300 원 		1 개
# 10 월 145970 치킨무(외식체인전용                               			    79,800 원 		14 개
# 10 월 124531 맥앤치즈볼(생활맥주                               			    79,640 원 		20 개
# 10 월 119863 삼조쎌텍 나쵸치즈소                               			    73,040 원 		8 개
# 10 월 115364 삼진 살사소스(2K                               			    59,400 원 		6 개
# 10 월 127454 파로 할라페뇨(슬라                               			    56,100 원 		6 개
# 10 월 100744 스프라이트 사이다(                               			    46,173 원 		3 개
# 10 월 146239 쉐프솔루션 김치볶음                               			    38,500 원 		25 개
# 10 월 100743 코카콜라 콜라(캔_                               			    34,056 원 		2 개
# 10 월 112371 칵테일냅킨(생활맥주                               			    33,000 원 		1 개
# 10 월 171838 팔도 비빔면(130                               			    29,480 원 		1 개
# 10 월 160016 오뚜기 케찹(스파우                               			    26,070 원 		6 개
# 10 월 146391 쉐프솔루션 햄야채볶                               			    24,239 원 		15 개
# 10 월 178733 물티슈(생활맥주용                                			    24,200 원 		2 개
# 10 월 242910 웰넛 건포도(500                               			    22,770 원 		9 개
# 10 월 401354 계란(특란_60g*                               			    19,365 원 		3 개
# 10 월 111308 천일식품 새우볶음밥                               			    17,930 원 		10 개
# 10 월 138389 이츠웰 초고추장(N                               			    13,200 원 		4 개
# 10 월 154639 오뚜기 마요네즈(골                               			    10,780 원 		1 개
# 10 월 215139 케이준드레싱(생활맥                               			     9,955 원 		1 개
# 10 월 146393 쉐프솔루션 해물볶음                               			     8,025 원 		5 개
# 10 월 135267 그라나파다노치즈(포                               			     7,260 원 		1 개
# 10 월 139476 신영상회 파슬리후레                               			     5,960 원 		1 개
# 10 월 500556 일회용기세트(1호_                               			     4,772 원 		2 개
# 10 월 514158 이츠웰 주방세제(그                               			     3,116 원 		1 개
# 10 월 159365 유니푸드 양념소금(                               			     1,100 원 		1 개
# Total Amount    4,974,996

# %% [markdown]
# ## Group by SKU, MONTH

# %%
sql_cmd = """
select
        sku, pname,
        month,
        '월' as mon,
        sum(total) as gtotal,
        sum(qty) as qty,
        '개' as quantity
from OrderAll
group by sku, month
order by sku, month;
"""
cursor = conn.cursor()
cursor.execute(sql_cmd)
tuples = cursor.fetchall()

# %%
i=0
for tuple in tuples:
    glist = []
    #pname = tuple[1].replace("\n","-")
    pname = tuple[1]
    monthstring = str(tuple[2])+u'월'
    qtystring = str(tuple[5])+u'개' 
    eachmonth = [tuple[0], pname, monthstring, "{:>12,}".format(tuple[4]), qtystring]
    
    print eachmonth[0], (eachmonth[1][:20]).ljust(30),'\t\t', eachmonth[2], '\t\t',eachmonth[3],'\t\t', eachmonth[4]
    i = i + 1
#    if i > 30:
#        break
# Out:
# 100353 백설 바삭튀김가루(1Kg/EA) 미국           		8월 		       2,750 		1개
# 100353 백설 바삭튀김가루(1Kg/EA) 미국           		9월 		      13,750 		5개
# 100743 코카콜라 콜라(캔_355ml 355g           		7월 		      68,112 		4개
# 100743 코카콜라 콜라(캔_355ml 355g           		8월 		      68,112 		4개
# 100743 코카콜라 콜라(캔_355ml 355g           		9월 		      34,056 		2개
# 100743 코카콜라 콜라(캔_355ml 355g           		10월 		      34,056 		2개
# 100744 스프라이트 사이다(355ml 355g           		7월 		      76,955 		5개
# 100744 스프라이트 사이다(355ml 355g           		8월 		      76,955 		5개
# 100744 스프라이트 사이다(355ml 355g           		9월 		      61,564 		4개
# 100744 스프라이트 사이다(355ml 355g           		10월 		      46,173 		3개
# 105409 아담스 파마산치즈파우더(1Kg/EA)           		7월 		      24,200 		2개
# 105409 아담스 파마산치즈파우더(1Kg/EA)           		8월 		      12,100 		1개
# 111308 천일식품 새우볶음밥(300g/EA)            		7월 		      23,309 		13개
# 111308 천일식품 새우볶음밥(300g/EA)            		8월 		      17,930 		10개
# 111308 천일식품 새우볶음밥(300g/EA)            		10월 		      17,930 		10개
# 112371 칵테일냅킨(생활맥주용 10000장입            		7월 		      33,000 		1개
# 112371 칵테일냅킨(생활맥주용 10000장입            		8월 		      33,000 		1개
# 112371 칵테일냅킨(생활맥주용 10000장입            		10월 		      33,000 		1개
# 115364 삼진 살사소스(2Kg/EA)                		7월 		      39,600 		4개
# 115364 삼진 살사소스(2Kg/EA)                		8월 		      59,400 		6개
# 115364 삼진 살사소스(2Kg/EA)                		9월 		      19,800 		2개
# 115364 삼진 살사소스(2Kg/EA)                		10월 		      59,400 		6개
# 115722 사세통상 버팔로윙(1Kg/EA) 태국           		7월 		     242,550 		21개
# 115722 사세통상 버팔로윙(1Kg/EA) 태국           		8월 		     127,050 		11개
# 115722 사세통상 버팔로윙(1Kg/EA) 태국           		9월 		     173,250 		15개
# 115722 사세통상 버팔로윙(1Kg/EA) 태국           		10월 		     127,050 		11개
# 116709 리코스 나쵸칩(454g/EA) 미국-           		7월 		     267,960 		84개
# 116709 리코스 나쵸칩(454g/EA) 미국-           		8월 		     210,540 		66개
# 116709 리코스 나쵸칩(454g/EA) 미국-           		9월 		     191,400 		60개
# 116709 리코스 나쵸칩(454g/EA) 미국-           		10월 		     111,650 		35개
# 116981 사세통상 버팔로윙스틱(1Kg/EA)            		7월 		     226,380 		21개
# 116981 사세통상 버팔로윙스틱(1Kg/EA)            		8월 		     172,480 		16개
# 116981 사세통상 버팔로윙스틱(1Kg/EA)            		9월 		     161,700 		15개
# 116981 사세통상 버팔로윙스틱(1Kg/EA)            		10월 		     118,580 		11개
# 118232 스팸 햄캔(마일드 200g/EA)-※           		7월 		     138,600 		45개
# 118232 스팸 햄캔(마일드 200g/EA)-※           		8월 		     184,800 		60개
# 118232 스팸 햄캔(마일드 200g/EA)-※           		9월 		     169,400 		55개
# 118232 스팸 햄캔(마일드 200g/EA)-※           		10월 		      92,400 		30개
# 119863 삼조쎌텍 나쵸치즈소스(1Kg/EA)            		7월 		      54,780 		6개
# 119863 삼조쎌텍 나쵸치즈소스(1Kg/EA)            		8월 		      82,170 		9개
# 119863 삼조쎌텍 나쵸치즈소스(1Kg/EA)            		9월 		      63,910 		7개
# 119863 삼조쎌텍 나쵸치즈소스(1Kg/EA)            		10월 		      73,040 		8개
# 124531 맥앤치즈볼(생활맥주용 50G*4입 2           		7월 		     238,920 		60개
# 124531 맥앤치즈볼(생활맥주용 50G*4입 2           		8월 		     167,244 		42개
# 124531 맥앤치즈볼(생활맥주용 50G*4입 2           		9월 		     119,460 		30개
# 124531 맥앤치즈볼(생활맥주용 50G*4입 2           		10월 		      79,640 		20개
# 127454 파로 할라페뇨(슬라이스 3Kg/EA)           		7월 		     102,850 		11개
# 127454 파로 할라페뇨(슬라이스 3Kg/EA)           		8월 		      93,500 		10개
# 127454 파로 할라페뇨(슬라이스 3Kg/EA)           		9월 		      46,750 		5개
# 127454 파로 할라페뇨(슬라이스 3Kg/EA)           		10월 		      56,100 		6개
# 133941 유동 골뱅이캔(자연산 140g/EA)           		8월 		      30,800 		10개
# 133941 유동 골뱅이캔(자연산 140g/EA)           		9월 		      15,400 		5개
# 134356 심플로트 냉동감자(메가크런치 2.04           		7월 		     602,580 		55개
# 134356 심플로트 냉동감자(메가크런치 2.04           		8월 		     493,020 		45개
# 134356 심플로트 냉동감자(메가크런치 2.04           		9월 		     438,240 		40개
# 134356 심플로트 냉동감자(메가크런치 2.04           		10월 		     449,196 		41개
# 135267 그라나파다노치즈(포션 200g/EA)           		7월 		      14,520 		2개
# 135267 그라나파다노치즈(포션 200g/EA)           		8월 		      21,780 		3개
# 135267 그라나파다노치즈(포션 200g/EA)           		10월 		       7,260 		1개
# 138389 이츠웰 초고추장(NEW 1Kg/EA)           		7월 		      23,100 		7개
# 138389 이츠웰 초고추장(NEW 1Kg/EA)           		8월 		      23,100 		7개
# 138389 이츠웰 초고추장(NEW 1Kg/EA)           		9월 		      29,700 		9개
# 138389 이츠웰 초고추장(NEW 1Kg/EA)           		10월 		      13,200 		4개
# 139476 신영상회 파슬리후레이크(250g/EA           		7월 		       5,960 		1개
# 139476 신영상회 파슬리후레이크(250g/EA           		10월 		       5,960 		1개
# 140440 심플로트 냉동감자(크링클컷웨지 2.2           		7월 		     476,036 		62개
# 140440 심플로트 냉동감자(크링클컷웨지 2.2           		8월 		     383,900 		50개
# 140440 심플로트 냉동감자(크링클컷웨지 2.2           		9월 		     399,256 		52개
# 140440 심플로트 냉동감자(크링클컷웨지 2.2           		10월 		     291,764 		38개
# 143790 이츠웰 참기름(NEW_캔_1L 916           		9월 		      11,660 		1개
# 144398 심플로트 냉동감자(세이보리_스트레이트           		7월 		     557,172 		54개
# 144398 심플로트 냉동감자(세이보리_스트레이트           		8월 		     340,494 		33개
# 144398 심플로트 냉동감자(세이보리_스트레이트           		9월 		     443,674 		43개
# 144398 심플로트 냉동감자(세이보리_스트레이트           		10월 		     257,950 		25개
# 145970 치킨무(외식체인전용 5Kg/EA) 한           		7월 		      91,200 		16개
# 145970 치킨무(외식체인전용 5Kg/EA) 한           		8월 		     102,600 		18개
# 145970 치킨무(외식체인전용 5Kg/EA) 한           		9월 		      74,100 		13개
# 145970 치킨무(외식체인전용 5Kg/EA) 한           		10월 		      79,800 		14개
# 146239 쉐프솔루션 김치볶음밥(300g/EA)           		7월 		      58,520 		38개
# 146239 쉐프솔루션 김치볶음밥(300g/EA)           		8월 		      69,300 		45개
# 146239 쉐프솔루션 김치볶음밥(300g/EA)           		9월 		     100,100 		65개
# 146239 쉐프솔루션 김치볶음밥(300g/EA)           		10월 		      38,500 		25개
# 146391 쉐프솔루션 햄야채볶음밥(300g/EA           		7월 		      19,392 		12개
# 146391 쉐프솔루션 햄야채볶음밥(300g/EA           		8월 		      48,479 		30개
# 146391 쉐프솔루션 햄야채볶음밥(300g/EA           		9월 		      56,558 		35개
# 146391 쉐프솔루션 햄야채볶음밥(300g/EA           		10월 		      24,239 		15개
# 146393 쉐프솔루션 해물볶음밥(300g/EA)           		7월 		      12,840 		8개
# 146393 쉐프솔루션 해물볶음밥(300g/EA)           		8월 		      24,074 		15개
# 146393 쉐프솔루션 해물볶음밥(300g/EA)           		9월 		      44,939 		28개
# 146393 쉐프솔루션 해물볶음밥(300g/EA)           		10월 		       8,025 		5개
# 154639 오뚜기 마요네즈(골드 스파우트팩 3.           		7월 		      21,560 		2개
# 154639 오뚜기 마요네즈(골드 스파우트팩 3.           		8월 		      21,560 		2개
# 154639 오뚜기 마요네즈(골드 스파우트팩 3.           		10월 		      10,780 		1개
# 159365 유니푸드 양념소금(마파치킨용 3.5g           		7월 		       2,200 		2개
# 159365 유니푸드 양념소금(마파치킨용 3.5g           		9월 		       1,100 		1개
# 159365 유니푸드 양념소금(마파치킨용 3.5g           		10월 		       1,100 		1개
# 160016 오뚜기 케찹(스파우트팩 3.3Kg/E           		7월 		      26,070 		6개
# 160016 오뚜기 케찹(스파우트팩 3.3Kg/E           		8월 		      43,450 		10개
# 160016 오뚜기 케찹(스파우트팩 3.3Kg/E           		9월 		      34,760 		8개
# 160016 오뚜기 케찹(스파우트팩 3.3Kg/E           		10월 		      26,070 		6개
# 163815 이츠웰 골뱅이캔(자연산 140g/EA           		7월 		     344,960 		112개
# 163815 이츠웰 골뱅이캔(자연산 140g/EA           		8월 		     323,400 		105개
# 163815 이츠웰 골뱅이캔(자연산 140g/EA           		9월 		     231,000 		75개
# 163815 이츠웰 골뱅이캔(자연산 140g/EA           		10월 		     123,200 		40개
# 166412 뫼루니식품 물결무늬파우더(데일리비어용           		7월 		     115,720 		8개
# 166412 뫼루니식품 물결무늬파우더(데일리비어용           		8월 		     101,255 		7개
# 166412 뫼루니식품 물결무늬파우더(데일리비어용           		9월 		      86,790 		6개
# 166412 뫼루니식품 물결무늬파우더(데일리비어용           		10월 		      86,790 		6개
# 166413 뫼루니 양념치킨소스(데일리비어용 양념           		7월 		      83,490 		11개
# 166413 뫼루니 양념치킨소스(데일리비어용 양념           		8월 		     106,260 		14개
# 169394 샐러드믹스(생활맥주용 150g*5입            		7월 		     345,600 		24개
# 169394 샐러드믹스(생활맥주용 150g*5입            		8월 		     288,000 		20개
# 169394 샐러드믹스(생활맥주용 150g*5입            		9월 		     187,200 		13개
# 169394 샐러드믹스(생활맥주용 150g*5입            		10월 		     144,000 		10개
# 171838 팔도 비빔면(130g/EA) 40EA           		7월 		      88,440 		3개
# 171838 팔도 비빔면(130g/EA) 40EA           		8월 		      58,960 		2개
# 171838 팔도 비빔면(130g/EA) 40EA           		9월 		      88,440 		3개
# 171838 팔도 비빔면(130g/EA) 40EA           		10월 		      29,480 		1개
# 176689 소시지(생활맥주용 천연돈장_70g*4           		7월 		     312,455 		65개
# 176689 소시지(생활맥주용 천연돈장_70g*4           		8월 		     490,314 		102개
# 176689 소시지(생활맥주용 천연돈장_70g*4           		9월 		     394,174 		82개
# 176689 소시지(생활맥주용 천연돈장_70g*4           		10월 		     216,315 		45개
# 177050 기름여과지(생활맥주용 100매 BOX           		10월 		      80,300 		1개
# 177058 미니고무장갑(생활맥주용 10입 EA)           		7월 		       8,250 		1개
# 177058 미니고무장갑(생활맥주용 10입 EA)           		8월 		      16,500 		2개
# 177058 미니고무장갑(생활맥주용 10입 EA)           		9월 		       8,250 		1개
# 178733 물티슈(생활맥주용 500입 BOX)            		9월 		      12,100 		1개
# 178733 물티슈(생활맥주용 500입 BOX)            		10월 		      24,200 		2개
# 178883 코스터(생활맥주용 600매 EA)             		7월 		      62,700 		1개
# 178883 코스터(생활맥주용 600매 EA)             		9월 		      62,700 		1개
# 201934 소고기육포(생활맥주용 70g/EA)            		7월 		     349,360 		80개
# 201934 소고기육포(생활맥주용 70g/EA)            		8월 		     240,185 		55개
# 201934 소고기육포(생활맥주용 70g/EA)            		9월 		     152,845 		35개
# 201934 소고기육포(생활맥주용 70g/EA)            		10월 		     174,680 		40개
# 206578 길림양행 땅콩(껍질무_1/2태 1Kg           		7월 		     138,600 		18개
# 206578 길림양행 땅콩(껍질무_1/2태 1Kg           		8월 		     115,500 		15개
# 206578 길림양행 땅콩(껍질무_1/2태 1Kg           		9월 		     100,100 		13개
# 206578 길림양행 땅콩(껍질무_1/2태 1Kg           		10월 		     115,500 		15개
# 215139 케이준드레싱(생활맥주용 2Kg/EA)           		7월 		      19,910 		2개
# 215139 케이준드레싱(생활맥주용 2Kg/EA)           		8월 		      39,820 		4개
# 215139 케이준드레싱(생활맥주용 2Kg/EA)           		9월 		       9,955 		1개
# 215139 케이준드레싱(생활맥주용 2Kg/EA)           		10월 		       9,955 		1개
# 215140 양파드레싱(생활맥주용 2Kg/EA)            		7월 		     158,400 		16개
# 215140 양파드레싱(생활맥주용 2Kg/EA)            		8월 		     158,400 		16개
# 215140 양파드레싱(생활맥주용 2Kg/EA)            		9월 		     138,600 		14개
# 215140 양파드레싱(생활맥주용 2Kg/EA)            		10월 		     118,800 		12개
# 232931 반건오징어(생활맥주용 10미 1.3K           		7월 		     354,000 		12개
# 232931 반건오징어(생활맥주용 10미 1.3K           		8월 		     590,000 		20개
# 232931 반건오징어(생활맥주용 10미 1.3K           		9월 		     383,500 		13개
# 232931 반건오징어(생활맥주용 10미 1.3K           		10월 		     177,000 		6개
# 242910 웰넛 건포도(500g/EA) 미국-※           		7월 		      43,010 		17개
# 242910 웰넛 건포도(500g/EA) 미국-※           		8월 		      25,300 		10개
# 242910 웰넛 건포도(500g/EA) 미국-※           		9월 		      30,360 		12개
# 242910 웰넛 건포도(500g/EA) 미국-※           		10월 		      22,770 		9개
# 247491 뫼루니식품 레드소스(데일리비어용 양념           		8월 		      15,180 		2개
# 247491 뫼루니식품 레드소스(데일리비어용 양념           		9월 		     121,440 		16개
# 247491 뫼루니식품 레드소스(데일리비어용 양념           		10월 		     227,700 		30개
# 401354 계란(특란_60g*30입 1.8Kg/           		7월 		      75,716 		8개
# 401354 계란(특란_60g*30입 1.8Kg/           		8월 		      90,590 		10개
# 401354 계란(특란_60g*30입 1.8Kg/           		9월 		      72,030 		10개
# 401354 계란(특란_60g*30입 1.8Kg/           		10월 		      19,365 		3개
# 424782 염지닭(생활맥주용 9호_9각 850g           		7월 		   1,672,440 		28개
# 424782 염지닭(생활맥주용 9호_9각 850g           		8월 		   1,552,980 		26개
# 424782 염지닭(생활맥주용 9호_9각 850g           		9월 		   1,254,330 		21개
# 424782 염지닭(생활맥주용 9호_9각 850g           		10월 		   1,015,410 		17개
# 424783 염지닭안심(생활맥주용 1Kg/EA)            		7월 		     683,100 		15개
# 424783 염지닭안심(생활맥주용 1Kg/EA)            		8월 		     364,320 		8개
# 424783 염지닭안심(생활맥주용 1Kg/EA)            		9월 		     455,400 		10개
# 424783 염지닭안심(생활맥주용 1Kg/EA)            		10월 		     318,780 		7개
# 500556 일회용기세트(1호_70*30mm_10           		8월 		       2,386 		1개
# 500556 일회용기세트(1호_70*30mm_10           		9월 		       7,158 		3개
# 500556 일회용기세트(1호_70*30mm_10           		10월 		       4,772 		2개
# 501191 하이코리아 락스(2L EA)                		7월 		      12,316 		12개
# 501326 스파크 세탁세제(5kg EA)               		8월 		      12,617 		1개
# 501326 스파크 세탁세제(5kg EA)               		9월 		      12,617 		1개
# 501386 트레펑(1L 막힌하수구용 EA)              		7월 		      24,365 		10개
# 501386 트레펑(1L 막힌하수구용 EA)              		8월 		      48,730 		20개
# 501386 트레펑(1L 막힌하수구용 EA)              		9월 		      48,730 		20개
# 503517 스카치브라이트 양면스폰지수세미(EA)           		7월 		       4,813 		5개
# 512186 이츠웰 롤백(소_25*35cm_500           		7월 		       5,390 		2개
# 512186 이츠웰 롤백(소_25*35cm_500           		8월 		       8,085 		3개
# 512188 이츠웰 롤백(중_30*40cm_500           		7월 		       7,700 		2개
# 512237 이츠웰 페이퍼타올(핸드타올_4500매           		9월 		      21,450 		1개
# 514151 이츠웰 다용도봉투(파란색_30L_48           		7월 		       9,900 		3개
# 514158 이츠웰 주방세제(그린알로_3kg EA           		9월 		       6,232 		2개
# 514158 이츠웰 주방세제(그린알로_3kg EA           		10월 		       3,116 		1개
# 514663 지원 일회용기뚜껑(W-3_75mm_1           		8월 		       2,024 		1개
# 514663 지원 일회용기뚜껑(W-3_75mm_1           		9월 		       4,048 		2개
# 514664 지원 일회용기(W-3_75*65mm_           		9월 		      13,726 		2개
# 526116 유산지(생활맥주용 1000개 EA)            		7월 		      66,000 		2개
# 526116 유산지(생활맥주용 1000개 EA)            		8월 		      33,000 		1개
# 526116 유산지(생활맥주용 1000개 EA)            		9월 		      66,000 		2개
# 526117 비닐백(생활맥주용 100매 EA)             		7월 		      39,600 		4개

# %%
print tuple[1]
def unicode_truncate(s, length, encoding='utf-8'):
    encoded = s.encode(encoding)[:length]
    return encoded.decode(encoding, 'ignore')
print unicode_truncate(tuple[1], 60)
# Out:
# 백설 바삭튀김가루(1Kg/EA) 미국
# ※미국산
# 백설 바삭튀김가루(1Kg/EA) 미국
# ※미국산
