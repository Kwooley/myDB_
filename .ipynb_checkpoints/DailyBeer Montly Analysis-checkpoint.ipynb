# %% [markdown]
# # DailyBeer

# %%
import sqlite3
conn = sqlite3.connect("OrderAll.db")

# %% [markdown]
# ## 1. Monthly  Total Amount Report

# %%
from pandas import Series, DataFrame
import pandas as pd

sql_cmd = """
            select month, sum(total) as grandtotal
            from OrderAll
            group by month
            order by month;
"""
cursor = conn.cursor()
cursor.execute(sql_cmd)
tuples = cursor.fetchall()

SR_Gtotal = Series([])


for tuple in tuples:
    SR_Gtotal = SR_Gtotal.set_value(int(tuple[0]), int(tuple[1]))
    print "{:>10}".format(tuple[0]), '월', "{:>12,}".format(tuple[1]),'원'

print SR_Gtotal.values
print SR_Gtotal.index
# Out:
#          7 월    8,474,601 원
#          8 월    7,594,394 원
#          9 월    6,673,702 원
#         10 월    4,974,996 원
#         11 월    4,325,622 원
# [8474601 7594394 6673702 4974996 4325622]
# Int64Index([7, 8, 9, 10, 11], dtype='int64')

# %%
SR_Gtotal
# Out:
# 7     8474601
# 8     7594394
# 9     6673702
# 10    4974996
# 11    4325622
# dtype: int64

# %%
from itertools import cycle, islice
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

ind = np.arange(len(SR_Gtotal))
listtotal = SR_Gtotal.values
listindex = SR_Gtotal.index

plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
people = listindex
y_pos = np.arange(len(listindex))
performance = listtotal
error = np.random.rand(len(listindex))

ax.barh(y_pos, performance, 0.6, align='center',
        color='green', ecolor='black')

for i, v in enumerate(listtotal):
    ax.text(v + 3, i + .25, "{:,}".format(v), color='green', fontweight='bold')

ax.set_yticks(y_pos)
ax.set_yticklabels(listindex)
ax.set_xticklabels([0,100,200,300,400,500,600,700,800,900,1000], rotation=90)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel(u'Amount')
ax.set_title('Grand Total Amount Paid to CJ')

plt.show()

# %% [markdown]
# ## 2. Monthly Products List

# %%
for month_input in listindex:
    
    sql_cmd = """
    select month, sku, pname, sum(total) as gtotal, '원' as won, sum(qty) as qty, '개' as quantity
    from OrderAll
    where month = {} and year = 2017
    group by sku
    order by gtotal desc;
    """.format(month_input)

    cursor = conn.cursor()
    cursor.execute(sql_cmd)
    tuples = cursor.fetchall()

    msum = 0
    linebreak = 0
    for tuple in tuples:
        linebreak += 1
        #pname = tuple[2].replace("\n", "-")
        pname = tuple[2]
        msum += tuple[3]
    
        if (linebreak % 5) == 0:
            print ''
        print tuple[0], '월', tuple[1], pname[:10].ljust(10), '\t', "{:20,}".format(tuple[3]),'원', '\t\t', tuple[5],'개'
       # SR_monthly_product = SR_monthly_product.set_value(pname[:10], tuple[3])
    print "="*64, 'Total Amount', "{:>12,}".format(msum), '원'
    print '\n\n'
# Out:
# 7 월 424782 염지닭(생활맥주용  	           1,672,440 원 		28 개
# 7 월 424783 염지닭안심(생활맥주 	             683,100 원 		15 개
# 7 월 134356 심플로트 냉동감자( 	             602,580 원 		55 개
# 7 월 144398 심플로트 냉동감자( 	             557,172 원 		54 개
#
# 7 월 140440 심플로트 냉동감자( 	             476,036 원 		62 개
# 7 월 232931 반건오징어(생활맥주 	             354,000 원 		12 개
# 7 월 201934 소고기육포(생활맥주 	             349,360 원 		80 개
# 7 월 169394 샐러드믹스(생활맥주 	             345,600 원 		24 개
# 7 월 163815 이츠웰 골뱅이캔(자 	             344,960 원 		112 개
#
# 7 월 176689 소시지(생활맥주용  	             312,455 원 		65 개
# 7 월 116709 리코스 나쵸칩(45 	             267,960 원 		84 개
# 7 월 115722 사세통상 버팔로윙( 	             242,550 원 		21 개
# 7 월 124531 맥앤치즈볼(생활맥주 	             238,920 원 		60 개
# 7 월 116981 사세통상 버팔로윙스 	             226,380 원 		21 개
#
# 7 월 215140 양파드레싱(생활맥주 	             158,400 원 		16 개
# 7 월 118232 스팸 햄캔(마일드  	             138,600 원 		45 개
# 7 월 206578 길림양행 땅콩(껍질 	             138,600 원 		18 개
# 7 월 166412 뫼루니식품 물결무늬 	             115,720 원 		8 개
# 7 월 127454 파로 할라페뇨(슬라 	             102,850 원 		11 개
#
# 7 월 145970 치킨무(외식체인전용 	              91,200 원 		16 개
# 7 월 171838 팔도 비빔면(130 	              88,440 원 		3 개
# 7 월 166413 뫼루니 양념치킨소스 	              83,490 원 		11 개
# 7 월 100744 스프라이트 사이다( 	              76,955 원 		5 개
# 7 월 401354 계란(특란_60g* 	              75,716 원 		8 개
#
# 7 월 100743 코카콜라 콜라(캔_ 	              68,112 원 		4 개
# 7 월 526116 유산지(생활맥주용  	              66,000 원 		2 개
# 7 월 178883 코스터(생활맥주용  	              62,700 원 		1 개
# 7 월 146239 쉐프솔루션 김치볶음 	              58,520 원 		38 개
# 7 월 119863 삼조쎌텍 나쵸치즈소 	              54,780 원 		6 개
#
# 7 월 242910 웰넛 건포도(500 	              43,010 원 		17 개
# 7 월 115364 삼진 살사소스(2K 	              39,600 원 		4 개
# 7 월 526117 비닐백(생활맥주용  	              39,600 원 		4 개
# 7 월 112371 칵테일냅킨(생활맥주 	              33,000 원 		1 개
# 7 월 160016 오뚜기 케찹(스파우 	              26,070 원 		6 개
#
# 7 월 501386 트레펑(1L 막힌하 	              24,365 원 		10 개
# 7 월 105409 아담스 파마산치즈파 	              24,200 원 		2 개
# 7 월 111308 천일식품 새우볶음밥 	              23,309 원 		13 개
# 7 월 138389 이츠웰 초고추장(N 	              23,100 원 		7 개
# 7 월 154639 오뚜기 마요네즈(골 	              21,560 원 		2 개
#
# 7 월 215139 케이준드레싱(생활맥 	              19,910 원 		2 개
# 7 월 146391 쉐프솔루션 햄야채볶 	              19,392 원 		12 개
# 7 월 135267 그라나파다노치즈(포 	              14,520 원 		2 개
# 7 월 146393 쉐프솔루션 해물볶음 	              12,840 원 		8 개
# 7 월 501191 하이코리아 락스(2 	              12,316 원 		12 개
#
# 7 월 514151 이츠웰 다용도봉투( 	               9,900 원 		3 개
# 7 월 177058 미니고무장갑(생활맥 	               8,250 원 		1 개
# 7 월 512188 이츠웰 롤백(중_3 	               7,700 원 		2 개
# 7 월 139476 신영상회 파슬리후레 	               5,960 원 		1 개
# 7 월 512186 이츠웰 롤백(소_2 	               5,390 원 		2 개
#
# 7 월 503517 스카치브라이트 양면 	               4,813 원 		5 개
# 7 월 159365 유니푸드 양념소금( 	               2,200 원 		2 개
# ================================================================ Total Amount    8,474,601 원
#
#
#
# 8 월 424782 염지닭(생활맥주용  	           1,552,980 원 		26 개
# 8 월 232931 반건오징어(생활맥주 	             590,000 원 		20 개
# 8 월 134356 심플로트 냉동감자( 	             493,020 원 		45 개
# 8 월 176689 소시지(생활맥주용  	             490,314 원 		102 개
#
# 8 월 140440 심플로트 냉동감자( 	             383,900 원 		50 개
# 8 월 424783 염지닭안심(생활맥주 	             364,320 원 		8 개
# 8 월 144398 심플로트 냉동감자( 	             340,494 원 		33 개
# 8 월 163815 이츠웰 골뱅이캔(자 	             323,400 원 		105 개
# 8 월 169394 샐러드믹스(생활맥주 	             288,000 원 		20 개
#
# 8 월 201934 소고기육포(생활맥주 	             240,185 원 		55 개
# 8 월 116709 리코스 나쵸칩(45 	             210,540 원 		66 개
# 8 월 118232 스팸 햄캔(마일드  	             184,800 원 		60 개
# 8 월 116981 사세통상 버팔로윙스 	             172,480 원 		16 개
# 8 월 124531 맥앤치즈볼(생활맥주 	             167,244 원 		42 개
#
# 8 월 215140 양파드레싱(생활맥주 	             158,400 원 		16 개
# 8 월 115722 사세통상 버팔로윙( 	             127,050 원 		11 개
# 8 월 206578 길림양행 땅콩(껍질 	             115,500 원 		15 개
# 8 월 166413 뫼루니 양념치킨소스 	             106,260 원 		14 개
# 8 월 145970 치킨무(외식체인전용 	             102,600 원 		18 개
#
# 8 월 166412 뫼루니식품 물결무늬 	             101,255 원 		7 개
# 8 월 127454 파로 할라페뇨(슬라 	              93,500 원 		10 개
# 8 월 401354 계란(특란_60g* 	              90,590 원 		10 개
# 8 월 119863 삼조쎌텍 나쵸치즈소 	              82,170 원 		9 개
# 8 월 100744 스프라이트 사이다( 	              76,955 원 		5 개
#
# 8 월 146239 쉐프솔루션 김치볶음 	              69,300 원 		45 개
# 8 월 100743 코카콜라 콜라(캔_ 	              68,112 원 		4 개
# 8 월 115364 삼진 살사소스(2K 	              59,400 원 		6 개
# 8 월 171838 팔도 비빔면(130 	              58,960 원 		2 개
# 8 월 501386 트레펑(1L 막힌하 	              48,730 원 		20 개
#
# 8 월 146391 쉐프솔루션 햄야채볶 	              48,479 원 		30 개
# 8 월 160016 오뚜기 케찹(스파우 	              43,450 원 		10 개
# 8 월 215139 케이준드레싱(생활맥 	              39,820 원 		4 개
# 8 월 112371 칵테일냅킨(생활맥주 	              33,000 원 		1 개
# 8 월 526116 유산지(생활맥주용  	              33,000 원 		1 개
#
# 8 월 133941 유동 골뱅이캔(자연 	              30,800 원 		10 개
# 8 월 242910 웰넛 건포도(500 	              25,300 원 		10 개
# 8 월 146393 쉐프솔루션 해물볶음 	              24,074 원 		15 개
# 8 월 138389 이츠웰 초고추장(N 	              23,100 원 		7 개
# 8 월 135267 그라나파다노치즈(포 	              21,780 원 		3 개
#
# 8 월 154639 오뚜기 마요네즈(골 	              21,560 원 		2 개
# 8 월 111308 천일식품 새우볶음밥 	              17,930 원 		10 개
# 8 월 177058 미니고무장갑(생활맥 	              16,500 원 		2 개
# 8 월 247491 뫼루니식품 레드소스 	              15,180 원 		2 개
# 8 월 501326 스파크 세탁세제(5 	              12,617 원 		1 개
#
# 8 월 105409 아담스 파마산치즈파 	              12,100 원 		1 개
# 8 월 512186 이츠웰 롤백(소_2 	               8,085 원 		3 개
# 8 월 100353 백설 바삭튀김가루( 	               2,750 원 		1 개
# 8 월 500556 일회용기세트(1호_ 	               2,386 원 		1 개
# 8 월 514663 지원 일회용기뚜껑( 	               2,024 원 		1 개
# ================================================================ Total Amount    7,594,394 원
#
#
#
# 9 월 424782 염지닭(생활맥주용  	           1,254,330 원 		21 개
# 9 월 424783 염지닭안심(생활맥주 	             455,400 원 		10 개
# 9 월 144398 심플로트 냉동감자( 	             443,674 원 		43 개
# 9 월 134356 심플로트 냉동감자( 	             438,240 원 		40 개
#
# 9 월 140440 심플로트 냉동감자( 	             399,256 원 		52 개
# 9 월 176689 소시지(생활맥주용  	             394,174 원 		82 개
# 9 월 232931 반건오징어(생활맥주 	             383,500 원 		13 개
# 9 월 163815 이츠웰 골뱅이캔(자 	             231,000 원 		75 개
# 9 월 116709 리코스 나쵸칩(45 	             191,400 원 		60 개
#
# 9 월 169394 샐러드믹스(생활맥주 	             187,200 원 		13 개
# 9 월 115722 사세통상 버팔로윙( 	             173,250 원 		15 개
# 9 월 118232 스팸 햄캔(마일드  	             169,400 원 		55 개
# 9 월 116981 사세통상 버팔로윙스 	             161,700 원 		15 개
# 9 월 201934 소고기육포(생활맥주 	             152,845 원 		35 개
#
# 9 월 215140 양파드레싱(생활맥주 	             138,600 원 		14 개
# 9 월 247491 뫼루니식품 레드소스 	             121,440 원 		16 개
# 9 월 124531 맥앤치즈볼(생활맥주 	             119,460 원 		30 개
# 9 월 146239 쉐프솔루션 김치볶음 	             100,100 원 		65 개
# 9 월 206578 길림양행 땅콩(껍질 	             100,100 원 		13 개
#
# 9 월 171838 팔도 비빔면(130 	              88,440 원 		3 개
# 9 월 166412 뫼루니식품 물결무늬 	              86,790 원 		6 개
# 9 월 145970 치킨무(외식체인전용 	              74,100 원 		13 개
# 9 월 401354 계란(특란_60g* 	              72,030 원 		10 개
# 9 월 526116 유산지(생활맥주용  	              66,000 원 		2 개
#
# 9 월 119863 삼조쎌텍 나쵸치즈소 	              63,910 원 		7 개
# 9 월 178883 코스터(생활맥주용  	              62,700 원 		1 개
# 9 월 100744 스프라이트 사이다( 	              61,564 원 		4 개
# 9 월 146391 쉐프솔루션 햄야채볶 	              56,558 원 		35 개
# 9 월 501386 트레펑(1L 막힌하 	              48,730 원 		20 개
#
# 9 월 127454 파로 할라페뇨(슬라 	              46,750 원 		5 개
# 9 월 146393 쉐프솔루션 해물볶음 	              44,939 원 		28 개
# 9 월 160016 오뚜기 케찹(스파우 	              34,760 원 		8 개
# 9 월 100743 코카콜라 콜라(캔_ 	              34,056 원 		2 개
# 9 월 242910 웰넛 건포도(500 	              30,360 원 		12 개
#
# 9 월 138389 이츠웰 초고추장(N 	              29,700 원 		9 개
# 9 월 512237 이츠웰 페이퍼타올( 	              21,450 원 		1 개
# 9 월 115364 삼진 살사소스(2K 	              19,800 원 		2 개
# 9 월 133941 유동 골뱅이캔(자연 	              15,400 원 		5 개
# 9 월 100353 백설 바삭튀김가루( 	              13,750 원 		5 개
#
# 9 월 514664 지원 일회용기(W- 	              13,726 원 		2 개
# 9 월 501326 스파크 세탁세제(5 	              12,617 원 		1 개
# 9 월 178733 물티슈(생활맥주용  	              12,100 원 		1 개
# 9 월 143790 이츠웰 참기름(NE 	              11,660 원 		1 개
# 9 월 215139 케이준드레싱(생활맥 	               9,955 원 		1 개
#
# 9 월 177058 미니고무장갑(생활맥 	               8,250 원 		1 개
# 9 월 500556 일회용기세트(1호_ 	               7,158 원 		3 개
# 9 월 514158 이츠웰 주방세제(그 	               6,232 원 		2 개
# 9 월 514663 지원 일회용기뚜껑( 	               4,048 원 		2 개
# 9 월 159365 유니푸드 양념소금( 	               1,100 원 		1 개
# ================================================================ Total Amount    6,673,702 원
#
#
#
# 10 월 424782 염지닭(생활맥주용  	           1,015,410 원 		17 개
# 10 월 134356 심플로트 냉동감자( 	             449,196 원 		41 개
# 10 월 424783 염지닭안심(생활맥주 	             318,780 원 		7 개
# 10 월 140440 심플로트 냉동감자( 	             291,764 원 		38 개
#
# 10 월 144398 심플로트 냉동감자( 	             257,950 원 		25 개
# 10 월 247491 뫼루니식품 레드소스 	             227,700 원 		30 개
# 10 월 176689 소시지(생활맥주용  	             216,315 원 		45 개
# 10 월 232931 반건오징어(생활맥주 	             177,000 원 		6 개
# 10 월 201934 소고기육포(생활맥주 	             174,680 원 		40 개
#
# 10 월 169394 샐러드믹스(생활맥주 	             144,000 원 		10 개
# 10 월 115722 사세통상 버팔로윙( 	             127,050 원 		11 개
# 10 월 163815 이츠웰 골뱅이캔(자 	             123,200 원 		40 개
# 10 월 215140 양파드레싱(생활맥주 	             118,800 원 		12 개
# 10 월 116981 사세통상 버팔로윙스 	             118,580 원 		11 개
#
# 10 월 206578 길림양행 땅콩(껍질 	             115,500 원 		15 개
# 10 월 116709 리코스 나쵸칩(45 	             111,650 원 		35 개
# 10 월 118232 스팸 햄캔(마일드  	              92,400 원 		30 개
# 10 월 166412 뫼루니식품 물결무늬 	              86,790 원 		6 개
# 10 월 177050 기름여과지(생활맥주 	              80,300 원 		1 개
#
# 10 월 145970 치킨무(외식체인전용 	              79,800 원 		14 개
# 10 월 124531 맥앤치즈볼(생활맥주 	              79,640 원 		20 개
# 10 월 119863 삼조쎌텍 나쵸치즈소 	              73,040 원 		8 개
# 10 월 115364 삼진 살사소스(2K 	              59,400 원 		6 개
# 10 월 127454 파로 할라페뇨(슬라 	              56,100 원 		6 개
#
# 10 월 100744 스프라이트 사이다( 	              46,173 원 		3 개
# 10 월 146239 쉐프솔루션 김치볶음 	              38,500 원 		25 개
# 10 월 100743 코카콜라 콜라(캔_ 	              34,056 원 		2 개
# 10 월 112371 칵테일냅킨(생활맥주 	              33,000 원 		1 개
# 10 월 171838 팔도 비빔면(130 	              29,480 원 		1 개
#
# 10 월 160016 오뚜기 케찹(스파우 	              26,070 원 		6 개
# 10 월 146391 쉐프솔루션 햄야채볶 	              24,239 원 		15 개
# 10 월 178733 물티슈(생활맥주용  	              24,200 원 		2 개
# 10 월 242910 웰넛 건포도(500 	              22,770 원 		9 개
# 10 월 401354 계란(특란_60g* 	              19,365 원 		3 개
#
# 10 월 111308 천일식품 새우볶음밥 	              17,930 원 		10 개
# 10 월 138389 이츠웰 초고추장(N 	              13,200 원 		4 개
# 10 월 154639 오뚜기 마요네즈(골 	              10,780 원 		1 개
# 10 월 215139 케이준드레싱(생활맥 	               9,955 원 		1 개
# 10 월 146393 쉐프솔루션 해물볶음 	               8,025 원 		5 개
#
# 10 월 135267 그라나파다노치즈(포 	               7,260 원 		1 개
# 10 월 139476 신영상회 파슬리후레 	               5,960 원 		1 개
# 10 월 500556 일회용기세트(1호_ 	               4,772 원 		2 개
# 10 월 514158 이츠웰 주방세제(그 	               3,116 원 		1 개
# 10 월 159365 유니푸드 양념소금( 	               1,100 원 		1 개
# ================================================================ Total Amount    4,974,996 원

# %% [markdown]
# ## 2. Monthly Product Details

# %% [markdown]
# ## Group by SKU, MONTH

# %%
sql_cmd = """
select
        sku, pname,
        month,
        sum(total) as gtotal,
        sum(qty) as qty
from OrderAll
group by sku, month
order by sku, month;
"""
cursor = conn.cursor()
cursor.execute(sql_cmd)
tuples = cursor.fetchall()

# %%
prev_sku = None
for tuple in tuples:
    #pname = tuple[1].replace("\n","-")
    pname = tuple[1]
    monthstring = str(tuple[2])+u'월'
    qtystring = str(tuple[4])+u'개' 
    eachmonth = [tuple[0], pname, monthstring, "{:>12,}원".format(tuple[4]), qtystring]
    
    if ( prev_sku != tuple[0]):
        print '='*90
        print ''
    prev_sku = tuple[0]
    print eachmonth[0], (eachmonth[1][:20]).ljust(30),'\t\t', eachmonth[2], '\t\t',eachmonth[3],'\t\t', eachmonth[4]
# Out:
# ==========================================================================================
#
# 100353 백설 바삭튀김가루(1Kg/EA) 미국           		8월 		           1원 		1개
# 100353 백설 바삭튀김가루(1Kg/EA) 미국           		9월 		           5원 		5개
# ==========================================================================================
#
# 100743 코카콜라 콜라(캔_355ml 355g           		7월 		           4원 		4개
# 100743 코카콜라 콜라(캔_355ml 355g           		8월 		           4원 		4개
# 100743 코카콜라 콜라(캔_355ml 355g           		9월 		           2원 		2개
# 100743 코카콜라 콜라(캔_355ml 355g           		10월 		           2원 		2개
# ==========================================================================================
#
# 100744 스프라이트 사이다(355ml 355g           		7월 		           5원 		5개
# 100744 스프라이트 사이다(355ml 355g           		8월 		           5원 		5개
# 100744 스프라이트 사이다(355ml 355g           		9월 		           4원 		4개
# 100744 스프라이트 사이다(355ml 355g           		10월 		           3원 		3개
# ==========================================================================================
#
# 105409 아담스 파마산치즈파우더(1Kg/EA)           		7월 		           2원 		2개
# 105409 아담스 파마산치즈파우더(1Kg/EA)           		8월 		           1원 		1개
# ==========================================================================================
#
# 111308 천일식품 새우볶음밥(300g/EA)            		7월 		          13원 		13개
# 111308 천일식품 새우볶음밥(300g/EA)            		8월 		          10원 		10개
# 111308 천일식품 새우볶음밥(300g/EA)            		10월 		          10원 		10개
# ==========================================================================================
#
# 112371 칵테일냅킨(생활맥주용 10000장입            		7월 		           1원 		1개
# 112371 칵테일냅킨(생활맥주용 10000장입            		8월 		           1원 		1개
# 112371 칵테일냅킨(생활맥주용 10000장입            		10월 		           1원 		1개
# ==========================================================================================
#
# 115364 삼진 살사소스(2Kg/EA)                		7월 		           4원 		4개
# 115364 삼진 살사소스(2Kg/EA)                		8월 		           6원 		6개
# 115364 삼진 살사소스(2Kg/EA)                		9월 		           2원 		2개
# 115364 삼진 살사소스(2Kg/EA)                		10월 		           6원 		6개
# ==========================================================================================
#
# 115722 사세통상 버팔로윙(1Kg/EA) 태국           		7월 		          21원 		21개
# 115722 사세통상 버팔로윙(1Kg/EA) 태국           		8월 		          11원 		11개
# 115722 사세통상 버팔로윙(1Kg/EA) 태국           		9월 		          15원 		15개
# 115722 사세통상 버팔로윙(1Kg/EA) 태국           		10월 		          11원 		11개
# ==========================================================================================
#
# 116709 리코스 나쵸칩(454g/EA) 미국-           		7월 		          84원 		84개
# 116709 리코스 나쵸칩(454g/EA) 미국-           		8월 		          66원 		66개
# 116709 리코스 나쵸칩(454g/EA) 미국-           		9월 		          60원 		60개
# 116709 리코스 나쵸칩(454g/EA) 미국-           		10월 		          35원 		35개
# ==========================================================================================
#
# 116981 사세통상 버팔로윙스틱(1Kg/EA)            		7월 		          21원 		21개
# 116981 사세통상 버팔로윙스틱(1Kg/EA)            		8월 		          16원 		16개
# 116981 사세통상 버팔로윙스틱(1Kg/EA)            		9월 		          15원 		15개
# 116981 사세통상 버팔로윙스틱(1Kg/EA)            		10월 		          11원 		11개
# ==========================================================================================
#
# 118232 스팸 햄캔(마일드 200g/EA)-※           		7월 		          45원 		45개
# 118232 스팸 햄캔(마일드 200g/EA)-※           		8월 		          60원 		60개
# 118232 스팸 햄캔(마일드 200g/EA)-※           		9월 		          55원 		55개
# 118232 스팸 햄캔(마일드 200g/EA)-※           		10월 		          30원 		30개
# ==========================================================================================
#
# 119863 삼조쎌텍 나쵸치즈소스(1Kg/EA)            		7월 		           6원 		6개
# 119863 삼조쎌텍 나쵸치즈소스(1Kg/EA)            		8월 		           9원 		9개
# 119863 삼조쎌텍 나쵸치즈소스(1Kg/EA)            		9월 		           7원 		7개
# 119863 삼조쎌텍 나쵸치즈소스(1Kg/EA)            		10월 		           8원 		8개
# ==========================================================================================
#
# 124531 맥앤치즈볼(생활맥주용 50G*4입 2           		7월 		          60원 		60개
# 124531 맥앤치즈볼(생활맥주용 50G*4입 2           		8월 		          42원 		42개
# 124531 맥앤치즈볼(생활맥주용 50G*4입 2           		9월 		          30원 		30개
# 124531 맥앤치즈볼(생활맥주용 50G*4입 2           		10월 		          20원 		20개
# ==========================================================================================
#
# 127454 파로 할라페뇨(슬라이스 3Kg/EA)           		7월 		          11원 		11개
# 127454 파로 할라페뇨(슬라이스 3Kg/EA)           		8월 		          10원 		10개
# 127454 파로 할라페뇨(슬라이스 3Kg/EA)           		9월 		           5원 		5개
# 127454 파로 할라페뇨(슬라이스 3Kg/EA)           		10월 		           6원 		6개
# ==========================================================================================
#
# 133941 유동 골뱅이캔(자연산 140g/EA)           		8월 		          10원 		10개
# 133941 유동 골뱅이캔(자연산 140g/EA)           		9월 		           5원 		5개
# ==========================================================================================
#
# 134356 심플로트 냉동감자(메가크런치 2.04           		7월 		          55원 		55개
# 134356 심플로트 냉동감자(메가크런치 2.04           		8월 		          45원 		45개
# 134356 심플로트 냉동감자(메가크런치 2.04           		9월 		          40원 		40개
# 134356 심플로트 냉동감자(메가크런치 2.04           		10월 		          41원 		41개
# ==========================================================================================
#
# 135267 그라나파다노치즈(포션 200g/EA)           		7월 		           2원 		2개
# 135267 그라나파다노치즈(포션 200g/EA)           		8월 		           3원 		3개
# 135267 그라나파다노치즈(포션 200g/EA)           		10월 		           1원 		1개
# ==========================================================================================
#
# 138389 이츠웰 초고추장(NEW 1Kg/EA)           		7월 		           7원 		7개
# 138389 이츠웰 초고추장(NEW 1Kg/EA)           		8월 		           7원 		7개
# 138389 이츠웰 초고추장(NEW 1Kg/EA)           		9월 		           9원 		9개
# 138389 이츠웰 초고추장(NEW 1Kg/EA)           		10월 		           4원 		4개
# ==========================================================================================
#
# 139476 신영상회 파슬리후레이크(250g/EA           		7월 		           1원 		1개
# 139476 신영상회 파슬리후레이크(250g/EA           		10월 		           1원 		1개
# ==========================================================================================
#
# 140440 심플로트 냉동감자(크링클컷웨지 2.2           		7월 		          62원 		62개
# 140440 심플로트 냉동감자(크링클컷웨지 2.2           		8월 		          50원 		50개
# 140440 심플로트 냉동감자(크링클컷웨지 2.2           		9월 		          52원 		52개
# 140440 심플로트 냉동감자(크링클컷웨지 2.2           		10월 		          38원 		38개
# ==========================================================================================
#
# 143790 이츠웰 참기름(NEW_캔_1L 916           		9월 		           1원 		1개
# ==========================================================================================
#
# 144398 심플로트 냉동감자(세이보리_스트레이트           		7월 		          54원 		54개
# 144398 심플로트 냉동감자(세이보리_스트레이트           		8월 		          33원 		33개
# 144398 심플로트 냉동감자(세이보리_스트레이트           		9월 		          43원 		43개
# 144398 심플로트 냉동감자(세이보리_스트레이트           		10월 		          25원 		25개
# ==========================================================================================
#
# 145970 치킨무(외식체인전용 5Kg/EA) 한           		7월 		          16원 		16개
# 145970 치킨무(외식체인전용 5Kg/EA) 한           		8월 		          18원 		18개
# 145970 치킨무(외식체인전용 5Kg/EA) 한           		9월 		          13원 		13개
# 145970 치킨무(외식체인전용 5Kg/EA) 한           		10월 		          14원 		14개
# ==========================================================================================
#
# 146239 쉐프솔루션 김치볶음밥(300g/EA)           		7월 		          38원 		38개
# 146239 쉐프솔루션 김치볶음밥(300g/EA)           		8월 		          45원 		45개
# 146239 쉐프솔루션 김치볶음밥(300g/EA)           		9월 		          65원 		65개
# 146239 쉐프솔루션 김치볶음밥(300g/EA)           		10월 		          25원 		25개
# ==========================================================================================
#
# 146391 쉐프솔루션 햄야채볶음밥(300g/EA           		7월 		          12원 		12개
# 146391 쉐프솔루션 햄야채볶음밥(300g/EA           		8월 		          30원 		30개
# 146391 쉐프솔루션 햄야채볶음밥(300g/EA           		9월 		          35원 		35개
# 146391 쉐프솔루션 햄야채볶음밥(300g/EA           		10월 		          15원 		15개
# ==========================================================================================
#
# 146393 쉐프솔루션 해물볶음밥(300g/EA)           		7월 		           8원 		8개
# 146393 쉐프솔루션 해물볶음밥(300g/EA)           		8월 		          15원 		15개
# 146393 쉐프솔루션 해물볶음밥(300g/EA)           		9월 		          28원 		28개
# 146393 쉐프솔루션 해물볶음밥(300g/EA)           		10월 		           5원 		5개
# ==========================================================================================
#
# 154639 오뚜기 마요네즈(골드 스파우트팩 3.           		7월 		           2원 		2개
# 154639 오뚜기 마요네즈(골드 스파우트팩 3.           		8월 		           2원 		2개
# 154639 오뚜기 마요네즈(골드 스파우트팩 3.           		10월 		           1원 		1개
# ==========================================================================================
#
# 159365 유니푸드 양념소금(마파치킨용 3.5g           		7월 		           2원 		2개
# 159365 유니푸드 양념소금(마파치킨용 3.5g           		9월 		           1원 		1개
# 159365 유니푸드 양념소금(마파치킨용 3.5g           		10월 		           1원 		1개
# ==========================================================================================
#
# 160016 오뚜기 케찹(스파우트팩 3.3Kg/E           		7월 		           6원 		6개
# 160016 오뚜기 케찹(스파우트팩 3.3Kg/E           		8월 		          10원 		10개
# 160016 오뚜기 케찹(스파우트팩 3.3Kg/E           		9월 		           8원 		8개
# 160016 오뚜기 케찹(스파우트팩 3.3Kg/E           		10월 		           6원 		6개
# ==========================================================================================
#
# 163815 이츠웰 골뱅이캔(자연산 140g/EA           		7월 		         112원 		112개
# 163815 이츠웰 골뱅이캔(자연산 140g/EA           		8월 		         105원 		105개
# 163815 이츠웰 골뱅이캔(자연산 140g/EA           		9월 		          75원 		75개
# 163815 이츠웰 골뱅이캔(자연산 140g/EA           		10월 		          40원 		40개
# ==========================================================================================
#
# 166412 뫼루니식품 물결무늬파우더(데일리비어용           		7월 		           8원 		8개
# 166412 뫼루니식품 물결무늬파우더(데일리비어용           		8월 		           7원 		7개
# 166412 뫼루니식품 물결무늬파우더(데일리비어용           		9월 		           6원 		6개
# 166412 뫼루니식품 물결무늬파우더(데일리비어용           		10월 		           6원 		6개
# ==========================================================================================
# 166413 뫼루니 양념치킨소스(데일리비어용 양념           		7월 		          11원 		11개
# 166413 뫼루니 양념치킨소스(데일리비어용 양념           		8월 		          14원 		14개
# ==========================================================================================
#
# 169394 샐러드믹스(생활맥주용 150g*5입            		7월 		          24원 		24개
# 169394 샐러드믹스(생활맥주용 150g*5입            		8월 		          20원 		20개
# 169394 샐러드믹스(생활맥주용 150g*5입            		9월 		          13원 		13개
# 169394 샐러드믹스(생활맥주용 150g*5입            		10월 		          10원 		10개
# ==========================================================================================
#
# 171838 팔도 비빔면(130g/EA) 40EA           		7월 		           3원 		3개
# 171838 팔도 비빔면(130g/EA) 40EA           		8월 		           2원 		2개
# 171838 팔도 비빔면(130g/EA) 40EA           		9월 		           3원 		3개
# 171838 팔도 비빔면(130g/EA) 40EA           		10월 		           1원 		1개
# ==========================================================================================
#
# 176689 소시지(생활맥주용 천연돈장_70g*4           		7월 		          65원 		65개
# 176689 소시지(생활맥주용 천연돈장_70g*4           		8월 		         102원 		102개
# 176689 소시지(생활맥주용 천연돈장_70g*4           		9월 		          82원 		82개
# 176689 소시지(생활맥주용 천연돈장_70g*4           		10월 		          45원 		45개
# ==========================================================================================
#
# 177050 기름여과지(생활맥주용 100매 BOX           		10월 		           1원 		1개
# ==========================================================================================
#
# 177058 미니고무장갑(생활맥주용 10입 EA)           		7월 		           1원 		1개
# 177058 미니고무장갑(생활맥주용 10입 EA)           		8월 		           2원 		2개
# 177058 미니고무장갑(생활맥주용 10입 EA)           		9월 		           1원 		1개
# ==========================================================================================
#
# 178733 물티슈(생활맥주용 500입 BOX)            		9월 		           1원 		1개
# 178733 물티슈(생활맥주용 500입 BOX)            		10월 		           2원 		2개
# ==========================================================================================
#
# 178883 코스터(생활맥주용 600매 EA)             		7월 		           1원 		1개
# 178883 코스터(생활맥주용 600매 EA)             		9월 		           1원 		1개
# ==========================================================================================
#
# 201934 소고기육포(생활맥주용 70g/EA)            		7월 		          80원 		80개
# 201934 소고기육포(생활맥주용 70g/EA)            		8월 		          55원 		55개
# 201934 소고기육포(생활맥주용 70g/EA)            		9월 		          35원 		35개
# 201934 소고기육포(생활맥주용 70g/EA)            		10월 		          40원 		40개
# ==========================================================================================
#
# 206578 길림양행 땅콩(껍질무_1/2태 1Kg           		7월 		          18원 		18개
# 206578 길림양행 땅콩(껍질무_1/2태 1Kg           		8월 		          15원 		15개
# 206578 길림양행 땅콩(껍질무_1/2태 1Kg           		9월 		          13원 		13개
# 206578 길림양행 땅콩(껍질무_1/2태 1Kg           		10월 		          15원 		15개
# ==========================================================================================
#
# 215139 케이준드레싱(생활맥주용 2Kg/EA)           		7월 		           2원 		2개
# 215139 케이준드레싱(생활맥주용 2Kg/EA)           		8월 		           4원 		4개
# 215139 케이준드레싱(생활맥주용 2Kg/EA)           		9월 		           1원 		1개
# 215139 케이준드레싱(생활맥주용 2Kg/EA)           		10월 		           1원 		1개
# ==========================================================================================
#
# 215140 양파드레싱(생활맥주용 2Kg/EA)            		7월 		          16원 		16개
# 215140 양파드레싱(생활맥주용 2Kg/EA)            		8월 		          16원 		16개
# 215140 양파드레싱(생활맥주용 2Kg/EA)            		9월 		          14원 		14개
# 215140 양파드레싱(생활맥주용 2Kg/EA)            		10월 		          12원 		12개
# ==========================================================================================
#
# 232931 반건오징어(생활맥주용 10미 1.3K           		7월 		          12원 		12개
# 232931 반건오징어(생활맥주용 10미 1.3K           		8월 		          20원 		20개
# 232931 반건오징어(생활맥주용 10미 1.3K           		9월 		          13원 		13개
# 232931 반건오징어(생활맥주용 10미 1.3K           		10월 		           6원 		6개
# ==========================================================================================
#
# 242910 웰넛 건포도(500g/EA) 미국-※           		7월 		          17원 		17개
# 242910 웰넛 건포도(500g/EA) 미국-※           		8월 		          10원 		10개
# 242910 웰넛 건포도(500g/EA) 미국-※           		9월 		          12원 		12개
# 242910 웰넛 건포도(500g/EA) 미국-※           		10월 		           9원 		9개
# ==========================================================================================
#
# 247491 뫼루니식품 레드소스(데일리비어용 양념           		8월 		           2원 		2개
# 247491 뫼루니식품 레드소스(데일리비어용 양념           		9월 		          16원 		16개
# 247491 뫼루니식품 레드소스(데일리비어용 양념           		10월 		          30원 		30개
# ==========================================================================================
#
# 401354 계란(특란_60g*30입 1.8Kg/           		7월 		           8원 		8개
# 401354 계란(특란_60g*30입 1.8Kg/           		8월 		          10원 		10개
# 401354 계란(특란_60g*30입 1.8Kg/           		9월 		          10원 		10개
# 401354 계란(특란_60g*30입 1.8Kg/           		10월 		           3원 		3개
# ==========================================================================================
#
# 424782 염지닭(생활맥주용 9호_9각 850g           		7월 		          28원 		28개
# 424782 염지닭(생활맥주용 9호_9각 850g           		8월 		          26원 		26개
# 424782 염지닭(생활맥주용 9호_9각 850g           		9월 		          21원 		21개
# 424782 염지닭(생활맥주용 9호_9각 850g           		10월 		          17원 		17개
# ==========================================================================================
#
# 424783 염지닭안심(생활맥주용 1Kg/EA)            		7월 		          15원 		15개
# 424783 염지닭안심(생활맥주용 1Kg/EA)            		8월 		           8원 		8개
# 424783 염지닭안심(생활맥주용 1Kg/EA)            		9월 		          10원 		10개
# 424783 염지닭안심(생활맥주용 1Kg/EA)            		10월 		           7원 		7개
# ==========================================================================================
#
# 500556 일회용기세트(1호_70*30mm_10           		8월 		           1원 		1개
# 500556 일회용기세트(1호_70*30mm_10           		9월 		           3원 		3개
# 500556 일회용기세트(1호_70*30mm_10           		10월 		           2원 		2개
# ==========================================================================================
#
# 501191 하이코리아 락스(2L EA)                		7월 		          12원 		12개
# ==========================================================================================
#
# 501326 스파크 세탁세제(5kg EA)               		8월 		           1원 		1개
# 501326 스파크 세탁세제(5kg EA)               		9월 		           1원 		1개
# ==========================================================================================
#
# 501386 트레펑(1L 막힌하수구용 EA)              		7월 		          10원 		10개
# 501386 트레펑(1L 막힌하수구용 EA)              		8월 		          20원 		20개
# 501386 트레펑(1L 막힌하수구용 EA)              		9월 		          20원 		20개
# ==========================================================================================
#
# 503517 스카치브라이트 양면스폰지수세미(EA)           		7월 		           5원 		5개
# ==========================================================================================
#
# 512186 이츠웰 롤백(소_25*35cm_500           		7월 		           2원 		2개
# 512186 이츠웰 롤백(소_25*35cm_500           		8월 		           3원 		3개
# ==========================================================================================
#
# 512188 이츠웰 롤백(중_30*40cm_500           		7월 		           2원 		2개
# ==========================================================================================
#
# 512237 이츠웰 페이퍼타올(핸드타올_4500매           		9월 		           1원 		1개
# ==========================================================================================
#
# 514151 이츠웰 다용도봉투(파란색_30L_48           		7월 		           3원 		3개
# ==========================================================================================
#
# 514158 이츠웰 주방세제(그린알로_3kg EA           		9월 		           2원 		2개
# 514158 이츠웰 주방세제(그린알로_3kg EA           		10월 		           1원 		1개
# ==========================================================================================
#
# 514663 지원 일회용기뚜껑(W-3_75mm_1           		8월 		           1원 		1개
# 514663 지원 일회용기뚜껑(W-3_75mm_1           		9월 		           2원 		2개
# ==========================================================================================
#
# 514664 지원 일회용기(W-3_75*65mm_           		9월 		           2원 		2개
# ==========================================================================================
#
# 526116 유산지(생활맥주용 1000개 EA)            		7월 		           2원 		2개
# 526116 유산지(생활맥주용 1000개 EA)            		8월 		           1원 		1개
# 526116 유산지(생활맥주용 1000개 EA)            		9월 		           2원 		2개
# ==========================================================================================
#
# 526117 비닐백(생활맥주용 100매 EA)             		7월 		           4원 		4개

# %% [markdown]
# ##  3. Make the SQL Result as the DataFrame Directly

# %%
sql_cmd = """
select
        sku, pname,
        month,
        sum(total) as gtotal,
        sum(qty) as tqty
from OrderAll
group by sku, month
order by sku, month;
"""
SQL_Result_DF1 = pd.read_sql_query(sql_cmd, conn)

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
pd.options.display.max_rows = 999

# %%
SQL_Result_DF1.columns
# Out:
# Index([u'sku', u'pname', u'month', u'gtotal'], dtype='object')

# %%
SQL_Result_DF1.set_index(['sku','pname', 'month'])
# Out:
#                                                                 gtotal  tqty
# sku    pname                                            month
# 100353 백설 바삭튀김가루(1Kg/EA) 미국-※미국산                        8         2750     1
#                                                         9        13750     5
# 100743 코카콜라 콜라(캔_355ml 355g/EA) 한국 24EA/BOX-※국내산        7        68112     4
#                                                         8        68112     4
#                                                         9        34056     2
#                                                         10       34056     2
#                                                         11       34980     2
# 100744 스프라이트 사이다(355ml 355g/EA) 한국 24EA/BOX-※국내산        7        76955     5
#                                                         8        76955     5
#                                                         9        61564     4
#                                                         10       46173     3
#                                                         11       30782     2
# 105409 아담스 파마산치즈파우더(1Kg/EA)                             7        24200     2
#                                                         8        12100     1
# 111308 천일식품 새우볶음밥(300g/EA)                              7        23309    13
#                                                         8        17930    10
#                                                         10       17930    10
# 112371 칵테일냅킨(생활맥주용 10000장입 BOX) 1EA/BOX                 7        33000     1
#                                                         8        33000     1
#                                                         10       33000     1
# 115364 삼진 살사소스(2Kg/EA)                                  7        39600     4
#                                                         8        59400     6
#                                                         9        19800     2
#                                                         10       59400     6
# 115722 사세통상 버팔로윙(1Kg/EA) 태국-※닭고기(태국산)                   7       242550    21
#                                                         8       127050    11
#                                                         9       173250    15
#                                                         10      127050    11
#                                                         11      184800    16
# 116709 리코스 나쵸칩(454g/EA) 미국-※미국                          7       267960    84
#                                                         8       210540    66
#                                                         9       191400    60
#                                                         10      111650    35
#                                                         11      127600    40
# 116981 사세통상 버팔로윙스틱(1Kg/EA) 태국-※닭고기(태국산)                 7       226380    21
#                                                         8       172480    16
#                                                         9       161700    15
#                                                         10      118580    11
#                                                         11      194040    18
# 118232 스팸 햄캔(마일드 200g/EA)-※돼지고기(수입산 80%+국내산 20%) 96.27% 7       138600    45
#                                                         8       184800    60
#                                                         9       169400    55
#                                                         10       92400    30
#                                                         11       92400    30
# 119863 삼조쎌텍 나쵸치즈소스(1Kg/EA)                              7        54780     6
#                                                         8        82170     9
#                                                         9        63910     7
#                                                         10       73040     8
#                                                         11       18260     2
# 124531 맥앤치즈볼(생활맥주용 50G*4입 200g/EA)                      7       238920    60
#                                                         8       167244    42
#                                                         9       119460    30
#                                                         10       79640    20
#                                                         11      139370    35
# 127454 파로 할라페뇨(슬라이스 3Kg/EA)                             7       102850    11
#                                                         8        93500    10
#                                                         9        46750     5
#                                                         10       56100     6
#                                                         11       18700     2
# 133941 유동 골뱅이캔(자연산 140g/EA)                             8        30800    10
#                                                         9        15400     5
# 134356 심플로트 냉동감자(메가크런치 2.04Kg/EA)                       7       602580    55
#                                                         8       493020    45
#                                                         9       438240    40
#                                                         10      449196    41
#                                                         11      295812    27
# 135267 그라나파다노치즈(포션 200g/EA)                             7        14520     2
#                                                         8        21780     3
#                                                         10        7260     1
# 138389 이츠웰 초고추장(NEW 1Kg/EA)                             7        23100     7
#                                                         8        23100     7
#                                                         9        29700     9
#                                                         10       13200     4
#                                                         11        9900     3
# 139476 신영상회 파슬리후레이크(250g/EA)                            7         5960     1
#                                                         10        5960     1
# 140440 심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)                      7       476036    62
#                                                         8       383900    50
#                                                         9       399256    52
#                                                         10      291764    38
#                                                         11      253374    33
# 143790 이츠웰 참기름(NEW_캔_1L 916g/EA) 수입산-※참깨(베트남산,미얀마산)     9        11660     1
# 144398 심플로트 냉동감자(세이보리_스트레이트컷 2.26Kg/EA)                 7       557172    54
#                                                         8       340494    33
#                                                         9       443674    43
#                                                         10      257950    25
#                                                         11      154770    15
# 145970 치킨무(외식체인전용 5Kg/EA) 한국-※국내산                       7        91200    16
#                                                         8       102600    18
#                                                         9        74100    13
#                                                         10       79800    14
#                                                         11       51300     9
# 146239 쉐프솔루션 김치볶음밥(300g/EA)                             7        58520    38
#                                                         8        69300    45
#                                                         9       100100    65
#                                                         10       38500    25
#                                                         11       15400    10
# 146391 쉐프솔루션 햄야채볶음밥(300g/EA)                            7        19392    12
#                                                         8        48479    30
#                                                         9        56558    35
#                                                         10       24239    15
#                                                         11       56558    35
# 146393 쉐프솔루션 해물볶음밥(300g/EA)                             7        12840     8
#                                                         8        24074    15
#                                                         9        44939    28
#                                                         10        8025     5
#                                                         11        8025     5
# 154639 오뚜기 마요네즈(골드 스파우트팩 3.2Kg/EA)                      7        21560     2
#                                                         8        21560     2
#                                                         10       10780     1
#                                                         11       10780     1
# 159365 유니푸드 양념소금(마파치킨용 3.5g*90입 315g/EA)                7         2200     2
#                                                         9         1100     1
#                                                         10        1100     1
# 160016 오뚜기 케찹(스파우트팩 3.3Kg/EA)                           7        26070     6
#                                                         8        43450    10
#                                                         9        34760     8
#                                                         10       26070     6
#                                                         11       17380     4
# 163815 이츠웰 골뱅이캔(자연산 140g/EA)                            7       344960   112
#                                                         8       323400   105
#                                                         9       231000    75
#                                                         10      123200    40
#                                                         11      123200    40
# 166412 뫼루니식품 물결무늬파우더(데일리비어용 매운맛 5Kg/EA) 미국-※미국산         7       115720     8
#                                                         8       101255     7
#                                                         9        86790     6
#                                                         10       86790     6
#                                                         11       43395     3
# 166413 뫼루니 양념치킨소스(데일리비어용 양념_뫼루니 2Kg/EA)                 7        83490    11
#                                                         8       106260    14
# 169394 샐러드믹스(생활맥주용 150g*5입 750g/BOX) 한국 1EA/BOX-※국내산    7       345600    24
#                                                         8       288000    20
#                                                         9       187200    13
#                                                         10      144000    10
#                                                         11      158400    11
# 171838 팔도 비빔면(130g/EA) 40EA/BOX                         7        88440     3
#                                                         8        58960     2
#                                                         9        88440     3
#                                                         10       29480     1
#                                                         11       29480     1
# 176689 소시지(생활맥주용 천연돈장_70g*4입 280g/EA) 한국-※돼지고기(국내산)     7       312455    65
#                                                         8       490314   102
#                                                         9       394174    82
#                                                         10      216315    45
#                                                         11      264385    55
# 177050 기름여과지(생활맥주용 100매 BOX) 1EA/BOX                    10       80300     1
# 177058 미니고무장갑(생활맥주용 10입 EA)                             7         8250     1
#                                                         8        16500     2
#                                                         9         8250     1
# 178733 물티슈(생활맥주용 500입 BOX) 1EA/BOX                      9        12100     1
#                                                         10       24200     2
# 178883 코스터(생활맥주용 600매 EA)                               7        62700     1
#                                                         9        62700     1
# 201934 소고기육포(생활맥주용 70g/EA) 호주-※호주산                      7       349360    80
#                                                         8       240185    55
#                                                         9       152845    35
#                                                         10      174680    40
#                                                         11      174680    40
# 206578 길림양행 땅콩(껍질무_1/2태 1Kg/PAC)-※이력번호:10931-17-060142M 7       138600    18
#        길림양행 땅콩(껍질무_1/2태 1Kg/PAC)-※이력번호:13361-17-300713M 8       115500    15
#        길림양행 땅콩(껍질무_1/2태 1Kg/PAC)-※이력번호:10931-17080202M  9       100100    13
#                                                         10      115500    15
#        길림양행 땅콩(껍질무_1/2태 1Kg/PAC)-※이력번호:10931-17-090163M 11       92400    12
# 215139 케이준드레싱(생활맥주용 2Kg/EA)                             7        19910     2
#                                                         8        39820     4
#                                                         9         9955     1
#                                                         10        9955     1
#                                                         11        9955     1
# 215140 양파드레싱(생활맥주용 2Kg/EA)                              7       158400    16
#                                                         8       158400    16
#                                                         9       138600    14
#                                                         10      118800    12
#                                                         11      108900    11
# 232931 반건오징어(생활맥주용 10미 1.3Kg/EA) 한국-※국내산                7       354000    12
#                                                         8       590000    20
#                                                         9       383500    13
#                                                         10      177000     6
#                                                         11      270500     9
# 242910 웰넛 건포도(500g/EA) 미국-※미국산                          7        43010    17
#                                                         8        25300    10
#                                                         9        30360    12
#                                                         10       22770     9
#                                                         11       20240     8
# 247491 뫼루니식품 레드소스(데일리비어용 양념치킨용 2Kg/EA)                  8        15180     2
#                                                         9       121440    16
#                                                         10      227700    30
#                                                         11       45540     6
# 251901 냉동감자(생활맥주용 스파이시스트레이트컷 2.04Kg/EA)                 11       68992     7
# 251902 냉동감자(생활맥주용 클리어코트슈스트링 2.04Kg/EA)                  11       68992     7
# 401354 계란(특란_60g*30입 1.8Kg/PAC) 한국-※달걀(국내산)             7        75716     8
#                                                         8        90590    10
#                                                         9        72030    10
#                                                         10       19365     3
#                                                         11       30242     5
# 424782 염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX                7      1672440    28
#                                                         8      1552980    26
#                                                         9      1254330    21
#                                                         10     1015410    17
#                                                         11      657030    11
# 424783 염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX                      7       683100    15
#                                                         8       364320     8
#                                                         9       455400    10
#                                                         10      318780     7
#                                                         11      318780     7
# 500556 일회용기세트(1호_70*30mm_100입 다용도 PAC)                  8         2386     1
#                                                         9         7158     3
#                                                         10        4772     2
# 501191 하이코리아 락스(2L EA)                                  7        12316    12
# 501326 스파크 세탁세제(5kg EA)                                 8        12617     1
#                                                         9        12617     1
# 501386 트레펑(1L 막힌하수구용 EA)                                7        24365    10
#                                                         8        48730    20
#                                                         9        48730    20
# 503517 스카치브라이트 양면스폰지수세미(EA)                             7         4813     5
# 512186 이츠웰 롤백(소_25*35cm_500입 EA)                        7         5390     2
#                                                         8         8085     3
#                                                         11       10780     4
# 512188 이츠웰 롤백(중_30*40cm_500입 EA)                        7         7700     2
# 512237 이츠웰 페이퍼타올(핸드타올_4500매 BOX) 1EA/BOX                9        21450     1
# 514151 이츠웰 다용도봉투(파란색_30L_48*64cm_100매 EA)               7         9900     3
# 514158 이츠웰 주방세제(그린알로_3kg EA)                            9         6232     2
#                                                         10        3116     1
# 514663 지원 일회용기뚜껑(W-3_75mm_100입 EA)                      8         2024     1
#                                                         9         4048     2
# 514664 지원 일회용기(W-3_75*65mm_100입 EA)                     9        13726     2
# 526116 유산지(생활맥주용 1000개 EA)                              7        66000     2
#                                                         8        33000     1
#                                                         9        66000     2
#                                                         11       66000     2
# 526117 비닐백(생활맥주용 100매 EA)                               7        39600     4
#                                                         11       49500     5

# %%
SQL_Result_DF1.set_index(['sku', 'pname', 'month'])[:15].unstack(level=-1)
# Out:
#                                                    gtotal                    \
# month                                                  7        8        9
# sku    pname
# 100353 백설 바삭튀김가루(1Kg/EA) 미국-※미국산                      NaN   2750.0  13750.0
# 100743 코카콜라 콜라(캔_355ml 355g/EA) 한국 24EA/BOX-※국내산  68112.0  68112.0  34056.0
# 100744 스프라이트 사이다(355ml 355g/EA) 한국 24EA/BOX-※국내산  76955.0  76955.0  61564.0
# 105409 아담스 파마산치즈파우더(1Kg/EA)                       24200.0  12100.0      NaN
# 111308 천일식품 새우볶음밥(300g/EA)                        23309.0      NaN      NaN
#
#                                                                     tqty       \
# month                                                  10       11    7    8
# sku    pname
# 100353 백설 바삭튀김가루(1Kg/EA) 미국-※미국산                      NaN      NaN   NaN  1.0
# 100743 코카콜라 콜라(캔_355ml 355g/EA) 한국 24EA/BOX-※국내산  34056.0  34980.0   4.0  4.0
# 100744 스프라이트 사이다(355ml 355g/EA) 한국 24EA/BOX-※국내산  46173.0  30782.0   5.0  5.0
# 105409 아담스 파마산치즈파우더(1Kg/EA)                           NaN      NaN   2.0  1.0
# 111308 천일식품 새우볶음밥(300g/EA)                            NaN      NaN  13.0  NaN
#
#
# month                                              9    10   11
# sku    pname
# 100353 백설 바삭튀김가루(1Kg/EA) 미국-※미국산                  5.0  NaN  NaN
# 100743 코카콜라 콜라(캔_355ml 355g/EA) 한국 24EA/BOX-※국내산  2.0  2.0  2.0
# 100744 스프라이트 사이다(355ml 355g/EA) 한국 24EA/BOX-※국내산  4.0  3.0  2.0
# 105409 아담스 파마산치즈파우더(1Kg/EA)                       NaN  NaN  NaN
# 111308 천일식품 새우볶음밥(300g/EA)                        NaN  NaN  NaN

# %% [markdown]
# ## Font in Plot

# %%
matplotlib.matplotlib_fname()
# Out:
# u'/Users/kylelee/anaconda2/lib/python2.7/site-packages/matplotlib/mpl-data/matplotlibrc'

# %%
import matplotlib.font_manager as fm
fm.get_fontconfig_fonts()
# Out:
# []

# %%
SQL_Result_DF1.set_index(['sku', 'pname', 'month'])[:15].unstack(level=-1).plot(kind='bar', stacked=False)
plt.rcParams["font.family"] = 'AppleMyungjo'
plt.rcParams['font.size'] = 8
plt.title(u'품목별 월별 매출현황' )
plt.show()

# %% [markdown]
# # Test Section

# %% [markdown]
# ### Truncate unicode string with Unicode utf-8

# %%
print tuple[1]
def unicode_truncate(s, length, encoding='utf-8'):
    encoded = s.encode(encoding)[:length]
    return encoded.decode(encoding, 'ignore')
print unicode_truncate(tuple[1], 60)
# Out:
# 백설 바삭튀김가루(1Kg/EA) 미국
# ※미국산
# 백설 바삭튀김가루(1Kg/EA) 미국
# ※미국산

# %% [markdown]
# ### tuple insertion

# %%
 t1 = ( (1, 'p100', 'JUL', 20), (1, 'p100', 'AUG', 30),
        (2, 'p200', 'JUL', 10), (2, 'p200', 'AUG', 40), (2, 'p200', 'SEP', 50),
        (3, 'p300', 'JUL', 40),
        (4, 'p400', 'JUL', 10), (4, 'p400', 'AUG', 20), (4, 'p400', 'SEP', 40), (4, 'p400', 'OCT', 60)
      )

# %%
t1
# Out:
# ((1, 'p100', 'JUL', 20),
#  (1, 'p100', 'AUG', 30),
#  (2, 'p200', 'JUL', 10),
#  (2, 'p200', 'AUG', 40),
#  (2, 'p200', 'SEP', 50),
#  (3, 'p300', 'JUL', 40),
#  (4, 'p400', 'JUL', 10),
#  (4, 'p400', 'AUG', 20),
#  (4, 'p400', 'SEP', 40),
#  (4, 'p400', 'OCT', 60))

# %% [markdown]
# ### DataFrame from dictionary

# %%
from pandas import Series, DataFrame
import numpy as np


dict1 = {'JUL':[10,20,30,40],
         'AUG':[11,21,31,41],
         'SEP':[12,22,32,42],
         'OCT':[13,23,33,43]
        }
df1 = DataFrame(dict1, columns=['JUL', 'AUG', 'SEP', 'OCT'], index=['p1','p2', 'p3','p4'])
df1
# Out:
#     JUL  AUG  SEP  OCT
# p1   10   11   12   13
# p2   20   21   22   23
# p3   30   31   32   33
# p4   40   41   42   43

# %% [markdown]
# ### new row insertion with dict form into DataFrame

# %%
df1.loc['p4'] = {'JUL':14, 'AUG':24, 'SEP':34, 'OCT':44}
df1
# Out:
#     JUL  AUG  SEP  OCT
# p1   10   11   12   13
# p2   20   21   22   23
# p3   30   31   32   33
# p4   14   24   34   44

# %%
df1.loc['p5'] = [50, 51, 52, 53]
df1
# Out:
#     JUL  AUG  SEP  OCT
# p1   10   11   12   13
# p2   20   21   22   23
# p3   30   31   32   33
# p4   14   24   34   44
# p5   50   51   52   53

# %% [markdown]
# ###  Test Unstack

# %%
df1.unstack(level=0)
# Out:
# JUL  p1    10
#      p2    20
#      p3    30
#      p4    14
#      p5    50
# AUG  p1    11
#      p2    21
#      p3    31
#      p4    24
#      p5    51
# SEP  p1    12
#      p2    22
#      p3    32
#      p4    34
#      p5    52
# OCT  p1    13
#      p2    23
#      p3    33
#      p4    44
#      p5    53
# dtype: int64

# %%
index = pd.MultiIndex.from_tuples([('one', 'a'), ('one', 'b'),
                                   ('two', 'a'), ('two', 'b')])
s1 = Series(np.arange(1.0, 5.0), index=index)

# %%
s1
# Out:
# one  a    1.0
#      b    2.0
# two  a    3.0
#      b    4.0
# dtype: float64

# %%
s.unstack(level=-1)
# Out:
#        a    b
# one  1.0  2.0
# two  3.0  4.0

# %% [markdown]
# ###  DataFrame with unstackI()

# %%
dfmi = DataFrame(dict1, columns=['JUL', 'AUG', 'SEP', 'OCT'], index=index)
dfmi
# Out:
#        JUL  AUG  SEP  OCT
# one a   10   11   12   13
#     b   20   21   22   23
# two a   30   31   32   33
#     b   40   41   42   43

# %%
dfmi.unstack(level=-1)
# Out:
#     JUL     AUG     SEP     OCT
#       a   b   a   b   a   b   a   b
# one  10  20  11  21  12  22  13  23
# two  30  40  31  41  32  42  33  43

# %%
dfmi.unstack(level=0)
# Out:
#   JUL     AUG     SEP     OCT
#   one two one two one two one two
# a  10  30  11  31  12  32  13  33
# b  20  40  21  41  22  42  23  43

# %%
dfmi.unstack(level=0).plot(kind='bar', stacked=True)

# %%
dfmi.unstack(level=-2)
# Out:
#   JUL     AUG     SEP     OCT
#   one two one two one two one two
# a  10  30  11  31  12  32  13  33
# b  20  40  21  41  22  42  23  43

# %% [markdown]
# ### Condition check of tuples and Make a dict from tuple elements

# %%
t1
# Out:
# ((1, 'p100', 'JUL', 20),
#  (1, 'p100', 'AUG', 30),
#  (2, 'p200', 'JUL', 10),
#  (2, 'p200', 'AUG', 40),
#  (2, 'p200', 'SEP', 50),
#  (3, 'p300', 'JUL', 40),
#  (4, 'p400', 'JUL', 10),
#  (4, 'p400', 'AUG', 20),
#  (4, 'p400', 'SEP', 40),
#  (4, 'p400', 'OCT', 60))

# %%
colarray = ['JUL', 'AUG', 'SEP', 'OCT']

prev = None
new_d = {'JUL':None, 'AUG':None, 'SEP':None, 'OCT':None}
dfdic = DataFrame(None, columns=colarray)
for t in t1:    
    if prev != t[0] and prev != None:
        print new_d
        dfdic.loc[t[1]] = new_d
        new_d = {'JUL':None, 'AUG':None, 'SEP':None, 'OCT':None}
        
    new_d[t[2]]= t[3]
    prev = t[0]
print new_d
# Out:
# {'OCT': None, 'AUG': 30, 'JUL': 20, 'SEP': None}
# {'OCT': None, 'AUG': 40, 'JUL': 10, 'SEP': 50}
# {'OCT': None, 'AUG': None, 'JUL': 40, 'SEP': None}
# {'OCT': 60, 'AUG': 20, 'JUL': 10, 'SEP': 40}

# %%
dfdic
# Out:
#        JUL   AUG   SEP  OCT
# p200  20.0  30.0   NaN  NaN
# p300  10.0  40.0  50.0  NaN
# p400  40.0   NaN   NaN  NaN

# %%
df1.loc['p100'] = [None, None, None, None]
df1.loc['p100']['JUL'] = 299

df1
# Out:
#       JUL   AUG   SEP   OCT
# p1     10    11    12    13
# p2     20    21    22    23
# p3     30    31    32    33
# p4     14    24    34    44
# p100  299  None  None  None

# %% [markdown]
# ### SQL result to DataFrame in SQLite3

# %%
myFrame = pd.read_sql_query(sql_cmd, conn)

# %%
myFrame
# Out:
#         sku                                      pname  month   gtotal  qty
# 0    100353                  백설 바삭튀김가루(1Kg/EA) 미국-※미국산      8     2750    1
# 1    100353                  백설 바삭튀김가루(1Kg/EA) 미국-※미국산      9    13750    5
# 2    100743  코카콜라 콜라(캔_355ml 355g/EA) 한국 24EA/BOX-※국내산      7    68112    4
# 3    100743  코카콜라 콜라(캔_355ml 355g/EA) 한국 24EA/BOX-※국내산      8    68112    4
# 4    100743  코카콜라 콜라(캔_355ml 355g/EA) 한국 24EA/BOX-※국내산      9    34056    2
# 5    100743  코카콜라 콜라(캔_355ml 355g/EA) 한국 24EA/BOX-※국내산     10    34056    2
# 6    100744  스프라이트 사이다(355ml 355g/EA) 한국 24EA/BOX-※국내산      7    76955    5
# 7    100744  스프라이트 사이다(355ml 355g/EA) 한국 24EA/BOX-※국내산      8    76955    5
# 8    100744  스프라이트 사이다(355ml 355g/EA) 한국 24EA/BOX-※국내산      9    61564    4
# 9    100744  스프라이트 사이다(355ml 355g/EA) 한국 24EA/BOX-※국내산     10    46173    3
# 10   105409                       아담스 파마산치즈파우더(1Kg/EA)      7    24200    2
# 11   105409                       아담스 파마산치즈파우더(1Kg/EA)      8    12100    1
# 12   111308                        천일식품 새우볶음밥(300g/EA)      7    23309   13
# 13   111308                        천일식품 새우볶음밥(300g/EA)      8    17930   10
# 14   111308                        천일식품 새우볶음밥(300g/EA)     10    17930   10
# 15   112371           칵테일냅킨(생활맥주용 10000장입 BOX) 1EA/BOX      7    33000    1
# 16   112371           칵테일냅킨(생활맥주용 10000장입 BOX) 1EA/BOX      8    33000    1
# 17   112371           칵테일냅킨(생활맥주용 10000장입 BOX) 1EA/BOX     10    33000    1
# 18   115364                            삼진 살사소스(2Kg/EA)      7    39600    4
# 19   115364                            삼진 살사소스(2Kg/EA)      8    59400    6
# 20   115364                            삼진 살사소스(2Kg/EA)      9    19800    2
# 21   115364                            삼진 살사소스(2Kg/EA)     10    59400    6
# 22   115722             사세통상 버팔로윙(1Kg/EA) 태국-※닭고기(태국산)      7   242550   21
# 23   115722             사세통상 버팔로윙(1Kg/EA) 태국-※닭고기(태국산)      8   127050   11
# 24   115722             사세통상 버팔로윙(1Kg/EA) 태국-※닭고기(태국산)      9   173250   15
# 25   115722             사세통상 버팔로윙(1Kg/EA) 태국-※닭고기(태국산)     10   127050   11
# 26   116709                    리코스 나쵸칩(454g/EA) 미국-※미국      7   267960   84
# 27   116709                    리코스 나쵸칩(454g/EA) 미국-※미국      8   210540   66
# 28   116709                    리코스 나쵸칩(454g/EA) 미국-※미국      9   191400   60
# 29   116709                    리코스 나쵸칩(454g/EA) 미국-※미국     10   111650   35
# ..      ...                                        ...    ...      ...  ...
# 163  424782          염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX      9  1254330   21
# 164  424782          염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX     10  1015410   17
# 165  424783                염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX      7   683100   15
# 166  424783                염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX      8   364320    8
# 167  424783                염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX      9   455400   10
# 168  424783                염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX     10   318780    7
# 169  500556            일회용기세트(1호_70*30mm_100입 다용도 PAC)      8     2386    1
# 170  500556            일회용기세트(1호_70*30mm_100입 다용도 PAC)      9     7158    3
# 171  500556            일회용기세트(1호_70*30mm_100입 다용도 PAC)     10     4772    2
# 172  501191                            하이코리아 락스(2L EA)      7    12316   12
# 173  501326                           스파크 세탁세제(5kg EA)      8    12617    1
# 174  501326                           스파크 세탁세제(5kg EA)      9    12617    1
# 175  501386                          트레펑(1L 막힌하수구용 EA)      7    24365   10
# 176  501386                          트레펑(1L 막힌하수구용 EA)      8    48730   20
# 177  501386                          트레펑(1L 막힌하수구용 EA)      9    48730   20
# 178  503517                       스카치브라이트 양면스폰지수세미(EA)      7     4813    5
# 179  512186                  이츠웰 롤백(소_25*35cm_500입 EA)      7     5390    2
# 180  512186                  이츠웰 롤백(소_25*35cm_500입 EA)      8     8085    3
# 181  512188                  이츠웰 롤백(중_30*40cm_500입 EA)      7     7700    2
# 182  512237          이츠웰 페이퍼타올(핸드타올_4500매 BOX) 1EA/BOX      9    21450    1
# 183  514151         이츠웰 다용도봉투(파란색_30L_48*64cm_100매 EA)      7     9900    3
# 184  514158                      이츠웰 주방세제(그린알로_3kg EA)      9     6232    2
# 185  514158                      이츠웰 주방세제(그린알로_3kg EA)     10     3116    1
# 186  514663                지원 일회용기뚜껑(W-3_75mm_100입 EA)      8     2024    1
# 187  514663                지원 일회용기뚜껑(W-3_75mm_100입 EA)      9     4048    2
# 188  514664               지원 일회용기(W-3_75*65mm_100입 EA)      9    13726    2
# 189  526116                        유산지(생활맥주용 1000개 EA)      7    66000    2
# 190  526116                        유산지(생활맥주용 1000개 EA)      8    33000    1
# 191  526116                        유산지(생활맥주용 1000개 EA)      9    66000    2
# 192  526117                         비닐백(생활맥주용 100매 EA)      7    39600    4
#
# [193 rows x 5 columns]

# %%
myFrame_T = myFrame.set_index(['sku','pname','month'])

# %%
myFrame_T
# Out:
#                                                          gtotal  qty
# sku    pname                                     month
# 100353 백설 바삭튀김가루(1Kg/EA) 미국-※미국산                 8         2750    1
#                                                  9        13750    5
# 100743 코카콜라 콜라(캔_355ml 355g/EA) 한국 24EA/BOX-※국내산 7        68112    4
#                                                  8        68112    4
#                                                  9        34056    2
#                                                  10       34056    2
# 100744 스프라이트 사이다(355ml 355g/EA) 한국 24EA/BOX-※국내산 7        76955    5
#                                                  8        76955    5
#                                                  9        61564    4
#                                                  10       46173    3
# 105409 아담스 파마산치즈파우더(1Kg/EA)                      7        24200    2
#                                                  8        12100    1
# 111308 천일식품 새우볶음밥(300g/EA)                       7        23309   13
#                                                  8        17930   10
#                                                  10       17930   10
# 112371 칵테일냅킨(생활맥주용 10000장입 BOX) 1EA/BOX          7        33000    1
#                                                  8        33000    1
#                                                  10       33000    1
# 115364 삼진 살사소스(2Kg/EA)                           7        39600    4
#                                                  8        59400    6
#                                                  9        19800    2
#                                                  10       59400    6
# 115722 사세통상 버팔로윙(1Kg/EA) 태국-※닭고기(태국산)            7       242550   21
#                                                  8       127050   11
#                                                  9       173250   15
#                                                  10      127050   11
# 116709 리코스 나쵸칩(454g/EA) 미국-※미국                   7       267960   84
#                                                  8       210540   66
#                                                  9       191400   60
#                                                  10      111650   35
# ...                                                         ...  ...
# 424782 염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX         9      1254330   21
#                                                  10     1015410   17
# 424783 염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX               7       683100   15
#                                                  8       364320    8
#                                                  9       455400   10
#                                                  10      318780    7
# 500556 일회용기세트(1호_70*30mm_100입 다용도 PAC)           8         2386    1
#                                                  9         7158    3
#                                                  10        4772    2
# 501191 하이코리아 락스(2L EA)                           7        12316   12
# 501326 스파크 세탁세제(5kg EA)                          8        12617    1
#                                                  9        12617    1
# 501386 트레펑(1L 막힌하수구용 EA)                         7        24365   10
#                                                  8        48730   20
#                                                  9        48730   20
# 503517 스카치브라이트 양면스폰지수세미(EA)                      7         4813    5
# 512186 이츠웰 롤백(소_25*35cm_500입 EA)                 7         5390    2
#                                                  8         8085    3
# 512188 이츠웰 롤백(중_30*40cm_500입 EA)                 7         7700    2
# 512237 이츠웰 페이퍼타올(핸드타올_4500매 BOX) 1EA/BOX         9        21450    1
# 514151 이츠웰 다용도봉투(파란색_30L_48*64cm_100매 EA)        7         9900    3
# 514158 이츠웰 주방세제(그린알로_3kg EA)                     9         6232    2
#                                                  10        3116    1
# 514663 지원 일회용기뚜껑(W-3_75mm_100입 EA)               8         2024    1
#                                                  9         4048    2
# 514664 지원 일회용기(W-3_75*65mm_100입 EA)              9        13726    2
# 526116 유산지(생활맥주용 1000개 EA)                       7        66000    2
#                                                  8        33000    1
#                                                  9        66000    2
# 526117 비닐백(생활맥주용 100매 EA)                        7        39600    4
#
# [193 rows x 2 columns]

# %%
myFrame_T.loc[u'백설 바삭튀김가루(1Kg/EA) 미국-※미국산']
# Out:
#                               sku  month mon  gtotal  qty quantity
# pname
# 백설 바삭튀김가루(1Kg/EA) 미국-※미국산  100353      8   월    2750    1        개
# 백설 바삭튀김가루(1Kg/EA) 미국-※미국산  100353      9   월   13750    5        개

# %%
myFrame_T[myFrame_T['sku'] == '100353']
# Out:
#                               sku  month mon  gtotal  qty quantity
# pname
# 백설 바삭튀김가루(1Kg/EA) 미국-※미국산  100353      8   월    2750    1        개
# 백설 바삭튀김가루(1Kg/EA) 미국-※미국산  100353      9   월   13750    5        개
