# %%
import sqlite3
import pandas as pd
from pandas import DataFrame, Series

conn_sales = sqlite3.connect('Sales.db')

# %%
sql_sales = """
                select year, month, sum(amount) as '총판매량'
                from sales
                where year = 2018 and month = 2;
"""
DF_Tsales = pd.read_sql_query(sql_sales, conn_sales)
DF_Tsales = DF_Tsales.set_index(['year', 'month'])

sql_lsales = """
                select year, month, sum(amount) as '라거판매량'
                from sales
                where year = 2018 and month = 2
                and cat2 = 21 or cat1 = 61;
"""
DF_Lsales = pd.read_sql_query(sql_lsales, conn_sales)
DF_Lsales = DF_Lsales.set_index(['year', 'month'])

sql_asales = """
                select year, month, sum(amount) as '에일판매량'
                from sales
                where year = 2018 and month = 2
                and cat2 = 22 or cat2 = 62;
"""
DF_Asales = pd.read_sql_query(sql_asales, conn_sales)
DF_Asales = DF_Asales.set_index(['year', 'month'])
sql_fsales = """
                select year, month, sum(amount) as '음식판매량'
                from sales
                where year = 2018 and month = 2
                and cat2 = 31 or cat2 = 30;
"""
DF_Fsales = pd.read_sql_query(sql_fsales, conn_sales)
DF_Fsales = DF_Fsales.set_index(['year', 'month'])

sql_csales = """
                select year, month, sum(amount) as '치킨판매량'
                from sales
                where (year = 2018 and month = 2)
                and (cat2 = 35 or cat2 = 36 or cat2 = 37);
"""
DF_Csales = pd.read_sql_query(sql_csales, conn_sales)
DF_Csales = DF_Csales.set_index(['year', 'month'])

DF_sales = pd.concat([DF_Tsales, DF_Lsales, DF_Asales, DF_Fsales, DF_Csales], axis=1)
DF_sales
# Out:
#                 총판매량    라거판매량     에일판매량    음식판매량    치킨판매량
# year month
# 2018 2      25373200  6579238  10777371  8391119  3857517

# %%
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %%
matplotlib.matplotlib_fname()
# Out:
# u'/Users/kwool/anaconda2/lib/python2.7/site-packages/matplotlib/mpl-data/matplotlibrc'

# %%
import matplotlib.font_manager as fm
fm.get_fontconfig_fonts()
# Out:
# []

# %%
fig = plt.figure()
my_colors = ['#3E8DAC', 'g', '#FEC200','y']
ax = DF_sales.plot.bar(stacked=False, figsize=(12,8), grid=True, colors=my_colors)

plt.rcParams["font.family"] = 'AppleMyungjo'
plt.rcParams['font.size'] = 12
plt.title(u'월별 매출 분석')

ax.set_xlabel('Year and Month')
ax.set_ylabel('Total Sales')


labels = []

for i in DF_sales.index:
    for j in DF_sales.columns:
        value_str = u"{:<12,}".format(int(DF_sales.loc[i][j])) 
        labels.append(value_str)

#print labels

patches = ax.patches
for label, rect in zip(labels, patches):
    width = rect.get_width()
    if width > 0:
        x = rect.get_x()
        y = rect.get_y()
        height = rect.get_height()
#        csv = "{:<12,}".format(int(label))
        ax.text(x + width/2., y + height/2.-0.01, label, ha='center', va='center', fontsize=14)

fig  = ax.get_figure()
fig.savefig('1-1-Sales-Total.png')
plt.show()

# %%
fig = plt.figure()

my_colors = ['#659353', 'g', '#FEC200','y']
ax = DF_sales[['라거판매량','에일판매량','음식판매량','치킨판매량']].T.plot.\
    pie(subplots=True, figsize=(6,6), autopct='%.2f', fontsize=14, colors=my_colors)

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
fig = ax[0].get_figure()
fig.savefig('1-2-Sales-Rate.png')
plt.show()

# %% [markdown]
# ## Food Sales

# %%
sql_food = """
            select year, month, pname, amount as sales
            from sales
            where cat1 = 3 and year = 2018 and month = 2;
"""
DF_food = pd.read_sql_query(sql_food, conn_sales)

DF_food_graph = DF_food.set_index('pname')
DF_food_graph
# Out:
#               year  month    sales
# pname
# 콜라            2018      2   138000
# 사이다           2018      2   168000
# 뻘건감자          2018      2   460000
# 촉촉오징어땅콩       2018      2   980000
# 골빔면           2018      2   315000
# 허연감자          2018      2   836119
# 스팸튀김          2018      2   198000
# 앵그리버드         2018      2  1353557
# 크리스피텐더        2018      2  1200000
# 버팔로윙          2018      2   645000
# 나초칩           2018      2   776000
# 그린라이트사라다      2018      2   299000
# 소시지와친구들       2018      2   546000
# 맥앤치즈샐러드       2018      2   247000
# 백화점육포         2018      2   275000
# 앵그리버드RED      2018      2   372000
# 앵그리버드RED(반반)  2018      2   286960
# 봉다리복만두        2018      2   180000

# %%
fig = plt.figure()
my_colors = ['#3E8DAC', 'g', '#FEC200','y','#FAC174']
ax = DF_food_graph['sales'].plot.bar(stacked=False, figsize=(18,10), grid=True, colors=my_colors)

plt.rcParams["font.family"] = 'AppleMyungjo'
plt.rcParams['font.size'] = 12
plt.title(u'음식 판매 매출 금액')

ax.set_xlabel('Food')
ax.set_ylabel('Total Sales')

labels = []
for i in DF_food_graph.index:
        value_str = u"{:<12,}".format(int(DF_food_graph.loc[i]['sales'])) 
        labels.append(value_str)
#print labels

patches = ax.patches
for label, rect in zip(labels, patches):
    width = rect.get_width()
    if width > 0:
        x = rect.get_x()
        y = rect.get_y()
        height = rect.get_height()
        ax.text(x + width/2., y + height/2.-0.01, label, ha='center', va='center', fontsize=12)

fig  = ax.get_figure()
fig.savefig('1-3-Food-Sales-Total.png')
plt.show()

# %%
# -------------------------------------------------------------------------
## Angry + RED + Half and Half
DF_food.loc[7, 'sales'] += DF_food.loc[15,'sales'] + DF_food.loc[16, 'sales']
DF_food = DF_food.drop([15,16])

# %%
# -----------------------------------------------------------------------------
# [0] 100743 콜라
indno = 0
sql_stmt = "select sum(total) from orderall where year=2018 and month=2 and sku=100743"
cursor = conn_sales.cursor()
cursor.execute(sql_stmt)
tuples = cursor.fetchone()
total = tuples[0]
DF_food.loc[indno, 'buy'] = total

# -----------------------------------------------------------------------------
# [1] 100744 사이다
indno = 1
sql_stmt = "select sum(total) from orderall where year=2018 and month=2 and sku=100744"
cursor = conn_sales.cursor()
cursor.execute(sql_stmt)
tuples = cursor.fetchone()
total = tuples[0]
DF_food.loc[indno, 'buy'] = total

# -----------------------------------------------------------------------------
# [2] 251901 빨간감자
indno = 2
sql_stmt = "select sum(total) from orderall where (year=2018 and month=2) and (sku=251901 or sku=215140 or sku=160016)"
cursor = conn_sales.cursor()
cursor.execute(sql_stmt)
tuples = cursor.fetchone()
total = tuples[0]
DF_food.loc[indno, 'buy'] = total

# -----------------------------------------------------------------------------
# [3] 오징어 + 땅콩
indno = 3
sql_stmt = "select sum(total) from orderall where (year=2018 and month=2) and (sku=232931 or sku = 206578)"
cursor = conn_sales.cursor()
cursor.execute(sql_stmt)
tuples = cursor.fetchone()
total = tuples[0]
DF_food.loc[indno, 'buy'] = total

# -----------------------------------------------------------------------------
# [4] 비빔면 + 골뱅이
indno = 4
sql_stmt = "select sum(total) from orderall where (year=2018 and month=2) and (sku=171838 or sku = 163815)"
cursor = conn_sales.cursor()
cursor.execute(sql_stmt)
tuples = cursor.fetchone()
total = tuples[0]
DF_food.loc[indno, 'buy'] = total

# -----------------------------------------------------------------------------
# [5] 251902 허연감자
indno = 5
sql_stmt = "select sum(total) from orderall where (year=2018 and month=2) and (sku=251902 or sku=215140 or sku=160016)"
cursor = conn_sales.cursor()
cursor.execute(sql_stmt)
tuples = cursor.fetchone()
total = tuples[0]
DF_food.loc[indno, 'buy'] = total

# -----------------------------------------------------------------------------
# [6] 118232 Spam
indno = 6
sql_stmt = "select sum(total) from orderall where year=2018 and month=2 and sku=118232"
cursor = conn_sales.cursor()
cursor.execute(sql_stmt)
tuples = cursor.fetchone()
total = tuples[0]
DF_food.loc[indno, 'buy'] = total


# -----------------------------------------------------------------------------
# [7] Angry + [15] Red + [16] H and H
indno = 7
#sql_stmt = "select sum(total) from orderall where (year=2018 and month=2) and (sku=424782 or sku=166412 or sku=247491 or sku=145970)"
sql_stmt = "select sum(total) from orderall where (year=2018 and month=2) and (sku=424782 or sku=166412 or sku=247491)"
cursor = conn_sales.cursor()
cursor.execute(sql_stmt)
tuples = cursor.fetchone()
total = tuples[0]
DF_food.loc[indno, 'buy'] = total


# -----------------------------------------------------------------------------
# [8] Krispy
indno = 8
sql_stmt = "select sum(total) from orderall where (year=2018 and month=2) and (sku=424783 or sku=140440)"
cursor = conn_sales.cursor()
cursor.execute(sql_stmt)
tuples = cursor.fetchone()
total = tuples[0]
DF_food.loc[indno, 'buy'] = total


# -----------------------------------------------------------------------------
# [9] Buff
indno = 9
sql_stmt = "select sum(total) from orderall where year=2018 and month=2 and sku=115722"
cursor = conn_sales.cursor()
cursor.execute(sql_stmt)
tuples = cursor.fetchone()
total = tuples[0]
DF_food.loc[indno, 'buy'] = total


# -----------------------------------------------------------------------------
# [10] Nacho
indno = 10
sql_stmt = "select sum(total) from orderall where (year=2018 and month=2) and (sku=116709 or sku = 115364 or sku = 119863)"
cursor = conn_sales.cursor()
cursor.execute(sql_stmt)
tuples = cursor.fetchone()
total = tuples[0]
DF_food.loc[indno, 'buy'] = total


# -----------------------------------------------------------------------------
# [11] Green Light Salad
indno = 11
sql_stmt = "select sum(total) from orderall where (year=2018 and month=2) and (sku=169394)"
cursor = conn_sales.cursor()
cursor.execute(sql_stmt)
tuples = cursor.fetchone()
total = tuples[0]
DF_food.loc[indno, 'buy'] = total


# -----------------------------------------------------------------------------
# [12] Green Light Salad
indno = 12
sql_stmt = "select sum(total) from orderall where (year=2018 and month=2) and (sku=176689 or sku=401354)"
cursor = conn_sales.cursor()
cursor.execute(sql_stmt)
tuples = cursor.fetchone()
total = tuples[0]
DF_food.loc[indno, 'buy'] = total


# -----------------------------------------------------------------------------
# [13] Mac and Cheese
indno = 13
sql_stmt = "select sum(total) from orderall where (year=2018 and month=2) and (sku=124531 or sku=215139 or sku=169394)"
cursor = conn_sales.cursor()
cursor.execute(sql_stmt)
tuples = cursor.fetchone()
total = tuples[0]
DF_food.loc[indno, 'buy'] = total



# -----------------------------------------------------------------------------
# [14] 64
indno = 14
sql_stmt = "select sum(total) from orderall where (year=2018 and month=2) and (sku=201934 or sku=206578 or sku=242910 )"
cursor = conn_sales.cursor()
cursor.execute(sql_stmt)
tuples = cursor.fetchone()
total = tuples[0]
DF_food.loc[indno, 'buy'] = total

# [15],[16] drop

# -----------------------------------------------------------------------------
# [17] dimsum
indno = 17
sql_stmt = "select sum(total) from orderall where (year=2018 and month=2) and (sku=140440 )"
cursor = conn_sales.cursor()
cursor.execute(sql_stmt)
tuples = cursor.fetchone()
total = tuples[0]
DF_food.loc[indno, 'buy'] = total



DF_food
# Out:
#     year  month     pname    sales       buy
# 0   2018      2        콜라   138000   35904.0
# 1   2018      2       사이다   168000   30782.0
# 2   2018      2      뻘건감자   460000  262922.0
# 3   2018      2   촉촉오징어땅콩   980000  365000.0
# 4   2018      2       골빔면   315000  137280.0
# 5   2018      2      허연감자   836119  381194.0
# 6   2018      2      스팸튀김   198000   77000.0
# 7   2018      2     앵그리버드  2012517  744810.0
# 8   2018      2    크리스피텐더  1200000  534292.0
# 9   2018      2      버팔로윙   645000  115500.0
# 10  2018      2       나초칩   776000  171160.0
# 11  2018      2  그린라이트사라다   299000  100800.0
# 12  2018      2   소시지와친구들   546000  211078.0
# 13  2018      2   맥앤치즈샐러드   247000  214287.0
# 14  2018      2     백화점육포   275000  220605.0
# 17  2018      2    봉다리복만두   180000  261052.0

# %% [markdown]
# ## Ale  Sales
