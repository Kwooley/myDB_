# %% [markdown]
# # DailyBeer

# %%
import sqlite3
conn = sqlite3.connect("OrderAll.db")

# %% [markdown]
# ## 1. Monthly  Total Amount Report

# %%
from pandas import Series, DataFrame
import pandas as pd

sql_cmd = """
            select month, sum(total) as grandtotal
            from OrderAll
            group by month
            order by month;
"""
cursor = conn.cursor()
cursor.execute(sql_cmd)
tuples = cursor.fetchall()

SR_Gtotal = Series([])


for tuple in tuples:
    SR_Gtotal = SR_Gtotal.set_value(int(tuple[0]), int(tuple[1]))
    print "{:>10}".format(tuple[0]), '월', "{:>12,}".format(tuple[1]),'원'

print SR_Gtotal.values
print SR_Gtotal.index
# Out:
#          7 월    8,474,601 원
#          8 월    7,594,394 원
#          9 월    6,673,702 원
#         10 월    4,974,996 원
#         11 월    4,325,622 원
#         12 월    4,400,016 원
# [8474601 7594394 6673702 4974996 4325622 4400016]
# Int64Index([7, 8, 9, 10, 11, 12], dtype='int64')

# %%
from itertools import cycle, islice
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

ind = np.arange(len(SR_Gtotal))
listtotal = SR_Gtotal.values
listindex = SR_Gtotal.index

plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
people = listindex
y_pos = np.arange(len(listindex))
performance = listtotal
error = np.random.rand(len(listindex))

ax.barh(y_pos, performance, 0.6, align='center',
        color='green', ecolor='black')

for i, v in enumerate(listtotal):
    ax.text(v + 3, i + .25, "{:,}".format(v), color='green', fontweight='bold')

ax.set_yticks(y_pos)
ax.set_yticklabels(listindex)
ax.set_xticklabels([0,100,200,300,400,500,600,700,800,900,1000], rotation=90)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel(u'Amount')
ax.set_title('Grand Total Amount Paid to CJ')

plt.show()

# %% [markdown]
# ##  2. Make the SQL Result as the DataFrame Directly

# %%
sql_cmd = """
select
        sku, pname,
        month,
        sum(total) as gtotal,
        sum(qty) as tqty
from OrderAll
group by sku, month
order by sku, month;
"""
SQL_Result_DF1 = pd.read_sql_query(sql_cmd, conn)

# %%
#print SQL_Result_DF1

# %%
print len(SQL_Result_DF1.index)
# Out:
# 272

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
pd.options.display.max_rows = 999

# %%
SQL_Result_DF1.columns
# Out:
# Index([u'sku', u'pname', u'month', u'gtotal', u'tqty'], dtype='object')

# %%
SQL_Result_DF1.set_index(['sku','pname', 'month'])
# Out:
#                                                         gtotal  tqty
# sku    pname                                     month
# 100353 백설 바삭튀김가루(1Kg/EA) 미국-※미국산                 8        2750     1
#                                                  9       13750     5
#                                                  12      11000     4
# 100743 코카콜라 콜라(캔_355ml 355g/EA) 한국 24EA/BOX-※국내산 7       68112     4
#                                                  8       68112     4
#                                                  9       34056     2
#                                                  10      34056     2
#                                                  11      34980     2
#                                                  12      35904     2
# 100744 스프라이트 사이다(355ml 355g/EA) 한국 24EA/BOX-※국내산 7       76955     5
#                                                  8       76955     5
#                                                  9       61564     4
#                                                  10      46173     3
#                                                  11      30782     2
#                                                  12      61564     4
# 105409 아담스 파마산치즈파우더(1Kg/EA)                      7       24200     2
#                                                  8       12100     1
# 111308 천일식품 새우볶음밥(300g/EA)                       7       23309    13
#                                                  8       17930    10
#                                                  10      17930    10
# 112371 칵테일냅킨(생활맥주용 10000장입 BOX) 1EA/BOX          7       33000     1
#                                                  8       33000     1
#                                                  10      33000     1
#                                                  12      33000     1
# 115364 삼진 살사소스(2Kg/EA)                           7       39600     4
#                                                  8       59400     6
#                                                  9       19800     2
#                                                  10      59400     6
#                                                  12      39600     4
# 115722 사세통상 버팔로윙(1Kg/EA) 태국-※닭고기(태국산)            7      242550    21
# ...                                                        ...   ...
# 424783 염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX               12     364320     8
# 500556 일회용기세트(1호_70*30mm_100입 다용도 PAC)           8        2386     1
#                                                  9        7158     3
#                                                  10       4772     2
# 501191 하이코리아 락스(2L EA)                           7       12316    12
# 501326 스파크 세탁세제(5kg EA)                          8       12617     1
#                                                  9       12617     1
#                                                  12      12617     1
# 501386 트레펑(1L 막힌하수구용 EA)                         7       24365    10
#                                                  8       48730    20
#                                                  9       48730    20
# 503517 스카치브라이트 양면스폰지수세미(EA)                      7        4813     5
# 512186 이츠웰 롤백(소_25*35cm_500입 EA)                 7        5390     2
#                                                  8        8085     3
#                                                  11      10780     4
# 512188 이츠웰 롤백(중_30*40cm_500입 EA)                 7        7700     2
# 512237 이츠웰 페이퍼타올(핸드타올_4500매 BOX) 1EA/BOX         9       21450     1
# 514151 이츠웰 다용도봉투(파란색_30L_48*64cm_100매 EA)        7        9900     3
# 514158 이츠웰 주방세제(그린알로_3kg EA)                     9        6232     2
#                                                  10       3116     1
#                                                  12       3116     1
# 514663 지원 일회용기뚜껑(W-3_75mm_100입 EA)               8        2024     1
#                                                  9        4048     2
# 514664 지원 일회용기(W-3_75*65mm_100입 EA)              9       13726     2
# 526116 유산지(생활맥주용 1000개 EA)                       7       66000     2
#                                                  8       33000     1
#                                                  9       66000     2
#                                                  11      66000     2
# 526117 비닐백(생활맥주용 100매 EA)                        7       39600     4
#                                                  11      49500     5
#
# [272 rows x 2 columns]

# %% [markdown]
# ### Pandas sort by group aggregate and column
#
# https://stackoverflow.com/questions/14941366/pandas-sort-by-group-aggregate-and-column

# %%
df_grouped = SQL_Result_DF1.groupby(['sku', 'pname'])
sort_group = SQL_Result_DF1.ix[df_grouped['gtotal'].transform(sum).sort_values(ascending=False).index]

sort_group.set_index(['sku', 'pname', 'month'])
#print len(sort_group.set_index(['sku', 'pname', 'month']).index)
# Out:
#                                                                 gtotal  tqty
# sku    pname                                            month
# 424782 염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX                9      1254330    21
#                                                         7      1672440    28
#                                                         12      836220    14
#                                                         11      657030    11
#                                                         10     1015410    17
#                                                         8      1552980    26
# 424783 염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX                      12      364320     8
#                                                         11      318780     7
#                                                         10      318780     7
#                                                         9       455400    10
#                                                         7       683100    15
#                                                         8       364320     8
# 134356 심플로트 냉동감자(메가크런치 2.04Kg/EA)                       11      295812    27
#                                                         7       602580    55
#                                                         8       493020    45
#                                                         9       438240    40
#                                                         10      449196    41
# 140440 심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)                      7       476036    62
#                                                         8       383900    50
#                                                         9       399256    52
#                                                         10      291764    38
#                                                         11      253374    33
#                                                         12      284086    37
# 232931 반건오징어(생활맥주용 10미 1.3Kg/EA) 한국-※국내산                7       354000    12
#                                                         12      310000    10
#                                                         11      270500     9
#                                                         8       590000    20
#                                                         10      177000     6
#                                                         9       383500    13
# 176689 소시지(생활맥주용 천연돈장_70g*4입 280g/EA) 한국-※돼지고기(국내산)     10      216315    45
#                                                         12      264385    55
#                                                         11      264385    55
#                                                         9       394174    82
#                                                         8       490314   102
#                                                         7       312455    65
# 144398 심플로트 냉동감자(세이보리_스트레이트컷 2.26Kg/EA)                 8       340494    33
#                                                         11      154770    15
#                                                         10      257950    25
#                                                         9       443674    43
#                                                         7       557172    54
# 169394 샐러드믹스(생활맥주용 150g*5입 750g/BOX) 한국 1EA/BOX-※국내산    12      201600    14
#                                                         8       288000    20
#                                                         9       187200    13
#                                                         11      158400    11
#                                                         7       345600    24
#                                                         10      144000    10
# 201934 소고기육포(생활맥주용 70g/EA) 호주-※호주산                      12      196515    45
#                                                         9       152845    35
#                                                         10      174680    40
#                                                         11      174680    40
#                                                         7       349360    80
#                                                         8       240185    55
# 163815 이츠웰 골뱅이캔(자연산 140g/EA)                            8       323400   105
#                                                         9       231000    75
#                                                         10      123200    40
#                                                         11      123200    40
#                                                         7       344960   112
#                                                         12       92400    30
# 116709 리코스 나쵸칩(454g/EA) 미국-※미국                          9       191400    60
#                                                         12       79750    25
#                                                         8       210540    66
#                                                         10      111650    35
#                                                         7       267960    84
#                                                         11      127600    40
# 116981 사세통상 버팔로윙스틱(1Kg/EA) 태국-※닭고기(태국산
니푸드 양념소금(마파치킨용 3.5g*90입 315g/EA)                9         1100     1
#                                                         10        1100     1
#                                                         7         2200     2
#        유니푸드 양념소금(마파치킨용 3.5g*90입 315g/EA) 한국-※정제염(국내산)   12        1100     1

# %% [markdown]
# # 99. Test Section

# %%
# SQL_Result_DF_index3 = SQL_Result_DF1.set_index(['sku','pname', 'month'])

### GROUP BY 'SKU"

df_grouped = SQL_Result_DF1.groupby(['sku', 'pname'])

###

print 'Total Number of Groups', df_grouped.ngroups

"""
for k, g in df_grouped:
    print k[0], k[1],'\t\t', 
    gsum = g['gtotal'].sum()
    print 'Group Total', "{:>12,}".format(gsum), '원'
    print '-'*100
"""
    
df_grouped_sum =  SQL_Result_DF1.groupby([u'sku', u'pname']).sum()
print df_grouped_sum[df_grouped_sum['gtotal']>6000000]
print "2,000,000 ~ 6,000,000"
print df_grouped_sum[(df_grouped_sum['gtotal'] > 2000000) & (df_grouped_sum['gtotal'] <= 6000000) ]
print "1,000,000 ~ 2,000,000"
print df_grouped_sum[(df_grouped_sum['gtotal'] > 1000000) & (df_grouped_sum['gtotal'] <= 2000000) ]
#print ""
#print df_grouped_sum[(df_grouped_sum['gtotal'] > 600000) & (df_grouped_sum['gtotal'] <= 1000000) ]
print "400,000 ~ 1,000,000"
print df_grouped_sum[(df_grouped_sum['gtotal'] > 400000) & (df_grouped_sum['gtotal'] <= 1000000) ]
print "200,000 ~ 400,000"
print df_grouped_sum[(df_grouped_sum['gtotal'] > 200000) & (df_grouped_sum['gtotal'] <= 400000) ]
print "100,000 ~ 200,000"
print df_grouped_sum[(df_grouped_sum['gtotal'] > 100000) & (df_grouped_sum['gtotal'] <= 200000) ]
print "50,000 ~ 100,000"
print df_grouped_sum[(df_grouped_sum['gtotal'] > 50000) & (df_grouped_sum['gtotal'] <= 100000) ]
print "000,000 ~ 50,000"
print df_grouped_sum[(df_grouped_sum['gtotal'] > 0) & (df_grouped_sum['gtotal'] <= 50000) ]



# print df_grouped_sum[['gtotal','tqty']].sort_values('gtotal', ascending=False)
# Out:
# Total Number of Groups 70
#                                           month   gtotal  tqty
# sku    pname
# 424782 염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX     57  6988410   117
# 2,000,000 ~ 6,000,000
#                                           month   gtotal  tqty
# sku    pname
# 134356 심플로트 냉동감자(메가크런치 2.04Kg/EA)            45  2278848   208
# 140440 심플로트 냉동감자(크링클컷웨지 2.26Kg/EA)           57  2088416   272
# 232931 반건오징어(생활맥주용 10미 1.3Kg/EA) 한국-※국내산     57  2085000    70
# 424783 염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX           57  2504700    55
# 1,000,000 ~ 2,000,000
#                                                       month   gtotal  tqty
# sku    pname
# 144398 심플로트 냉동감자(세이보리_스트레이트컷 2.26Kg/EA)                  45  1754060   170
# 163815 이츠웰 골뱅이캔(자연산 140g/EA)                             57  1238160   402
# 169394 샐러드믹스(생활맥주용 150g*5입 750g/BOX) 한국 1EA/BOX-※국내산     57  1324800    92
# 176689 소시지(생활맥주용 천연돈장_70g*4입 280g/EA) 한국-※돼지고기(국내산)      57  1942028   404
# 201934 소고기육포(생활맥주용 70g/EA) 호주-※호주산                       57  1288265   295
# 400,000 ~ 1,000,000
#                                                          month  gtotal  tqty
# sku    pname
# 115722 사세통상 버팔로윙(1Kg/EA) 태국-※닭고기(태국산)                       57  877800    76
# 116709 리코스 나쵸칩(454g/EA) 미국-※미국                              57  988900   310
# 116981 사세통상 버팔로윙스틱(1Kg/EA) 태국-※닭고기(태국산)                     57  916300    85
# 118232 스팸 햄캔(마일드 200g/EA)-※돼지고기(수입산 80%+국내산 20%) 96.27%     57  739200   240
# 124531 맥앤치즈볼(생활맥주용 50G*4입 200g/EA)                          57  844184   212
# 145970 치킨무(외식체인전용 5Kg/EA) 한국-※국내산                           57  456000    80
# 166412 뫼루니식품 물결무늬파우더(데일리비어용 매운맛 5Kg/EA) 미국-※미국산             57  506275    35
# 215140 양파드레싱(생활맥주용 2Kg/EA)                                  57  821700    83
# 247491 뫼루니식품 레드소스(데일리비어용 양념치킨용 2Kg/EA)                      50  470580    62
# 251902 냉동감자(생활맥주용 클리어코트슈스트링 2.04Kg/EA)                      23  413952    42
# 200,000 ~ 400,000
#                                                         month  gtotal  tqty
# sku    pname
# 100743 코카콜라 콜라(캔_355ml 355g/EA) 한국 24EA/BOX-※국내산           57  275220    16
# 100744 스프라이트 사이다(355ml 355g/EA) 한국 24EA/BOX-※국내산           57  353993    23
# 115364 삼진 살사소스(2Kg/EA)                                     46  217800    22
# 119863 삼조쎌텍 나쵸치즈소스(1Kg/EA)                                 57  346940    38
# 127454 파로 할라페뇨(슬라이스 3Kg/EA)                                57  364650    39
# 146239 쉐프솔루션 김치볶음밥(300g/EA)                                57  297220   193
# 146391 쉐프솔루션 햄야채볶음밥(300g/EA)                               57  269862   167
# 171838 팔도 비빔면(130g/EA) 40EA/BOX                            45  294800    10
# 206578 길림양행 땅콩(껍질무_1/2태 1Kg/PAC)-※이력번호:10931-17080202M     19  215600    28
# 251901 냉동감자(생활맥주용 스파이시스트레이트컷 2.04Kg/EA)                    23  325248    33
# 401354 계란(특란_60g*30입 1.8Kg/PAC) 한국-※달걀(국내산)                57  305967    39
# 526116 유산지(생활맥주용 1000개 EA)                                 35  231000     7
# 100,000 ~ 200,000
#                                                          month  gtotal  tqty
# sku    pname
# 112371 칵테일냅킨(생활맥주용 10000장입 BOX) 1EA/BOX                     37  132000     4
# 138389 이츠웰 초고추장(NEW 1Kg/EA)                                 57  108900    33
# 160016 오뚜기 케찹(스파우트팩 3.3Kg/EA)                               57  173800    40
# 166413 뫼루니 양념치킨소스(데일리비어용 양념_뫼루니 2Kg/EA)                     15  189750    25
# 178883 코스터(생활맥주용 600매 EA)                                   16  125400     2
# 206578 길림양행 땅콩(껍질무_1/2태 1Kg/PAC)-※이력번호:10931-17-060142M      7  138600    18
#        길림양행 땅콩(껍질무_1/2태 1Kg/PAC)-※이력번호:13361-17-300713M      8  115500    15
# 215139 케이준드레싱(생활맥주용 2Kg/EA)                                 57  109505    11
# 242910 웰넛 건포도(500g/EA) 미국-※미국산                              57  162338    62
# 501386 트레펑(1L 막힌하수구용 EA)                                    24  121825    50
# 50,000 ~ 100,000
#                                                          month  gtotal  tqty
# sku    pname
# 111308 천일식품 새우볶음밥(300g/EA)                                  25   59169    33
# 135267 그라나파다노치즈(포션 200g/EA)                                 37   58080     8
# 146393 쉐프솔루션 해물볶음밥(300g/EA)                                 45   97903    61
# 154639 오뚜기 마요네즈(골드 스파우트팩 3.2Kg/EA)                          36   64680     6
# 177050 기름여과지(생활맥주용 100매 BOX) 1EA/BOX                        10   80300     1
# 178733 물티슈(생활맥주용 500입 BOX) 1EA/BOX                          31   72600     6
# 206578 길림양행 땅콩(껍질무_1/2태 1Kg/PAC)-※이력번호:10931-17-090163M     11   92400    12
#        길림양행 땅콩(껍질무_1/2태 1Kg/PAC)-※이력번호:10931-17-100183M     12   77000    10
# 526117 비닐백(생활맥주용 100매 EA)                                   18   89100     9
# 000,000 ~ 50,000
#                                                        month  gtotal  tqty
# sku    pname
# 100353 백설 바삭튀김가루(1Kg/EA) 미국-※미국산                          29   27500    10
# 105409 아담스 파마산치즈파우더(1Kg/EA)                               15   36300     3
# 133941 유동 골뱅이캔(자연산 140g/EA)                               17   46200    15
# 139476 신영상회 파슬리후레이크(250g/EA)                              17   11920     2
# 143790 이츠웰 참기름(NEW_캔_1L 916g/EA) 수입산-※참깨(베트남산,미얀마산)       21   23320     2
# 159365 유니푸드 양념소금(마파치킨용 3.5g*90입 315g/EA)                  26    4400     4
#        유니푸드 양념소금(마파치킨용 3.5g*90입 315g/EA) 한국-※정제염(국내산)     12    1100     1
# 177058 미니고무장갑(생활맥주용 10입 EA)                               24   33000     4
# 500556 일회용기세트(1호_70*30mm_100입 다용도 PAC)                    27   14316     6
# 501191 하이코리아 락스(2L EA)                                     7   12316    12
# 501326 스파크 세탁세제(5kg EA)                                   29   37851     3
# 503517 스카치브라이트 양면스폰지수세미(EA)                                7    4813     5
# 512186 이츠웰 롤백(소_25*35cm_500입 EA)                          26   24255     9
# 512188 이츠웰 롤백(중_30*40cm_500입 EA)                           7    7700     2
# 512237 이츠웰 페이퍼타올(핸드타올_4500매 BOX) 1EA/BOX                   9   21450     1
# 514151 이츠웰 다용도봉투(파란색_30L_48*64cm_100매 EA)                  7    9900     3
# 514158 이츠웰 주방세제(그린알로_3kg EA)                              31   12464     4
# 514663 지원 일회용기뚜껑(W-3_75mm_100입 EA)                        17    6072     3
# 514664 지원 일회용기(W-3_75*65mm_100입 EA)                        9   13726     2

# %%
SQL_Result_DF1.set_index(['sku', 'pname', 'month'])[:15].unstack(level=-1)
# Out:
#                                                    gtotal                    \
# month                                                  7        8        9
# sku    pname
# 100353 백설 바삭튀김가루(1Kg/EA) 미국-※미국산                      NaN   2750.0  13750.0
# 100743 코카콜라 콜라(캔_355ml 355g/EA) 한국 24EA/BOX-※국내산  68112.0  68112.0  34056.0
# 100744 스프라이트 사이다(355ml 355g/EA) 한국 24EA/BOX-※국내산  76955.0  76955.0  61564.0
# 105409 아담스 파마산치즈파우더(1Kg/EA)                       24200.0  12100.0      NaN
# 111308 천일식품 새우볶음밥(300g/EA)                        23309.0      NaN      NaN
#
#                                                                     tqty       \
# month                                                  10       11    7    8
# sku    pname
# 100353 백설 바삭튀김가루(1Kg/EA) 미국-※미국산                      NaN      NaN   NaN  1.0
# 100743 코카콜라 콜라(캔_355ml 355g/EA) 한국 24EA/BOX-※국내산  34056.0  34980.0   4.0  4.0
# 100744 스프라이트 사이다(355ml 355g/EA) 한국 24EA/BOX-※국내산  46173.0  30782.0   5.0  5.0
# 105409 아담스 파마산치즈파우더(1Kg/EA)                           NaN      NaN   2.0  1.0
# 111308 천일식품 새우볶음밥(300g/EA)                            NaN      NaN  13.0  NaN
#
#
# month                                              9    10   11
# sku    pname
# 100353 백설 바삭튀김가루(1Kg/EA) 미국-※미국산                  5.0  NaN  NaN
# 100743 코카콜라 콜라(캔_355ml 355g/EA) 한국 24EA/BOX-※국내산  2.0  2.0  2.0
# 100744 스프라이트 사이다(355ml 355g/EA) 한국 24EA/BOX-※국내산  4.0  3.0  2.0
# 105409 아담스 파마산치즈파우더(1Kg/EA)                       NaN  NaN  NaN
# 111308 천일식품 새우볶음밥(300g/EA)                        NaN  NaN  NaN

# %% [markdown]
# ## Font in Plot

# %%
matplotlib.matplotlib_fname()
# Out:
# u'/Users/kylelee/anaconda2/lib/python2.7/site-packages/matplotlib/mpl-data/matplotlibrc'

# %%
import matplotlib.font_manager as fm
fm.get_fontconfig_fonts()
# Out:
# []

# %%
SQL_Result_DF1.set_index(['sku', 'pname', 'month'])[:15].unstack(level=-1).plot(kind='bar', stacked=False)
plt.rcParams["font.family"] = 'AppleMyungjo'
plt.rcParams['font.size'] = 8
plt.title(u'품목별 월별 매출현황' )
plt.show()

# %% [markdown]
# ### Truncate unicode string with Unicode utf-8

# %%
print tuple[1]
def unicode_truncate(s, length, encoding='utf-8'):
    encoded = s.encode(encoding)[:length]
    return encoded.decode(encoding, 'ignore')
print unicode_truncate(tuple[1], 60)
# Out:
# 백설 바삭튀김가루(1Kg/EA) 미국
# ※미국산
# 백설 바삭튀김가루(1Kg/EA) 미국
# ※미국산

# %% [markdown]
# ### tuple insertion

# %%
 t1 = ( (1, 'p100', 'JUL', 20), (1, 'p100', 'AUG', 30),
        (2, 'p200', 'JUL', 10), (2, 'p200', 'AUG', 40), (2, 'p200', 'SEP', 50),
        (3, 'p300', 'JUL', 40),
        (4, 'p400', 'JUL', 10), (4, 'p400', 'AUG', 20), (4, 'p400', 'SEP', 40), (4, 'p400', 'OCT', 60)
      )

# %%
t1
# Out:
# ((1, 'p100', 'JUL', 20),
#  (1, 'p100', 'AUG', 30),
#  (2, 'p200', 'JUL', 10),
#  (2, 'p200', 'AUG', 40),
#  (2, 'p200', 'SEP', 50),
#  (3, 'p300', 'JUL', 40),
#  (4, 'p400', 'JUL', 10),
#  (4, 'p400', 'AUG', 20),
#  (4, 'p400', 'SEP', 40),
#  (4, 'p400', 'OCT', 60))

# %% [markdown]
# ### DataFrame from dictionary

# %%
from pandas import Series, DataFrame
import numpy as np


dict1 = {'JUL':[10,20,30,40],
         'AUG':[11,21,31,41],
         'SEP':[12,22,32,42],
         'OCT':[13,23,33,43]
        }
df1 = DataFrame(dict1, columns=['JUL', 'AUG', 'SEP', 'OCT'], index=['p1','p2', 'p3','p4'])
df1
# Out:
#     JUL  AUG  SEP  OCT
# p1   10   11   12   13
# p2   20   21   22   23
# p3   30   31   32   33
# p4   40   41   42   43

# %% [markdown]
# ### new row insertion with dict form into DataFrame

# %%
df1.loc['p4'] = {'JUL':14, 'AUG':24, 'SEP':34, 'OCT':44}
df1
# Out:
#     JUL  AUG  SEP  OCT
# p1   10   11   12   13
# p2   20   21   22   23
# p3   30   31   32   33
# p4   14   24   34   44

# %%
df1.loc['p5'] = [50, 51, 52, 53]
df1
# Out:
#     JUL  AUG  SEP  OCT
# p1   10   11   12   13
# p2   20   21   22   23
# p3   30   31   32   33
# p4   14   24   34   44
# p5   50   51   52   53

# %% [markdown]
# ###  Test Unstack

# %%
df1.unstack(level=0)
# Out:
# JUL  p1    10
#      p2    20
#      p3    30
#      p4    14
#      p5    50
# AUG  p1    11
#      p2    21
#      p3    31
#      p4    24
#      p5    51
# SEP  p1    12
#      p2    22
#      p3    32
#      p4    34
#      p5    52
# OCT  p1    13
#      p2    23
#      p3    33
#      p4    44
#      p5    53
# dtype: int64

# %%
index = pd.MultiIndex.from_tuples([('one', 'a'), ('one', 'b'),
                                   ('two', 'a'), ('two', 'b')])
s1 = Series(np.arange(1.0, 5.0), index=index)

# %%
s1
# Out:
# one  a    1.0
#      b    2.0
# two  a    3.0
#      b    4.0
# dtype: float64

# %%
s.unstack(level=-1)
# Out:
#        a    b
# one  1.0  2.0
# two  3.0  4.0

# %% [markdown]
# ###  DataFrame with unstackI()

# %%
dfmi = DataFrame(dict1, columns=['JUL', 'AUG', 'SEP', 'OCT'], index=index)
dfmi
# Out:
#        JUL  AUG  SEP  OCT
# one a   10   11   12   13
#     b   20   21   22   23
# two a   30   31   32   33
#     b   40   41   42   43

# %%
dfmi.unstack(level=-1)
# Out:
#     JUL     AUG     SEP     OCT
#       a   b   a   b   a   b   a   b
# one  10  20  11  21  12  22  13  23
# two  30  40  31  41  32  42  33  43

# %%
dfmi.unstack(level=0)
# Out:
#   JUL     AUG     SEP     OCT
#   one two one two one two one two
# a  10  30  11  31  12  32  13  33
# b  20  40  21  41  22  42  23  43

# %%
dfmi.unstack(level=0).plot(kind='bar', stacked=True)

# %%
dfmi.unstack(level=-2)
# Out:
#   JUL     AUG     SEP     OCT
#   one two one two one two one two
# a  10  30  11  31  12  32  13  33
# b  20  40  21  41  22  42  23  43

# %% [markdown]
# ### Condition check of tuples and Make a dict from tuple elements

# %%
t1
# Out:
# ((1, 'p100', 'JUL', 20),
#  (1, 'p100', 'AUG', 30),
#  (2, 'p200', 'JUL', 10),
#  (2, 'p200', 'AUG', 40),
#  (2, 'p200', 'SEP', 50),
#  (3, 'p300', 'JUL', 40),
#  (4, 'p400', 'JUL', 10),
#  (4, 'p400', 'AUG', 20),
#  (4, 'p400', 'SEP', 40),
#  (4, 'p400', 'OCT', 60))

# %%
colarray = ['JUL', 'AUG', 'SEP', 'OCT']

prev = None
new_d = {'JUL':None, 'AUG':None, 'SEP':None, 'OCT':None}
dfdic = DataFrame(None, columns=colarray)
for t in t1:    
    if prev != t[0] and prev != None:
        print new_d
        dfdic.loc[t[1]] = new_d
        new_d = {'JUL':None, 'AUG':None, 'SEP':None, 'OCT':None}
        
    new_d[t[2]]= t[3]
    prev = t[0]
print new_d
# Out:
# {'OCT': None, 'AUG': 30, 'JUL': 20, 'SEP': None}
# {'OCT': None, 'AUG': 40, 'JUL': 10, 'SEP': 50}
# {'OCT': None, 'AUG': None, 'JUL': 40, 'SEP': None}
# {'OCT': 60, 'AUG': 20, 'JUL': 10, 'SEP': 40}

# %%
dfdic
# Out:
#        JUL   AUG   SEP  OCT
# p200  20.0  30.0   NaN  NaN
# p300  10.0  40.0  50.0  NaN
# p400  40.0   NaN   NaN  NaN

# %%
df1.loc['p100'] = [None, None, None, None]
df1.loc['p100']['JUL'] = 299

df1
# Out:
#       JUL   AUG   SEP   OCT
# p1     10    11    12    13
# p2     20    21    22    23
# p3     30    31    32    33
# p4     14    24    34    44
# p100  299  None  None  None

# %% [markdown]
# ### SQL result to DataFrame in SQLite3

# %%
myFrame = pd.read_sql_query(sql_cmd, conn)

# %%
myFrame
# Out:
#         sku                                      pname  month   gtotal  qty
# 0    100353                  백설 바삭튀김가루(1Kg/EA) 미국-※미국산      8     2750    1
# 1    100353                  백설 바삭튀김가루(1Kg/EA) 미국-※미국산      9    13750    5
# 2    100743  코카콜라 콜라(캔_355ml 355g/EA) 한국 24EA/BOX-※국내산
# 191  526116                        유산지(생활맥주용 1000개 EA)      9    66000    2
# 192  526117                         비닐백(생활맥주용 100매 EA)      7    39600    4
#
# [193 rows x 5 columns]

# %%
myFrame_T = myFrame.set_index(['sku','pname','month'])

# %%
myFrame_T
# Out:
#                                                          gtotal  qty
# sku    pname                                     month
# 100353 백설 바삭튀김가루(1Kg/EA) 미국-※미국산                 8         2750    1
#                                                  9        13750    5
# 100743 코카콜라 콜라(캔_355ml 355g/EA) 한국 24EA/BOX-※국내산 7        68112    4
#                                                  8        68112    4
#                                                  9        34056    2
#                                                  10       34056    2
# 100744 스프라이트 사이다(355ml 355g/EA) 한국 24EA/BOX-※국내산 7        76955    5
#                                                  8        76955    5
#                                                  9        61564    4
#                                                  10       46173    3
# 105409 아담스 파마산치즈파우더(1Kg/EA)                      7        24200    2
#                                                  8        12100    1
# 111308 천일식품 새우볶음밥(300g/EA)                       7        23309   13
#                                                  8        17930   10
#                                                  10       17930   10
# 112371 칵테일냅킨(생활맥주용 10000장입 BOX) 1EA/BOX          7        33000    1
#                                                  8        33000    1
#                                                  10       33000    1
# 115364 삼진 살사소스(2Kg/EA)                           7        39600    4
#                                                  8        59400    6
#                                                  9        19800    2
#                                                  10       59400    6
# 115722 사세통상 버팔로윙(1Kg/EA) 태국-※닭고기(태국산)            7       242550   21
#                                                  8       127050   11
#                                                  9       173250   15
#                                                  10      127050   11
# 116709 리코스 나쵸칩(454g/EA) 미국-※미국                   7       267960   84
#                                                  8       210540   66
#                                                  9       191400   60
#                                                  10      111650   35
# ...                                                         ...  ...
# 424782 염지닭(생활맥주용 9호_9각 850g/EA) 10EA/BOX         9      1254330   21
#                                                  10     1015410   17
# 424783 염지닭안심(생활맥주용 1Kg/EA) 5EA/BOX               7       683100   15
#                                                  8       364320    8
#                                                  9       455400   10
#                                                  10      318780    7
# 500556 일회용기세트(1호_70*30mm_100입 다용도 PAC)           8         2386    1
#                                                  9         7158    3
#                                                  10        4772    2
# 501191 하이코리아 락스(2L EA)                           7        12316   12
# 501326 스파크 세탁세제(5kg EA)                          8        12617    1
#                                                  9        12617    1
# 501386 트레펑(1L 막힌하수구용 EA)                         7        24365   10
#                                                  8        48730   20
#                                                  9        48730   20
# 503517 스카치브라이트 양면스폰지수세미(EA)                      7         4813    5
# 512186 이츠웰 롤백(소_25*35cm_500입 EA)                 7         5390    2
#                                                  8         8085    3
# 512188 이츠웰 롤백(중_30*40cm_500입 EA)                 7         7700    2
# 512237 이츠웰 페이퍼타올(핸드타올_4500매 BOX) 1EA/BOX         9        21450    1
# 514151 이츠웰 다용도봉투(파란색_30L_48*64cm_100매 EA)        7         9900    3
# 514158 이츠웰 주방세제(그린알로_3kg EA)                     9         6232    2
#                                                  10        3116    1
# 514663 지원 일회용기뚜껑(W-3_75mm_100입 EA)               8         2024    1
#                                                  9         4048    2
# 514664 지원 일회용기(W-3_75*65mm_100입 EA)              9        13726    2
# 526116 유산지(생활맥주용 1000개 EA)                       7        66000    2
#                                                  8        33000    1
#                                                  9        66000    2
# 526117 비닐백(생활맥주용 100매 EA)                        7        39600    4
#
# [193 rows x 2 columns]

# %%
myFrame_T.loc[u'백설 바삭튀김가루(1Kg/EA) 미국-※미국산']
# Out:
#                               sku  month mon  gtotal  qty quantity
# pname
# 백설 바삭튀김가루(1Kg/EA) 미국-※미국산  100353      8   월    2750    1        개
# 백설 바삭튀김가루(1Kg/EA) 미국-※미국산  100353      9   월   13750    5        개

# %%
myFrame_T[myFrame_T['sku'] == '100353']
# Out:
#                               sku  month mon  gtotal  qty quantity
# pname
# 백설 바삭튀김가루(1Kg/EA) 미국-※미국산  100353      8   월    2750    1        개
# 백설 바삭튀김가루(1Kg/EA) 미국-※미국산  100353      9   월   13750    5        개
